# %% [markdown]
# ### Demo key shift with chopin prelude

# %% [markdown]
# Thoughts:
# - turn original midi into running-status-free midi (avoiding confusion when recovering midi from smart contract call)
# - turn midi into smart contracts
#     - for note manipulation: `new note hex = original note hex + note_shift_amount * 2^8`; `length` unchanged

# %%
import mido
import sys
import binascii
import pprint
from collections import OrderedDict
from mido import Message, MidiFile, MidiTrack
from enum import Enum
from copy import copy, deepcopy

# %%
### Need to deal with variable length -- for both "len" of meta-event, and "delta-time"
### Need to deal with running status -- http://midi.teragonaudio.com/tech/midispec/run.htm

MSB_1 = ['8', '9', 'a', 'b', 'c', 'd', 'e', 'f']

## TODO: ff00
## TODO: ff20, 21
## TODO: ff7f
## TODO: running status for all events

END_OF_TRACK = 'ff2f00'
TEXT_META_EVENTS = [f'ff0{i+1}' for i in range(9)]
TEMPO = 'ff5103'
SMPTE = 'ff5405'
TIME_SIG = 'ff5804'
KEY_SIG = 'ff5902'

class Track:
    def __init__(self, track):
        self.track = track
        self._parse()
    
    def _get_varlen_value (self, string):
        value = ''
        j = 0
        while True:
            if string[j] not in MSB_1: # reached last byte of variable-length field
                value = string[0:j+2]
                break
            else:
                j += 2
        return value
        
    def _varFieldToInt(self, hexstring):
        ret = 0
        current_byte = ''

        i=0
        while len(hexstring):
            current_byte = "0x" + hexstring[0:2]
            current_integer = int(current_byte, 16)
            ret = (ret << 7) | (current_integer & 0x7f)
            if not current_integer & 0x80:
                return ret
            hexstring = hexstring[2:]

            i += 1
            if i>1000:
                print('error')
                break
    
    def _parse(self):
        D = []
        
        assert self.track[0:8] == '4d54726b'
        self.chunklen = self.track[8:8+8]
        D.append({'type':'header', 'value':'4d54726b'})
        D.append({'type':'chunklen', 'value':self.track[8:8+8]})
        
        track = self.track[16:]
        i = 0
        state = 'delta-time' # state in ['delta-time', 'event']
        while True:
            if state == 'delta-time':
                value = self._get_varlen_value(track[i:])
                D.append( {'type':'delta time', 'value':value} )
                i += len(value)
                state = 'event'
                continue
                
            else: # state == 'event'
                running = False
                ## first decode event
                if track[i] not in MSB_1: # running status in use
                    event = last_event # for note on / note off / control change / program change - include channel n
                    running = True
                else:
                    track_first6 = track[i:i+6]
                    track_first4 = track[i:i+4]
                    track_first = track[i]
                    if track_first6 == END_OF_TRACK: # end of track; ff 2f 00
                        event = END_OF_TRACK
                    elif track_first6 == TIME_SIG: # ff 58 04 nn dd cc bb
                        event = TIME_SIG
                    elif track_first6 == KEY_SIG: # ff 59 02 sf mi
                        event = KEY_SIG
                    elif track_first6 == TEMPO: # ff 51 03 tt tt tt
                        event = TEMPO
                    elif track_first6 == SMPTE: # ff 54 05 hr mn se fr ff
                        event = SMPTE
                    elif track_first4 in TEXT_META_EVENTS:
                        event = track_first4
                    elif track_first in ['b','c','8','9']:
                        event = track[i:i+2]
                    
                ## then parse event and append to event list
                if event == END_OF_TRACK: # end of track; ff 2f 00
                    D.append( {'type':'end of track', 'type hex':END_OF_TRACK, 'value':''} )
                    break
                
                elif event == TIME_SIG: # ff 58 04 nn dd cc bb
                    D.append( {'type':'time signature', 'type hex':track_first6, 'value':track[i+6:i+6+8]} )
                    i += 14
                    
                elif event == KEY_SIG: # ff 59 02 sf mi
                    D.append( {'type':'key signature', 'type hex':track_first6, 'value':track[i+6:i+6+4]} )
                    i += 10
                
                elif event == TEMPO: # ff 51 03 tt tt tt
                    D.append( {'type':'tempo', 'type hex':track_first6, 'value':track[i+6:i+6+6]} )
                    i += 12
                
                elif event == SMPTE: # ff 54 05 hr mn se fr ff
                    D.append( {'type':'smpte', 'type hex':track_first6, 'value':track[i+6:i+6+10]} )
                    i += 16
                    
                # sequence/track name (ff 03 length text)
                # or marker (ff 06 length text)
                # or cue (ff 07 length text)
                elif event in TEXT_META_EVENTS:
                    if running:
                        name_length_varlen = self._get_varlen_value(track)
                        name_length = self._varFieldToInt(name_length_varlen)
                        name = track[i + len(name_length_varlen) : i + len(name_length_varlen) + name_length*2]
                        D.append( {'type':'text meta event', 'type hex':event, 'omitted':2, ## omitted 2 bytes
                                   'length_varlen':name_length_varlen, 'name':name} )
                        i += len(name_length_varlen) + name_length*2 # name_length * byte, every byte == 2 hex
                    else:
                        name_length_varlen = self._get_varlen_value(track[i+4:])
                        name_length = self._varFieldToInt(name_length_varlen)
                        name = track[i + 4 + len(name_length_varlen) : i + 4 + len(name_length_varlen) + name_length*2]
                        D.append( {'type':'text meta event', 'type hex':track_first4, 'omitted':0,
                                   'length_varlen':name_length_varlen, 'name':name} )
                        i += 4 + len(name_length_varlen) + name_length*2 # name_length * byte, every byte == 2 hex
                
                # Assuming only bn/cn/8n/9n can use running-status
                elif event[0] == 'b': # control change; bn controller value
                    if running:
                        D.append( {'type':'control change', 'type hex':'b', 'omitted':1,
                                   'channel':event[1], 'controller':track[i:i+2], 'value':track[i+2:i+4]} )
                        i += 4
                    else:
                        D.append( {'type':'control change', 'type hex':'b', 'omitted':0,
                                   'channel':track[i+1], 'controller':track[i+2:i+4], 'value':track[i+4:i+6]} )
                        i += 6
                
                elif event[0] == 'c': # program change; cn program
                    if running:
                        D.append( {'type':'program change', 'type hex':'c', 'omitted':1,
                                   'channel':event[1], 'program':track[i:i+2]} )
                        i += 2
                    else:
                        D.append( {'type':'program change', 'type hex':'c', 'omitted':0,
                                   'channel':track[i+1], 'program':track[i+2:i+4]} )
                        i += 4
                
                elif event[0] == '9': # note on; 9n note velocity
                    if running:
                        D.append( {'type':'note on', 'type hex':'9', 'omitted':1,
                                   'channel':event[1], 'note':track[i:i+2], 'velocity':track[i+2:i+4]} )
                        i += 4
                    else:
                        D.append( {'type':'note on', 'type hex':'9', 'omitted':0,
                                   'channel':track[i+1], 'note':track[i+2:i+4], 'velocity':track[i+4:i+6]} )
                        i += 6
                    
                elif track_first == '8': # note off; 8n note velocity
                    if running:
                        D.append( {'type':'note off', 'type hex':'8', 'omitted':1,
                                   'channel':event[1], 'note':track[i:i+2], 'velocity':track[i+2:i+4]} )
                        i += 4
                    else:
                        D.append( {'type':'note off', 'type hex':'8', 'omitted':0,
                                   'channel':track[i+1], 'note':track[i+2:i+4], 'velocity':track[i+4:i+6]} )
                        i += 6
                
                last_event = event
                state = 'delta-time'
                
        self.segs = D    
    
    def segs_to_hexstring(self): # segs is list of events, each event is a dictionary
        hexstring = ''

        for event in self.segs:
            hexstring += Track.event_to_hexstring(event)
        return hexstring

    @staticmethod
    def event_to_hexstring(event):
        if event['type'] == 'header' or event['type'] == 'chunklen' or event['type'] == 'delta time':
            hexstring = event['value']

        elif event['type'] == 'end of track':
            hexstring = event['type hex']

        elif event['type'] == 'text meta event':
            hexstring = event['type hex']*(not event['omitted']) + event['length_varlen'] + event['name']

        elif event['type'] in ['time signature', 'key signature', 'tempo', 'smpte']:
            hexstring = event['type hex'] + event['value']

        elif event['type'] == 'control change':
            hexstring = (event['type hex']+event['channel'])*(not event['omitted']) + event['controller'] + event['value']

        elif event['type'] == 'program change':
            hexstring = (event['type hex']+event['channel'])*(not event['omitted']) + event['program']

        elif event['type'] == 'note on' or event['type'] == 'note off':
            hexstring = (event['type hex']+event['channel'])*(not event['omitted']) + event['note'] + event['velocity']

        return hexstring
    
    @staticmethod
    def event_to_hexstring_discard_runningstatus(event):
        if event['type'] == 'header' or event['type'] == 'chunklen' or event['type'] == 'delta time':
            hexstring = event['value']

        elif event['type'] == 'end of track':
            hexstring = event['type hex']

        elif event['type'] == 'text meta event':
            hexstring = event['type hex'] + event['length_varlen'] + event['name']

        elif event['type'] in ['time signature', 'key signature', 'tempo', 'smpte']:
            hexstring = event['type hex'] + event['value']

        elif event['type'] == 'control change':
            hexstring = event['type hex'] + event['channel'] + event['controller'] + event['value']

        elif event['type'] == 'program change':
            hexstring = event['type hex'] + event['channel'] + event['program']

        elif event['type'] == 'note on' or event['type'] == 'note off':
            hexstring = event['type hex'] + event['channel'] + event['note'] + event['velocity']

        return hexstring
    
class Music:
    def __init__(self, name):
        self._parse_midi(name)
        self.name = name
    
    def _parse_midi(self, name):
        midi_file = f'./{name}.mid'

        with open(midi_file, 'rb') as f:
            hexdata = binascii.hexlify(f.read())
        hexdata_str = hexdata.decode("utf-8")

        MTrk = '4d54726b'
        tracks_str = []
        for i,chunk in enumerate(hexdata_str.split(MTrk)):
            if i == 0:
                header_str = chunk
            else:
                tracks_str.append (MTrk + chunk)

        track_objs = [Track(t) for t in tracks_str]
        
        self.header_str = header_str
        self.track_objs = track_objs

    def keyshift(self, shift_amount):
        track_objs = self.track_objs.copy()
        for obj in track_objs:
            for event in obj.segs:
                if event['type'] == 'note on' or event['type'] == 'note off':
                    note_hex = '0x'+event['note']
                    note_integer = int(note_hex, 16)
                    note_integer_shifted = note_integer + shift_amount
                    note_hex_shifted = hex(note_integer_shifted)[2:]
                    note_hex_shifted = note_hex_shifted.rjust(2, '0')
                    event['note'] = note_hex_shifted
        self.track_objs = track_objs
    
    def export_midi(self, name):
        recovered_tracks = [T.segs_to_hexstring() for T in self.track_objs]
        with open(f'{name}.mid', 'wb') as fout:
            fout.write( binascii.unhexlify(self.header_str + ''.join(recovered_tracks)) )

# %%
chpn_og = Music('chpn-p1')
print(f'number of music tracks: {len(chpn_og.track_objs)-1}')
# Out:
# number of music tracks: 6

# %%
for i,track_obj in enumerate(chpn_og.track_objs):
    omit = 0
    for event in track_obj.segs:
        if 'omitted' in event:
            omit += event['omitted']
    print(f'track {i} omitted {omit} bytes')
# Out:
# track 0 omitted 0 bytes
# track 1 omitted 409 bytes
# track 2 omitted 247 bytes
# track 3 omitted 0 bytes
# track 4 omitted 0 bytes
# track 5 omitted 0 bytes
# track 6 omitted 0 bytes

# %%
chpn = deepcopy(chpn_og)

# %%
print(chpn_og.track_objs[1].segs[1])
print(chpn_og.track_objs[2].segs[1])
# Out:
# {'type': 'chunklen', 'value': '00000519'}
# {'type': 'chunklen', 'value': '00000430'}

# %%
chunklen1 = int('0x' + chpn.track_objs[1].segs[1]['value'], 16)
chunklen1_new = chunklen1 - 409
chunklen1_new_hex = hex(chunklen1_new)[2:]
chunklen1_new_hex = chunklen1_new_hex.rjust(8, '0')
chpn.track_objs[1].segs[1]['value'] = chunklen1_new_hex

# %%
chunklen2 = int('0x' + chpn.track_objs[2].segs[1]['value'], 16)
chunklen2_new = chunklen2 - 247
chunklen2_new_hex = hex(chunklen2_new)[2:]
chunklen2_new_hex = chunklen2_new_hex.rjust(8, '0')
chpn.track_objs[2].segs[1]['value'] = chunklen2_new_hex

# %%
print(chpn.track_objs[1].segs[1])
print(chpn.track_objs[2].segs[1])
# Out:
# {'type': 'chunklen', 'value': '00000380'}
# {'type': 'chunklen', 'value': '00000339'}

# %%
def convert_hex_to_arr(hexstring):
        '''
        last element of the felt array is an integer indicating the hex-length of the last felt value
        '''
        arr = []
        s = hexstring
        while( len(s)>62 ):
            felt_hex = s[0:62]
            arr.append( int(felt_hex, 16) )
            s = s[62:]
        felt_hex = s
        last_length = len(felt_hex)
        arr.append( int(felt_hex, 16) )
        arr.append(last_length)
        
        return arr
    
def generate_single(hexstring, name):
        ret = []
        
        ret.append( '@view')
        ret.append(f'func {name} {{')
        ret.append( '        range_check_ptr')
        ret.append( '    } () -> (')
        ret.append( '        z_len : felt,')
        ret.append( '        z : felt*')
        ret.append( '    ):')
        ret.append( '    alloc_locals\n')
        ret.append( '    let (local z) = alloc()\n')
      
        arr = convert_hex_to_arr(hexstring)
        for i,num in enumerate(arr):
            ret.append(f'    assert [z+{i}] = {num}')
        ret.append(f'    let z_len = {i+1}')
        ret.append('\n    return (z_len, z)')
        ret.append('end')
        
        for line in ret:
            print(line)

def event_to_hexstring_no_omittance(event):
        if event['type'] == 'header' or event['type'] == 'chunklen' or event['type'] == 'delta time':
            hexstring = event['value']

        elif event['type'] == 'end of track':
            hexstring = event['type hex']

        elif event['type'] == 'text meta event':
            hexstring = event['type hex'] + event['length_varlen'] + event['name']

        elif event['type'] in ['time signature', 'key signature', 'tempo', 'smpte']:
            hexstring = event['type hex'] + event['value']

        elif event['type'] == 'control change':
            hexstring = event['type hex'] + event['channel'] + event['controller'] + event['value']

        elif event['type'] == 'program change':
            hexstring = event['type hex'] + event['channel'] + event['program']

        elif event['type'] == 'note on' or event['type'] == 'note off':
            hexstring = event['type hex'] + event['channel'] + event['note'] + event['velocity']

        return hexstring

# %% [markdown]
# ### header

# %%
header_str = chpn.header_str
print(header_str)
print()
generate_single(header_str, 'header')
# Out:
# 4d546864000000060001000701e0
#
# @view
# func header {
#         range_check_ptr
#     } () -> (
#         z_len : felt,
#         z : felt*
#     ):
#     alloc_locals
#
#     let (local z) = alloc()
#
#     assert [z+0] = 1568433012465980210040715044389344
#     assert [z+1] = 28
#     let z_len = 2
#
#     return (z_len, z)
# end

# %%
'4d546864000000060001000701e0' == header_str
# Out:
# True

# %% [markdown]
# ### tempo

# %%
tempo_track_str = chpn.track_objs[0].segs_to_hexstring()
generate_single(tempo_track_str, 'tempo')
# Out:
# @view
# func tempo {
#         range_check_ptr
#     } () -> (
#         z_len : felt,
#         z : felt*
#     ):
#     alloc_locals
#
#     let (local z) = alloc()
#
#     assert [z+0] = 136630055383401356149242572565537006397567730891369451453366224442570469166
#     assert [z+1] = 56878481284227153506060204573840070485491661497866299408952274119203762226
#     assert [z+2] = 57218742765747676653729478877327742453910538518085541581276926540566324000
#     assert [z+3] = 119099539352645953382626715204872617300325554821710503471433969358017491828
#     assert [z+4] = 179199866051856678441086820727855504111432963000120495484779184055806752110
#     assert [z+5] = 182386416965249781959371082215309469022151687836411848675778097417160897582
#     assert [z+6] = 86921838934465134510603573218541076527360967275041835275082931199162789898
#     assert [z+7] = 1759974419771673291367073350716576123904882470560914998945739957575377269
#     assert [z+8] = 179239919692890548195358917716852909526288841824410734111800313607068582914
#     assert [z+9] = 5383577935113922528687246149374653598711318964583495258471129969782437660
#     assert [z+10] = 451105125220025342880865559293650232292651125996995473632006373288640991491
#     assert [z+11] = 22311677055006626080114904203650550697811591619838099221023032065655616293
#     assert [z+12] = 22964294172643393264916610625051498064416767246478980703782614645146451793
#     assert [z+13] = 5390783100015670484750057007450518677240276225182750246160288956341750879
#     assert [z+14] = 104637357935294571596128356022728345896094515214403532699743872282113871103
#     assert [z+15] = 143135650314513906508913731699376782911517025412635286352547181316606591756
#     assert [z+16] = 283248236159178824148923397140806940860430263778980857975463556752740463204
#     assert [z+17] = 451105125104578042750353036829349746705069304898194151214496962033154478339
#     assert [z+18] = 21145066664074850253173987345756150522699636014170556813716257059996674475
#     assert [z+19] = 37099070690413978526319608885719138128623123284203276363637360427898568529
#     assert [z+20] = 5383139107700686257923926173619583225470319158118622677257347506534288316
#     assert [z+21] = 366020295580945797105025333169318561412194347514052617548490082759323166975
#     assert [z+22] = 143135624102037684521431365964234106160592936621726613859741897896955544331
#     assert [z+23] = 233424529281697737657970012533587722516346280509006397272184135907645307400
#     assert [z+24] = 451105125182114360107079691704978288940724892433977372619603570981292953859
#     assert [z+25] = 20094384886310155527385410943677105838407560820834456704689610808888072425
#     assert [z+26] = 37099070690153861707506920217891489557590024320850601987330269915072757585
#     assert [z+27] = 5380022174867658298883568701244993154804138216207720746145108734112893884
#     assert [z+28] = 366158330507881608380774028286564101974412489524892660195745615655012935935
#     assert [z+29] = 143135624102018401264900403346019360266495927877133206850326751812797924108
#     assert [z+30] = 4555718675775854490560575107976771996205828557051083836814756706425149716
#     assert [z+31] = 451105125152529073991041308290407144671982375146120639535160974258059825411
#     assert [z+32] = 22308606569830737627117053047754054975115835877038098458568300996852481067
#     assert [z+33] = 37099070690781119635481496615737972734087200500030963125753398160186998609
#     assert [z+34] = 5389212780207077841993812665992411715954687473053140950081922728703757636
#     assert [z+35] = 334023799517228292889817241388123137211272518786485353764145690299453738239
#     assert [z+36] = 143135680465087482553195362116565683221145008609437396093379270974345642765
#     assert [z+37] = 35716887751961918505365126309073976210735661293392628599703934827350144272
#     assert [z+38] = 451105125182297551044125218901275578283078638619061035809694657993737457923
#     assert [z+39] = 22944642261608822140164575064973538570286625444250456092015815274122796424
#     assert [z+40] = 15896905913814202672333845724337222665762764099868158030273332203741262079
#     assert [z+41] = 143135654081928729256700145019403189464770084197866032328831764141939163916
#     assert [z+42] = 94382270898615051006120187542896729184924672185530982856918838006149135880
#     assert [z+43] = 451105125205439065819498938415580561116634532936256087951172843220976488707
#     assert [z+44] = 20872241692534119295496372707768179113906079805161197322212840018977498114
#     assert [z+45] = 37099070690583566787745121612551598130263516004051876335399797222423199569
#     assert [z+46] = 5387194259512666606368038145919116508488490529349886688016161028073262297
#     assert [z+47] = 5390245468445022357052869403467836542432924088927137857570313429157264136
#     assert [z+48] = 451105125117226252096715549095192043732193555328545717511942966528951931139
#     assert [z+49] = 20219971479121576689981520347808333047847772681682042581215878984117717948
#     assert [z+50] = 366020295580945797101960342087594707186342143461405584135377663516238089471
#     assert [z+51] = 143135641276972218304988611988135978678293282116067830443021217257753740044
#     assert [z+52] = 124735504293079937610049794488115426336411848991528996086876620754495874056
#     assert [z+53] = 451105125182114360107079691899219521865645259693624379348540117125762601219
#     assert [z+54] = 20475919945297838017632105645241111647137597330778678148687707315997757490
#     assert [z+55] = 37099070690507444571159516563606567641843425262102662752661151533392265041
#     assert [z+56] = 5380525289531563814974204577092042760488845839392763701890385681406167940
#     assert [z+57] = 51521518050393386437282758611000017877945549179863594023001429966740329727
#     assert [z+58] = 143135640134169303245411221943092486632587263741391394496246908950464758539
#     assert [z+59] = 333597554156882666494404811576046206221845724266166483449812235528787379752
#     assert [z+60] = 451105125080650948692795674655531780242290445400229866131890209813858046211
#     assert [z+61] = 20347140705052192892355819262171564502995245274151779621546855989368301995
#     assert [z+62] = 26497988301869107578558912081788200731592262594158328491568218852658052945
#     assert [z+63] = 5380525264848995455105316532358794829109910825201322919783162971857029965
#     assert [z+64] = 235135577860408855570004327382484585536599059875676016460515392571296126207
#     assert [z+65] = 143135633929402276983004342207117063058635778347150852127263486694726370060
#     assert [z+66] = 283248020479605482842601533708600741509466676888633574582936271527907001640
#     assert [z+67] = 451105125035439658938144686434787312554627381004836318513371253719475114243
#     assert [z+68] = 19607243503735577242411788777014719337756860431110657776749773748634869630
#     assert [z+69] = 72436011985951304738485785832796225712403372259903988828531840983662919505
#     assert [z+70] = 5377598952200401256518432147368454795046858685763450257006932441438554854
#     assert [z+71] = 81419883224689092685042253367357751432096529072698482513988716191082096895
#     assert [z+72] = 143135629923993502128284190561938676443106670946859193428756538080621560586
#     assert [z+73] = 436212179642031421079822676593108085538773162494929152154101287048612138004
#     assert [z+74] = 451105125021100825227187008472509365843160091912413558948624288560147550467
#     assert [z+75] = 24324773955772347694136580376437155168540428968927591894239555680388133305
#     assert [z+76] = 22964294173139140124831673748416313910726698250207795677974540070419496785
#     assert [z+77] = 5393463812058809428113086074322739239168702983482687499168044049141796214
#     assert [z+78] = 312821634739887185583602130101434830883930261349306638669981129438325313791
#     assert [z+79] = 143135675204467262566892968997673138086179596649788925455305426988602295052
#     assert [z+80] = 244918632943770752115364906830584366252947903059203856071882546172244835624
#     assert [z+81] = 451105125239702249016003012393453738005488401439045993657022311236829663491
#     assert [z+82] = 22944644367854655511308414251451979767865325096720696401163918670184674993
#     assert [z+83] = 72436011986682070406721740135627400567128306961635828464055166857780985681
#     assert [z+84] = 5390168703169562450217265846996517107464245882634700075517455981550439653
#     assert [z+85] = 24880777151784085961402822500672392774370896063826685484927231925048972543
#     assert [z+86] = 143135694319567368971338726145781478805245016250038557205929946542739882765
#     assert [z+87] = 442147250141124650185387477128112750834812299546225169130681224376341248284
#     assert [z+88] = 451105125270304726914057340815386119783408930144505458599044396842976497923
#     assert [z+89] = 24509047086863572337562352042748080988631704770607890022525381565668582138
#     assert [z+90] = 192581612391572363857512041688431958934438495998696243228776765016060264273
#     assert [z+91] = 5385745279210130829251137592936237733413267107694071950149066311342427296
#     assert [z+92] = 141409862470995355627457944431503599869616548893449659240077573527110945023
#     assert [z+93] = 143135667941570100673003404198574752039610715398524617495261447690020409603
#     assert [z+94] = 21933511568103170747819757428654829905900663440983625054800597638458412580
#     assert [z+95] = 37099070690810320712754515455071305156960978719037740929968004396420497233
#     assert [z+96] = 5389725965358874163850766230162755369138198502176250249727953762060012686
#     assert [z+97] = 63944661474617722586496237485496896235739935687861825438329789968364939519
#     assert [z+98] = 143135646631071238201925167090015908843956948455329122844143691136431620876
#     assert [z+99] = 349380446134766001480947924208761406447047871057129524369784355275089855008
#     assert [z+100] = 451105125182298228971112640682916829208848236385818691999063732455687016707
#     assert [z+101] = 21812245727994327168318743221115439598288746769207059400767413110929399888
#     assert [z+102] = 15896905913499970763300959249950362474966308710436503129363820467548913489
#     assert [z+103] = 5390257797368314049614498881342361246392458962627302924282559073169378428
#     assert [z+104] = 76257376957291974120412314983124299854471959385930891078870600976947683583
#     assert [z+105] = 143135655974638207554532294631120623085243840637415097646689027661688275724
#     assert [z+106] = 383426868703270521713661930132724976374351398324748738779753269074041517944
#     assert [z+107] = 451105125174639110300849345086062416143184931871836754629983769265600155907
#     assert [z+108] = 21689416210978788851768741452914664006878195159788328807821594759508308773
#     assert [z+109] = 22964294172643393264916610625051498064416767246478980703782614645146451793
#     assert [z+110] = 5390783100015670484862569249498800909547016020702429763453678021364616671
#     assert [z+111] = 62122600439067074327857745885115489846478713887392489319984106728435291391
#     assert [z+112] = 143135685882506289146113179781148333469715632465780989134771054426278920974
#     assert [z+113] = 240712773423908593254038882440443339809013076141098508514681328901959204392
#     assert [z+114] = 451105125395078820995483750983375242609495734581716212161812222850702987523
#     assert [z+115] = 25881551011741544284152238382747076283370064708800416353042504167514453051
#     assert [z+116] = 37099070692463944308851585743514169341004461037477044459434953586670632785
#     assert [z+117] = 5436428083323123998766272267503911434396746479339369824916435442059121810
#     assert [z+118] = 387084425431365292698202486739472729688888927683297000059991541859940111615
#     assert [z+119] = 143135905166178121784891314722375895952969538074754738941194530799087584022
#     assert [z+120] = 23945416059546428264607553734031502695576653230086526405151861714688
#     assert [z+121] = 56
#     let z_len = 122
#
#     return (z_len, z)
# end

# %%
'...' == tempo_track_str
# Out:
# True

# %% [markdown]
# ### music track one

# %%
def generate_single_note_manipulable(segs, name):
    i = 0
    ret = []
    ret.append('    local shift_amount_m256 = shift_amount * 256')
    for event in segs:
        if 'note' in event['type']:
            hexstr = Track.event_to_hexstring(event)
            hexstr_len = len(hexstr)
            ret.append( f'    assert [z+{i}] = {int(hexstr, 16)} + shift_amount_m256' )
            ret.append( f'    assert [z+{i+1}] = {hexstr_len}' )
            i += 2
        else:
            hexstr = Track.event_to_hexstring(event)
            s = hexstr
            while( len(s)>62 ):
                felt_hex = s[0:62]
                ret.append( f'    assert [z+{i}] = {int(felt_hex, 16)}' )
                ret.append( f'    assert [z+{i+1}] = 62' )
                s = s[62:]
                i += 2
            felt_hex = s
            last_length = len(felt_hex)
            ret.append( f'    assert [z+{i}] = {int(felt_hex, 16)}' )
            ret.append( f'    assert [z+{i+1}] = {last_length}' )
            i += 2
    for line in ret:
        print(line)

# %%
len(chpn_og.track_objs[1].segs)
# Out:
# 832

# %%
generate_single_note_manipulable(chpn_og.track_objs[1].segs[0:416], '')
# Out:
#     local shift_amount_m256 = shift_amount * 256
#     assert [z+0] = 1297379947
#     assert [z+1] = 8
#     assert [z+2] = 1305
#     assert [z+3] = 8
#     assert [z+4] = 0
#     assert [z+5] = 2
#     assert [z+6] = 5172255634965538127576624586516596
#     assert [z+7] = 28
#     assert [z+8] = 0
#     assert [z+9] = 2
#     assert [z+10] = 49152
#     assert [z+11] = 4
#     assert [z+12] = 0
#     assert [z+13] = 2
#     assert [z+14] = 11536228
#     assert [z+15] = 6
#     assert [z+16] = 0
#     assert [z+17] = 2
#     assert [z+18] = 2624
#     assert [z+19] = 4
#     assert [z+20] = 0
#     assert [z+21] = 2
#     assert [z+22] = 23423
#     assert [z+23] = 4
#     assert [z+24] = 0
#     assert [z+25] = 2
#     assert [z+26] = 450553776345030037904731835580182146853641395011731700227710265710693791032
#     assert [z+27] = 62
#     assert [z+28] = 926233139
#     assert [z+29] = 8
#     assert [z+30] = 33056
#     assert [z+31] = 4
#     assert [z+32] = 9452593 + shift_amount_m256
#     assert [z+33] = 6
#     assert [z+34] = 80
#     assert [z+35] = 2
#     assert [z+36] = 15360 + shift_amount_m256
#     assert [z+37] = 4
#     assert [z+38] = 0
#     assert [z+39] = 2
#     assert [z+40] = 17205 + shift_amount_m256
#     assert [z+41] = 4
#     assert [z+42] = 0
#     assert [z+43] = 2
#     assert [z+44] = 16417 + shift_amount_m256
#     assert [z+45] = 4
#     assert [z+46] = 80
#     assert [z+47] = 2
#     assert [z+48] = 16384 + shift_amount_m256
#     assert [z+49] = 4
#     assert [z+50] = 0
#     assert [z+51] = 2
#     assert [z+52] = 15403 + shift_amount_m256
#     assert [z+53] = 4
#     assert [z+54] = 80
#     assert [z+55] = 2
#     assert [z+56] = 15360 + shift_amount_m256
#     assert [z+57] = 4
#     assert [z+58] = 0
#     assert [z+59] = 2
#     assert [z+60] = 17152 + shift_amount_m256
#     assert [z+61] = 4
#     assert [z+62] = 0
#     assert [z+63] = 2
#     assert [z+64] = 17707 + shift_amount_m256
#     assert [z+65] = 4
#     assert [z+66] = 80
#     assert [z+67] = 2
#     assert [z+68] = 17664 + shift_amount_m256
#     assert [z+69] = 4
#     assert [z+70] = 33056
#     assert [z+71] = 4
#     assert [z+72] = 15923 + shift_amount_m256
#     assert [z+73] = 4
#     assert [z+74] = 80
#     assert [z+75] = 2
#     assert [z+76] = 15872 + shift_amount_m256
#     assert [z+77] = 4
#     assert [z+78] = 0
#     assert [z+79] = 2
#     assert [z+80] = 17211 + shift_amount_m256
#     assert [z+81] = 4
#     assert [z+82] = 0
#     assert [z+83] = 2
#     assert [z+84] = 16680 + shift_amount_m256
#     assert [z+85] = 4
#     assert [z+86] = 80
#     assert [z+87] = 2
#     assert [z+88] = 16640 + shift_amount_m256
#     assert [z+89] = 4
#     assert [z+90] = 0
#     assert [z+91] = 2
#     assert [z+92] = 15919 + shift_amount_m256
#     assert [z+93] = 4
#     assert [z+94] = 80
#     assert [z+95] = 2
#     assert [z+96] = 15872 + shift_amount_m256
#     assert [z+97] = 4
#     assert [z+98] = 0
#     assert [z+99] = 2
#     assert [z+100] = 17152 + shift_amount_m256
#     assert [z+101] = 4
#     assert [z+102] = 0
#     assert [z+103] = 2
#     assert [z+104] = 17709 + shift_amount_m256
#     assert [z+105] = 4
#     assert [z+106] = 80
#     assert [z+107] = 2
#     assert [z+108] = 17664 + shift_amount_m256
#     assert [z+109] = 4
#     assert [z+110] = 33056
#     assert [z+111] = 4
#     assert [z+112] = 15419 + shift_amount_m256
#     assert [z+113] = 4
#     assert [z+114] = 80
#     assert [z+115] = 2
#     assert [z+116] = 15360 + shift_amount_m256
#     assert [z+117] = 4
#     assert [z+118] = 0
#     assert [z+119] = 2
#     assert [z+120] = 17219 + shift_amount_m256
#     assert [z+121] = 4
#     assert [z+122] = 0
#     assert [z+123] = 2
#     assert [z+124] = 16430 + shift_amount_m256
#     assert [z+125] = 4
#     assert [z+126] = 80
#     assert [z+127] = 2
#     assert [z+128] = 16384 + shift_amount_m256
#     assert [z+129] = 4
#     assert [z+130] = 0
#     assert [z+131] = 2
#     assert [z+132] = 15421 + shift_amount_m256
#     assert [z+133] = 4
#     assert [z+134] = 80
#     assert [z+135] = 2
#     assert [z+136] = 15360 + shift_amount_m256
#     assert [z+137] = 4
#     assert [z+138] = 0
#     assert [z+139] = 2
#     assert [z+140] = 17152 + shift_amount_m256
#     assert [z+141] = 4
#     assert [z+142] = 0
#     assert [z+143] = 2
#     assert [z+144] = 17729 + shift_amount_m256
#     assert [z+145] = 4
#     assert [z+146] = 80
#     assert [z+147] = 2
#     assert [z+148] = 17664 + shift_amount_m256
#     assert [z+149] = 4
#     assert [z+150] = 33056
#     assert [z+151] = 4
#     assert [z+152] = 16454 + shift_amount_m256
#     assert [z+153] = 4
#     assert [z+154] = 80
#     assert [z+155] = 2
#     assert [z+156] = 16384 + shift_amount_m256
#     assert [z+157] = 4
#     assert [z+158] = 0
#     assert [z+159] = 2
#     assert [z+160] = 18251 + shift_amount_m256
#     assert [z+161] = 4
#     assert [z+162] = 0
#     assert [z+163] = 2
#     assert [z+164] = 17204 + shift_amount_m256
#     assert [z+165] = 4
#     assert [z+166] = 80
#     assert [z+167] = 2
#     assert [z+168] = 17152 + shift_amount_m256
#     assert [z+169] = 4
#     assert [z+170] = 0
#     assert [z+171] = 2
#     assert [z+172] = 16454 + shift_amount_m256
#     assert [z+173] = 4
#     assert [z+174] = 80
#     assert [z+175] = 2
#     assert [z+176] = 16384 + shift_amount_m256
#     assert [z+177] = 4
#     assert [z+178] = 0
#     assert [z+179] = 2
#     assert [z+180] = 18176 + shift_amount_m256
#     assert [z+181] = 4
#     assert [z+182] = 0
#     assert [z+183] = 2
#     assert [z+184] = 18510 + shift_amount_m256
#     assert [z+185] = 4
#     assert [z+186] = 80
#     assert [z+187] = 2
#     assert [z+188] = 18432 + shift_amount_m256
#     assert [z+189] = 4
#     assert [z+190] = 80
#     assert [z+191] = 2
#     assert [z+192] = 16463 + shift_amount_m256
#     assert [z+193] = 4
#     assert [z+194] = 80
#     assert [z+195] = 2
#     assert [z+196] = 17739 + shift_amount_m256
#     assert [z+197] = 4
#     assert [z+198] = 80
#     assert [z+199] = 2
#     assert [z+200] = 17664 + shift_amount_m256
#     assert [z+201] = 4
#     assert [z+202] = 0
#     assert [z+203] = 2
#     assert [z+204] = 19536 + shift_amount_m256
#     assert [z+205] = 4
#     assert [z+206] = 0
#     assert [z+207] = 2
#     assert [z+208] = 18490 + shift_amount_m256
#     assert [z+209] = 4
#     assert [z+210] = 80
#     assert [z+211] = 2
#     assert [z+212] = 18432 + shift_amount_m256
#     assert [z+213] = 4
#     assert [z+214] = 0
#     assert [z+215] = 2
#     assert [z+216] = 17739 + shift_amount_m256
#     assert [z+217] = 4
#     assert [z+218] = 80
#     assert [z+219] = 2
#     assert [z+220] = 17664 + shift_amount_m256
#     assert [z+221] = 4
#     assert [z+222] = 0
#     assert [z+223] = 2
#     assert [z+224] = 19456 + shift_amount_m256
#     assert [z+225] = 4
#     assert [z+226] = 0
#     assert [z+227] = 2
#     assert [z+228] = 16384 + shift_amount_m256
#     assert [z+229] = 4
#     assert [z+230] = 0
#     assert [z+231] = 2
#     assert [z+232] = 15952 + shift_amount_m256
#     assert [z+233] = 4
#     assert [z+234] = 0
#     assert [z+235] = 2
#     assert [z+236] = 19024 + shift_amount_m256
#     assert [z+237] = 4
#     assert [z+238] = 80
#     assert [z+239] = 2
#     assert [z+240] = 18944 + shift_amount_m256
#     assert [z+241] = 4
#     assert [z+242] = 0
#     assert [z+243] = 2
#     assert [z+244] = 15872 + shift_amount_m256
#     assert [z+245] = 4
#     assert [z+246] = 80
#     assert [z+247] = 2
#     assert [z+248] = 16470 + shift_amount_m256
#     assert [z+249] = 4
#     assert [z+250] = 80
#     assert [z+251] = 2
#     assert [z+252] = 17746 + shift_amount_m256
#     assert [z+253] = 4
#     assert [z+254] = 80
#     assert [z+255] = 2
#     assert [z+256] = 17664 + shift_amount_m256
#     assert [z+257] = 4
#     assert [z+258] = 0
#     assert [z+259] = 2
#     assert [z+260] = 19544 + shift_amount_m256
#     assert [z+261] = 4
#     assert [z+262] = 0
#     assert [z+263] = 2
#     assert [z+264] = 18493 + shift_amount_m256
#     assert [z+265] = 4
#     assert [z+266] = 80
#     assert [z+267] = 2
#     assert [z+268] = 18432 + shift_amount_m256
#     assert [z+269] = 4
#     assert [z+270] = 0
#     assert [z+271] = 2
#     assert [z+272] = 17746 + shift_amount_m256
#     assert [z+273] = 4
#     assert [z+274] = 80
#     assert [z+275] = 2
#     assert [z+276] = 17664 + shift_amount_m256
#     assert [z+277] = 4
#     assert [z+278] = 0
#     assert [z+279] = 2
#     assert [z+280] = 19456 + shift_amount_m256
#     assert [z+281] = 4
#     assert [z+282] = 0
#     assert [z+283] = 2
#     assert [z+284] = 16384 + shift_amount_m256
#     assert [z+285] = 4
#     assert [z+286] = 0
#     assert [z+287] = 2
#     assert [z+288] = 15956 + shift_amount_m256
#     assert [z+289] = 4
#     assert [z+290] = 0
#     assert [z+291] = 2
#     assert [z+292] = 19028 + shift_amount_m256
#     assert [z+293] = 4
#     assert [z+294] = 80
#     assert [z+295] = 2
#     assert [z+296] = 18944 + shift_amount_m256
#     assert [z+297] = 4
#     assert [z+298] = 0
#     assert [z+299] = 2
#     assert [z+300] = 15872 + shift_amount_m256
#     assert [z+301] = 4
#     assert [z+302] = 80
#     assert [z+303] = 2
#     assert [z+304] = 16470 + shift_amount_m256
#     assert [z+305] = 4
#     assert [z+306] = 80
#     assert [z+307] = 2
#     assert [z+308] = 17234 + shift_amount_m256
#     assert [z+309] = 4
#     assert [z+310] = 80
#     assert [z+311] = 2
#     assert [z+312] = 17152 + shift_amount_m256
#     assert [z+313] = 4
#     assert [z+314] = 0
#     assert [z+315] = 2
#     assert [z+316] = 19544 + shift_amount_m256
#     assert [z+317] = 4
#     assert [z+318] = 0
#     assert [z+319] = 2
#     assert [z+320] = 18231 + shift_amount_m256
#     assert [z+321] = 4
#     assert [z+322] = 80
#     assert [z+323] = 2
#     assert [z+324] = 18176 + shift_amount_m256
#     assert [z+325] = 4
#     assert [z+326] = 0
#     assert [z+327] = 2
#     assert [z+328] = 17226 + shift_amount_m256
#     assert [z+329] = 4
#     assert [z+330] = 80
#     assert [z+331] = 2
#     assert [z+332] = 17152 + shift_amount_m256
#     assert [z+333] = 4
#     assert [z+334] = 0
#     assert [z+335] = 2
#     assert [z+336] = 19456 + shift_amount_m256
#     assert [z+337] = 4
#     assert [z+338] = 0
#     assert [z+339] = 2
#     assert [z+340] = 16384 + shift_amount_m256
#     assert [z+341] = 4
#     assert [z+342] = 0
#     assert [z+343] = 2
#     assert [z+344] = 15939 + shift_amount_m256
#     assert [z+345] = 4
#     assert [z+346] = 0
#     assert [z+347] = 2
#     assert [z+348] = 19026 + shift_amount_m256
#     assert [z+349] = 4
#     assert [z+350] = 80
#     assert [z+351] = 2
#     assert [z+352] = 18944 + shift_amount_m256
#     assert [z+353] = 4
#     assert [z+354] = 0
#     assert [z+355] = 2
#     assert [z+356] = 15872 + shift_amount_m256
#     assert [z+357] = 4
#     assert [z+358] = 33056
#     assert [z+359] = 4
#     assert [z+360] = 15928 + shift_amount_m256
#     assert [z+361] = 4
#     assert [z+362] = 80
#     assert [z+363] = 2
#     assert [z+364] = 15872 + shift_amount_m256
#     assert [z+365] = 4
#     assert [z+366] = 0
#     assert [z+367] = 2
#     assert [z+368] = 18235 + shift_amount_m256
#     assert [z+369] = 4
#     assert [z+370] = 0
#     assert [z+371] = 2
#     assert [z+372] = 16681 + shift_amount_m256
#     assert [z+373] = 4
#     assert [z+374] = 80
#     assert [z+375] = 2
#     assert [z+376] = 16640 + shift_amount_m256
#     assert [z+377] = 4
#     assert [z+378] = 0
#     assert [z+379] = 2
#     assert [z+380] = 15922 + shift_amount_m256
#     assert [z+381] = 4
#     assert [z+382] = 80
#     assert [z+383] = 2
#     assert [z+384] = 15872 + shift_amount_m256
#     assert [z+385] = 4
#     assert [z+386] = 0
#     assert [z+387] = 2
#     assert [z+388] = 18176 + shift_amount_m256
#     assert [z+389] = 4
#     assert [z+390] = 0
#     assert [z+391] = 2
#     assert [z+392] = 17711 + shift_amount_m256
#     assert [z+393] = 4
#     assert [z+394] = 80
#     assert [z+395] = 2
#     assert [z+396] = 17664 + shift_amount_m256
#     assert [z+397] = 4
#     assert [z+398] = 33056
#     assert [z+399] = 4
#     assert [z+400] = 15413 + shift_amount_m256
#     assert [z+401] = 4
#     assert [z+402] = 80
#     assert [z+403] = 2
#     assert [z+404] = 15360 + shift_amount_m256
#     assert [z+405] = 4
#     assert [z+406] = 0
#     assert [z+407] = 2
#     assert [z+408] = 17212 + shift_amount_m256
#     assert [z+409] = 4
#     assert [z+410] = 0
#     assert [z+411] = 2
#     assert [z+412] = 16420 + shift_amount_m256
#     assert [z+413] = 4
#     assert [z+414] = 80
#     assert [z+415] = 2
#     assert [z+416] = 16384 + shift_amount_m256
#     assert [z+417] = 4
#     assert [z+418] = 0
#     assert [z+419] = 2
#     assert [z+420] = 15411 + shift_amount_m256
#     assert [z+421] = 4
#     assert [z+422] = 80
#     assert [z+423] = 2
#     assert [z+424] = 15360 + shift_amount_m256
#     assert [z+425] = 4
#     assert [z+426] = 0
#     assert [z+427] = 2
#     assert [z+428] = 17152 + shift_amount_m256
#     assert [z+429] = 4
#     assert [z+430] = 0
#     assert [z+431] = 2
#     assert [z+432] = 17709 + shift_amount_m256
#     assert [z+433] = 4
#     assert [z+434] = 80
#     assert [z+435] = 2
#     assert [z+436] = 17664 + shift_amount_m256
#     assert [z+437] = 4
#     assert [z+438] = 33056
#     assert [z+439] = 4
#     assert [z+440] = 15930 + shift_amount_m256
#     assert [z+441] = 4
#     assert [z+442] = 80
#     assert [z+443] = 2
#     assert [z+444] = 15872 + shift_amount_m256
#     assert [z+445] = 4
#     assert [z+446] = 0
#     assert [z+447] = 2
#     assert [z+448] = 17213 + shift_amount_m256
#     assert [z+449] = 4
#     assert [z+450] = 0
#     assert [z+451] = 2
#     assert [z+452] = 16685 + shift_amount_m256
#     assert [z+453] = 4
#     assert [z+454] = 80
#     assert [z+455] = 2
#     assert [z+456] = 16640 + shift_amount_m256
#     assert [z+457] = 4
#     assert [z+458] = 0
#     assert [z+459] = 2
#     assert [z+460] = 15930 + shift_amount_m256
#     assert [z+461] = 4
#     assert [z+462] = 80
#     assert [z+463] = 2
#     assert [z+464] = 15872 + shift_amount_m256
#     assert [z+465] = 4
#     assert [z+466] = 0
#     assert [z+467] = 2
#     assert [z+468] = 17152 + shift_amount_m256
#     assert [z+469] = 4
#     assert [z+470] = 0
#     assert [z+471] = 2
#     assert [z+472] = 17715 + shift_amount_m256
#     assert [z+473] = 4
#     assert [z+474] = 80
#     assert [z+475] = 2
#     assert [z+476] = 17664 + shift_amount_m256
#     assert [z+477] = 4
#     assert [z+478] = 33056
#     assert [z+479] = 4
#     assert [z+480] = 15424 + shift_amount_m256
#     assert [z+481] = 4
#     assert [z+482] = 80
#     assert [z+483] = 2
#     assert [z+484] = 15360 + shift_amount_m256
#     assert [z+485] = 4
#     assert [z+486] = 0
#     assert [z+487] = 2
#     assert [z+488] = 17224 + shift_amount_m256
#     assert [z+489] = 4
#     assert [z+490] = 0
#     assert [z+491] = 2
#     assert [z+492] = 16433 + shift_amount_m256
#     assert [z+493] = 4
#     assert [z+494] = 80
#     assert [z+495] = 2
#     assert [z+496] = 16384 + shift_amount_m256
#     assert [z+497] = 4
#     assert [z+498] = 0
#     assert [z+499] = 2
#     assert [z+500] = 15426 + shift_amount_m256
#     assert [z+501] = 4
#     assert [z+502] = 80
#     assert [z+503] = 2
#     assert [z+504] = 15360 + shift_amount_m256
#     assert [z+505] = 4
#     assert [z+506] = 0
#     assert [z+507] = 2
#     assert [z+508] = 17152 + shift_amount_m256
#     assert [z+509] = 4
#     assert [z+510] = 0
#     assert [z+511] = 2
#     assert [z+512] = 17726 + shift_amount_m256
#     assert [z+513] = 4
#     assert [z+514] = 80
#     assert [z+515] = 2
#     assert [z+516] = 17664 + shift_amount_m256
#     assert [z+517] = 4
#     assert [z+518] = 33056
#     assert [z+519] = 4
#     assert [z+520] = 16454 + shift_amount_m256
#     assert [z+521] = 4
#     assert [z+522] = 80
#     assert [z+523] = 2
#     assert [z+524] = 16384 + shift_amount_m256
#     assert [z+525] = 4
#     assert [z+526] = 0
#     assert [z+527] = 2
#     assert [z+528] = 18251 + shift_amount_m256
#     assert [z+529] = 4
#     assert [z+530] = 0
#     assert [z+531] = 2
#     assert [z+532] = 17204 + shift_amount_m256
#     assert [z+533] = 4
#     assert [z+534] = 80
#     assert [z+535] = 2
#     assert [z+536] = 17152 + shift_amount_m256
#     assert [z+537] = 4
#     assert [z+538] = 0
#     assert [z+539] = 2
#     assert [z+540] = 16454 + shift_amount_m256
#     assert [z+541] = 4
#     assert [z+542] = 80
#     assert [z+543] = 2
#     assert [z+544] = 16384 + shift_amount_m256
#     assert [z+545] = 4
#     assert [z+546] = 0
#     assert [z+547] = 2
#     assert [z+548] = 18176 + shift_amount_m256
#     assert [z+549] = 4
#     assert [z+550] = 0
#     assert [z+551] = 2
#     assert [z+552] = 18501 + shift_amount_m256
#     assert [z+553] = 4
#     assert [z+554] = 80
#     assert [z+555] = 2
#     assert [z+556] = 18432 + shift_amount_m256
#     assert [z+557] = 4
#     assert [z+558] = 80
#     assert [z+559] = 2
#     assert [z+560] = 15685 + shift_amount_m256
#     assert [z+561] = 4
#     assert [z+562] = 80
#     assert [z+563] = 2
#     assert [z+564] = 16715 + shift_amount_m256
#     assert [z+565] = 4
#     assert [z+566] = 80
#     assert [z+567] = 2
#     assert [z+568] = 16640 + shift_amount_m256
#     assert [z+569] = 4
#     assert [z+570] = 0
#     assert [z+571] = 2
#     assert [z+572] = 18768 + shift_amount_m256
#     assert [z+573] = 4
#     assert [z+574] = 0
#     assert [z+575] = 2
#     assert [z+576] = 17719 + shift_amount_m256
#     assert [z+577] = 4
#     assert [z+578] = 80
#     assert [z+579] = 2
#     assert [z+580] = 17664 + shift_amount_m256
#     assert [z+581] = 4
#     assert [z+582] = 0
#     assert [z+583] = 2
#     assert [z+584] = 16715 + shift_amount_m256
#     assert [z+585] = 4
#     assert [z+586] = 80
#     assert [z+587] = 2
#     assert [z+588] = 16640 + shift_amount_m256
#     assert [z+589] = 4
#     assert [z+590] = 0
#     assert [z+591] = 2
#     assert [z+592] = 18688 + shift_amount_m256
#     assert [z+593] = 4
#     assert [z+594] = 0
#     assert [z+595] = 2
#     assert [z+596] = 15616 + shift_amount_m256
#     assert [z+597] = 4
#     assert [z+598] = 0
#     assert [z+599] = 2
#     assert [z+600] = 15930 + shift_amount_m256
#     assert [z+601] = 4
#     assert [z+602] = 0
#     assert [z+603] = 2
#     assert [z+604] = 19017 + shift_amount_m256
#     assert [z+605] = 4
#     assert [z+606] = 80
#     assert [z+607] = 2
#     assert [z+608] = 18944 + shift_amount_m256
#     assert [z+609] = 4
#     assert [z+610] = 0
#     assert [z+611] = 2
#     assert [z+612] = 15872 + shift_amount_m256
#     assert [z+613] = 4
#     assert [z+614] = 80
#     assert [z+615] = 2
#     assert [z+616] = 16200 + shift_amount_m256
#     assert [z+617] = 4
#     assert [z+618] = 80
#     assert [z+619] = 2
#     assert [z+620] = 17230 + shift_amount_m256
#     assert [z+621] = 4
#     assert [z+622] = 80
#     assert [z+623] = 2
#     assert [z+624] = 17152 + shift_amount_m256
#     assert [z+625] = 4
#     assert [z+626] = 0
#     assert [z+627] = 2
#     assert [z+628] = 19282 + shift_amount_m256
#     assert [z+629] = 4
#     assert [z+630] = 0
#     assert [z+631] = 2
#     assert [z+632] = 18489 + shift_amount_m256
#     assert [z+633] = 4
#     assert [z+634] = 80
#     assert [z+635] = 2
#     assert [z+636] = 18432 + shift_amount_m256
#     assert [z+637] = 4
#     assert [z+638] = 0
#     assert [z+639] = 2
#     assert [z+640] = 17230 + shift_amount_m256
#     assert [z+641] = 4
#     assert [z+642] = 80
#     assert [z+643] = 2
#     assert [z+644] = 17152 + shift_amount_m256
#     assert [z+645] = 4
#     assert [z+646] = 0
#     assert [z+647] = 2
#     assert [z+648] = 19200 + shift_amount_m256
#     assert [z+649] = 4
#     assert [z+650] = 0
#     assert [z+651] = 2
#     assert [z+652] = 16128 + shift_amount_m256
#     assert [z+653] = 4
#     assert [z+654] = 0
#     assert [z+655] = 2
#     assert [z+656] = 19534 + shift_amount_m256
#     assert [z+657] = 4
#     assert [z+658] = 0
#     assert [z+659] = 2
#     assert [z+660] = 16445 + shift_amount_m256
#     assert [z+661] = 4
#     assert [z+662] = 80
#     assert [z+663] = 2
#     assert [z+664] = 16384 + shift_amount_m256
#     assert [z+665] = 4
#     assert [z+666] = 0
#     assert [z+667] = 2
#     assert [z+668] = 19456 + shift_amount_m256
#     assert [z+669] = 4
#     assert [z+670] = 80
#     assert [z+671] = 2
#     assert [z+672] = 17227 + shift_amount_m256
#     assert [z+673] = 4
#     assert [z+674] = 80
#     assert [z+675] = 2
#     assert [z+676] = 17744 + shift_amount_m256
#     assert [z+677] = 4
#     assert [z+678] = 80
#     assert [z+679] = 2
#     assert [z+680] = 17664 + shift_amount_m256
#     assert [z+681] = 4
#     assert [z+682] = 0
#     assert [z+683] = 2
#     assert [z+684] = 20310 + shift_amount_m256
#     assert [z+685] = 4
#     assert [z+686] = 0
#     assert [z+687] = 2
#     assert [z+688] = 18492 + shift_amount_m256
#     assert [z+689] = 4
#     assert [z+690] = 80
#     assert [z+691] = 2
#     assert [z+692] = 18432 + shift_amount_m256
#     assert [z+693] = 4
#     assert [z+694] = 0
#     assert [z+695] = 2
#     assert [z+696] = 17739 + shift_amount_m256
#     assert [z+697] = 4
#     assert [z+698] = 80
#     assert [z+699] = 2
#     assert [z+700] = 17664 + shift_amount_m256
#     assert [z+701] = 4
#     assert [z+702] = 0
#     assert [z+703] = 2
#     assert [z+704] = 20224 + shift_amount_m256
#     assert [z+705] = 4
#     assert [z+706] = 0
#     assert [z+707] = 2
#     assert [z+708] = 17152 + shift_amount_m256
#     assert [z+709] = 4
#     assert [z+710] = 0
#     assert [z+711] = 2
#     assert [z+712] = 16703 + shift_amount_m256
#     assert [z+713] = 4
#     assert [z+714] = 0
#     assert [z+715] = 2
#     assert [z+716] = 19793 + shift_amount_m256
#     assert [z+717] = 4
#     assert [z+718] = 80
#     assert [z+719] = 2
#     assert [z+720] = 19712 + shift_amount_m256
#     assert [z+721] = 4
#     assert [z+722] = 0
#     assert [z+723] = 2
#     assert [z+724] = 16640 + shift_amount_m256
#     assert [z+725] = 4
#     assert [z+726] = 80
#     assert [z+727] = 2
#     assert [z+728] = 16219 + shift_amount_m256
#     assert [z+729] = 4
#     assert [z+730] = 80
#     assert [z+731] = 2
#     assert [z+732] = 17234 + shift_amount_m256
#     assert [z+733] = 4
#     assert [z+734] = 80
#     assert [z+735] = 2
#     assert [z+736] = 17152 + shift_amount_m256
#     assert [z+737] = 4
#     assert [z+738] = 0
#     assert [z+739] = 2
#     assert [z+740] = 19291 + shift_amount_m256
#     assert [z+741] = 4
#     assert [z+742] = 0
#     assert [z+743] = 2
#     assert [z+744] = 18493 + shift_amount_m256
#     assert [z+745] = 4
#     assert [z+746] = 80
#     assert [z+747] = 2
#     assert [z+748] = 18432 + shift_amount_m256
#     assert [z+749] = 4
#     assert [z+750] = 0
#     assert [z+751] = 2
#     assert [z+752] = 17231 + shift_amount_m256
#     assert [z+753] = 4
#     assert [z+754] = 80
#     assert [z+755] = 2
#     assert [z+756] = 17152 + shift_amount_m256
#     assert [z+757] = 4
#     assert [z+758] = 0
#     assert [z+759] = 2
#     assert [z+760] = 19200 + shift_amount_m256
#     assert [z+761] = 4
#     assert [z+762] = 0
#     assert [z+763] = 2
#     assert [z+764] = 16128 + shift_amount_m256
#     assert [z+765] = 4
#     assert [z+766] = 0
#     assert [z+767] = 2
#     assert [z+768] = 16450 + shift_amount_m256
#     assert [z+769] = 4
#     assert [z+770] = 0
#     assert [z+771] = 2
#     assert [z+772] = 19542 + shift_amount_m256
#     assert [z+773] = 4
#     assert [z+774] = 80
#     assert [z+775] = 2
#     assert [z+776] = 19456 + shift_amount_m256
#     assert [z+777] = 4
#     assert [z+778] = 0
#     assert [z+779] = 2
#     assert [z+780] = 16384 + shift_amount_m256
#     assert [z+781] = 4
#     assert [z+782] = 80
#     assert [z+783] = 2
#     assert [z+784] = 16476 + shift_amount_m256
#     assert [z+785] = 4
#     assert [z+786] = 80
#     assert [z+787] = 2
#     assert [z+788] = 17750 + shift_amount_m256
#     assert [z+789] = 4
#     assert [z+790] = 80
#     assert [z+791] = 2
#     assert [z+792] = 17664 + shift_amount_m256
#     assert [z+793] = 4
#     assert [z+794] = 0
#     assert [z+795] = 2
#     assert [z+796] = 19552 + shift_amount_m256
#     assert [z+797] = 4
#     assert [z+798] = 0
#     assert [z+799] = 2
#     assert [z+800] = 18495 + shift_amount_m256
#     assert [z+801] = 4
#     assert [z+802] = 80
#     assert [z+803] = 2
#     assert [z+804] = 18432 + shift_amount_m256
#     assert [z+805] = 4
#     assert [z+806] = 0
#     assert [z+807] = 2
#     assert [z+808] = 17746 + shift_amount_m256
#     assert [z+809] = 4
#     assert [z+810] = 80
#     assert [z+811] = 2
#     assert [z+812] = 17664 + shift_amount_m256
#     assert [z+813] = 4
#     assert [z+814] = 0
#     assert [z+815] = 2
#     assert [z+816] = 19456 + shift_amount_m256
#     assert [z+817] = 4
#     assert [z+818] = 0
#     assert [z+819] = 2
#     assert [z+820] = 16384 + shift_amount_m256
#     assert [z+821] = 4
#     assert [z+822] = 0
#     assert [z+823] = 2
#     assert [z+824] = 16725 + shift_amount_m256
#     assert [z+825] = 4
#     assert [z+826] = 0
#     assert [z+827] = 2
#     assert [z+828] = 19797 + shift_amount_m256
#     assert [z+829] = 4
#     assert [z+830] = 80
#     assert [z+831] = 2
#     assert [z+832] = 19712 + shift_amount_m256
#     assert [z+833] = 4

# %%
generate_single_note_manipulable(chpn_og.track_objs[1].segs[416:], '')
# Out:
#     local shift_amount_m256 = shift_amount * 256
#     assert [z+0] = 0
#     assert [z+1] = 2
#     assert [z+2] = 16640 + shift_amount_m256
#     assert [z+3] = 4
#     assert [z+4] = 0
#     assert [z+5] = 2
#     assert [z+6] = 16993 + shift_amount_m256
#     assert [z+7] = 4
#     assert [z+8] = 120
#     assert [z+9] = 2
#     assert [z+10] = 18257 + shift_amount_m256
#     assert [z+11] = 4
#     assert [z+12] = 120
#     assert [z+13] = 2
#     assert [z+14] = 18176 + shift_amount_m256
#     assert [z+15] = 4
#     assert [z+16] = 0
#     assert [z+17] = 2
#     assert [z+18] = 20057 + shift_amount_m256
#     assert [z+19] = 4
#     assert [z+20] = 0
#     assert [z+21] = 2
#     assert [z+22] = 19014 + shift_amount_m256
#     assert [z+23] = 4
#     assert [z+24] = 80
#     assert [z+25] = 2
#     assert [z+26] = 18944 + shift_amount_m256
#     assert [z+27] = 4
#     assert [z+28] = 0
#     assert [z+29] = 2
#     assert [z+30] = 18260 + shift_amount_m256
#     assert [z+31] = 4
#     assert [z+32] = 80
#     assert [z+33] = 2
#     assert [z+34] = 18176 + shift_amount_m256
#     assert [z+35] = 4
#     assert [z+36] = 0
#     assert [z+37] = 2
#     assert [z+38] = 19968 + shift_amount_m256
#     assert [z+39] = 4
#     assert [z+40] = 0
#     assert [z+41] = 2
#     assert [z+42] = 16896 + shift_amount_m256
#     assert [z+43] = 4
#     assert [z+44] = 0
#     assert [z+45] = 2
#     assert [z+46] = 17214 + shift_amount_m256
#     assert [z+47] = 4
#     assert [z+48] = 0
#     assert [z+49] = 2
#     assert [z+50] = 20305 + shift_amount_m256
#     assert [z+51] = 4
#     assert [z+52] = 80
#     assert [z+53] = 2
#     assert [z+54] = 20224 + shift_amount_m256
#     assert [z+55] = 4
#     assert [z+56] = 0
#     assert [z+57] = 2
#     assert [z+58] = 17152 + shift_amount_m256
#     assert [z+59] = 4
#     assert [z+60] = 0
#     assert [z+61] = 2
#     assert [z+62] = 17507 + shift_amount_m256
#     assert [z+63] = 4
#     assert [z+64] = 120
#     assert [z+65] = 2
#     assert [z+66] = 18514 + shift_amount_m256
#     assert [z+67] = 4
#     assert [z+68] = 120
#     assert [z+69] = 2
#     assert [z+70] = 18432 + shift_amount_m256
#     assert [z+71] = 4
#     assert [z+72] = 0
#     assert [z+73] = 2
#     assert [z+74] = 20571 + shift_amount_m256
#     assert [z+75] = 4
#     assert [z+76] = 0
#     assert [z+77] = 2
#     assert [z+78] = 19528 + shift_amount_m256
#     assert [z+79] = 4
#     assert [z+80] = 80
#     assert [z+81] = 2
#     assert [z+82] = 19456 + shift_amount_m256
#     assert [z+83] = 4
#     assert [z+84] = 0
#     assert [z+85] = 2
#     assert [z+86] = 18514 + shift_amount_m256
#     assert [z+87] = 4
#     assert [z+88] = 80
#     assert [z+89] = 2
#     assert [z+90] = 18432 + shift_amount_m256
#     assert [z+91] = 4
#     assert [z+92] = 0
#     assert [z+93] = 2
#     assert [z+94] = 20480 + shift_amount_m256
#     assert [z+95] = 4
#     assert [z+96] = 0
#     assert [z+97] = 2
#     assert [z+98] = 17408 + shift_amount_m256
#     assert [z+99] = 4
#     assert [z+100] = 0
#     assert [z+101] = 2
#     assert [z+102] = 17728 + shift_amount_m256
#     assert [z+103] = 4
#     assert [z+104] = 0
#     assert [z+105] = 2
#     assert [z+106] = 20821 + shift_amount_m256
#     assert [z+107] = 4
#     assert [z+108] = 80
#     assert [z+109] = 2
#     assert [z+110] = 20736 + shift_amount_m256
#     assert [z+111] = 4
#     assert [z+112] = 0
#     assert [z+113] = 2
#     assert [z+114] = 17664 + shift_amount_m256
#     assert [z+115] = 4
#     assert [z+116] = 0
#     assert [z+117] = 2
#     assert [z+118] = 18020 + shift_amount_m256
#     assert [z+119] = 4
#     assert [z+120] = 120
#     assert [z+121] = 2
#     assert [z+122] = 19026 + shift_amount_m256
#     assert [z+123] = 4
#     assert [z+124] = 120
#     assert [z+125] = 2
#     assert [z+126] = 18944 + shift_amount_m256
#     assert [z+127] = 4
#     assert [z+128] = 0
#     assert [z+129] = 2
#     assert [z+130] = 21092 + shift_amount_m256
#     assert [z+131] = 4
#     assert [z+132] = 0
#     assert [z+133] = 2
#     assert [z+134] = 20285 + shift_amount_m256
#     assert [z+135] = 4
#     assert [z+136] = 80
#     assert [z+137] = 2
#     assert [z+138] = 20224 + shift_amount_m256
#     assert [z+139] = 4
#     assert [z+140] = 0
#     assert [z+141] = 2
#     assert [z+142] = 19041 + shift_amount_m256
#     assert [z+143] = 4
#     assert [z+144] = 80
#     assert [z+145] = 2
#     assert [z+146] = 18944 + shift_amount_m256
#     assert [z+147] = 4
#     assert [z+148] = 0
#     assert [z+149] = 2
#     assert [z+150] = 20992 + shift_amount_m256
#     assert [z+151] = 4
#     assert [z+152] = 0
#     assert [z+153] = 2
#     assert [z+154] = 17920 + shift_amount_m256
#     assert [z+155] = 4
#     assert [z+156] = 0
#     assert [z+157] = 2
#     assert [z+158] = 18243 + shift_amount_m256
#     assert [z+159] = 4
#     assert [z+160] = 0
#     assert [z+161] = 2
#     assert [z+162] = 21341 + shift_amount_m256
#     assert [z+163] = 4
#     assert [z+164] = 80
#     assert [z+165] = 2
#     assert [z+166] = 21248 + shift_amount_m256
#     assert [z+167] = 4
#     assert [z+168] = 0
#     assert [z+169] = 2
#     assert [z+170] = 18176 + shift_amount_m256
#     assert [z+171] = 4
#     assert [z+172] = 80
#     assert [z+173] = 2
#     assert [z+174] = 19047 + shift_amount_m256
#     assert [z+175] = 4
#     assert [z+176] = 80
#     assert [z+177] = 2
#     assert [z+178] = 19553 + shift_amount_m256
#     assert [z+179] = 4
#     assert [z+180] = 80
#     assert [z+181] = 2
#     assert [z+182] = 19456 + shift_amount_m256
#     assert [z+183] = 4
#     assert [z+184] = 0
#     assert [z+185] = 2
#     assert [z+186] = 22124 + shift_amount_m256
#     assert [z+187] = 4
#     assert [z+188] = 0
#     assert [z+189] = 2
#     assert [z+190] = 20306 + shift_amount_m256
#     assert [z+191] = 4
#     assert [z+192] = 80
#     assert [z+193] = 2
#     assert [z+194] = 20224 + shift_amount_m256
#     assert [z+195] = 4
#     assert [z+196] = 0
#     assert [z+197] = 2
#     assert [z+198] = 19529 + shift_amount_m256
#     assert [z+199] = 4
#     assert [z+200] = 80
#     assert [z+201] = 2
#     assert [z+202] = 19456 + shift_amount_m256
#     assert [z+203] = 4
#     assert [z+204] = 0
#     assert [z+205] = 2
#     assert [z+206] = 22016 + shift_amount_m256
#     assert [z+207] = 4
#     assert [z+208] = 0
#     assert [z+209] = 2
#     assert [z+210] = 18944 + shift_amount_m256
#     assert [z+211] = 4
#     assert [z+212] = 0
#     assert [z+213] = 2
#     assert [z+214] = 18486 + shift_amount_m256
#     assert [z+215] = 4
#     assert [z+216] = 0
#     assert [z+217] = 2
#     assert [z+218] = 21579 + shift_amount_m256
#     assert [z+219] = 4
#     assert [z+220] = 80
#     assert [z+221] = 2
#     assert [z+222] = 21504 + shift_amount_m256
#     assert [z+223] = 4
#     assert [z+224] = 0
#     assert [z+225] = 2
#     assert [z+226] = 18432 + shift_amount_m256
#     assert [z+227] = 4
#     assert [z+228] = 80
#     assert [z+229] = 2
#     assert [z+230] = 18242 + shift_amount_m256
#     assert [z+231] = 4
#     assert [z+232] = 80
#     assert [z+233] = 2
#     assert [z+234] = 18499 + shift_amount_m256
#     assert [z+235] = 4
#     assert [z+236] = 80
#     assert [z+237] = 2
#     assert [z+238] = 18432 + shift_amount_m256
#     assert [z+239] = 4
#     assert [z+240] = 0
#     assert [z+241] = 2
#     assert [z+242] = 21320 + shift_amount_m256
#     assert [z+243] = 4
#     assert [z+244] = 0
#     assert [z+245] = 2
#     assert [z+246] = 19249 + shift_amount_m256
#     assert [z+247] = 4
#     assert [z+248] = 80
#     assert [z+249] = 2
#     assert [z+250] = 19200 + shift_amount_m256
#     assert [z+251] = 4
#     assert [z+252] = 0
#     assert [z+253] = 2
#     assert [z+254] = 18495 + shift_amount_m256
#     assert [z+255] = 4
#     assert [z+256] = 80
#     assert [z+257] = 2
#     assert [z+258] = 18432 + shift_amount_m256
#     assert [z+259] = 4
#     assert [z+260] = 0
#     assert [z+261] = 2
#     assert [z+262] = 21248 + shift_amount_m256
#     assert [z+263] = 4
#     assert [z+264] = 0
#     assert [z+265] = 2
#     assert [z+266] = 18176 + shift_amount_m256
#     assert [z+267] = 4
#     assert [z+268] = 0
#     assert [z+269] = 2
#     assert [z+270] = 17714 + shift_amount_m256
#     assert [z+271] = 4
#     assert [z+272] = 0
#     assert [z+273] = 2
#     assert [z+274] = 20798 + shift_amount_m256
#     assert [z+275] = 4
#     assert [z+276] = 80
#     assert [z+277] = 2
#     assert [z+278] = 20736 + shift_amount_m256
#     assert [z+279] = 4
#     assert [z+280] = 0
#     assert [z+281] = 2
#     assert [z+282] = 17664 + shift_amount_m256
#     assert [z+283] = 4
#     assert [z+284] = 0
#     assert [z+285] = 2
#     assert [z+286] = 17725 + shift_amount_m256
#     assert [z+287] = 4
#     assert [z+288] = 120
#     assert [z+289] = 2
#     assert [z+290] = 18491 + shift_amount_m256
#     assert [z+291] = 4
#     assert [z+292] = 120
#     assert [z+293] = 2
#     assert [z+294] = 18432 + shift_amount_m256
#     assert [z+295] = 4
#     assert [z+296] = 0
#     assert [z+297] = 2
#     assert [z+298] = 20799 + shift_amount_m256
#     assert [z+299] = 4
#     assert [z+300] = 0
#     assert [z+301] = 2
#     assert [z+302] = 19497 + shift_amount_m256
#     assert [z+303] = 4
#     assert [z+304] = 80
#     assert [z+305] = 2
#     assert [z+306] = 19456 + shift_amount_m256
#     assert [z+307] = 4
#     assert [z+308] = 0
#     assert [z+309] = 2
#     assert [z+310] = 18493 + shift_amount_m256
#     assert [z+311] = 4
#     assert [z+312] = 80
#     assert [z+313] = 2
#     assert [z+314] = 18432 + shift_amount_m256
#     assert [z+315] = 4
#     assert [z+316] = 0
#     assert [z+317] = 2
#     assert [z+318] = 20736 + shift_amount_m256
#     assert [z+319] = 4
#     assert [z+320] = 0
#     assert [z+321] = 2
#     assert [z+322] = 17664 + shift_amount_m256
#     assert [z+323] = 4
#     assert [z+324] = 0
#     assert [z+325] = 2
#     assert [z+326] = 17199 + shift_amount_m256
#     assert [z+327] = 4
#     assert [z+328] = 0
#     assert [z+329] = 2
#     assert [z+330] = 20284 + shift_amount_m256
#     assert [z+331] = 4
#     assert [z+332] = 80
#     assert [z+333] = 2
#     assert [z+334] = 20224 + shift_amount_m256
#     assert [z+335] = 4
#     assert [z+336] = 0
#     assert [z+337] = 2
#     assert [z+338] = 17152 + shift_amount_m256
#     assert [z+339] = 4
#     assert [z+340] = 80
#     assert [z+341] = 2
#     assert [z+342] = 16440 + shift_amount_m256
#     assert [z+343] = 4
#     assert [z+344] = 80
#     assert [z+345] = 2
#     assert [z+346] = 17207 + shift_amount_m256
#     assert [z+347] = 4
#     assert [z+348] = 80
#     assert [z+349] = 2
#     assert [z+350] = 17152 + shift_amount_m256
#     assert [z+351] = 4
#     assert [z+352] = 0
#     assert [z+353] = 2
#     assert [z+354] = 19513 + shift_amount_m256
#     assert [z+355] = 4
#     assert [z+356] = 0
#     assert [z+357] = 2
#     assert [z+358] = 18212 + shift_amount_m256
#     assert [z+359] = 4
#     assert [z+360] = 80
#     assert [z+361] = 2
#     assert [z+362] = 18176 + shift_amount_m256
#     assert [z+363] = 4
#     assert [z+364] = 0
#     assert [z+365] = 2
#     assert [z+366] = 17201 + shift_amount_m256
#     assert [z+367] = 4
#     assert [z+368] = 80
#     assert [z+369] = 2
#     assert [z+370] = 17152 + shift_amount_m256
#     assert [z+371] = 4
#     assert [z+372] = 0
#     assert [z+373] = 2
#     assert [z+374] = 19456 + shift_amount_m256
#     assert [z+375] = 4
#     assert [z+376] = 0
#     assert [z+377] = 2
#     assert [z+378] = 16384 + shift_amount_m256
#     assert [z+379] = 4
#     assert [z+380] = 0
#     assert [z+381] = 2
#     assert [z+382] = 15921 + shift_amount_m256
#     assert [z+383] = 4
#     assert [z+384] = 0
#     assert [z+385] = 2
#     assert [z+386] = 18993 + shift_amount_m256
#     assert [z+387] = 4
#     assert [z+388] = 80
#     assert [z+389] = 2
#     assert [z+390] = 18944 + shift_amount_m256
#     assert [z+391] = 4
#     assert [z+392] = 0
#     assert [z+393] = 2
#     assert [z+394] = 15872 + shift_amount_m256
#     assert [z+395] = 4
#     assert [z+396] = 120
#     assert [z+397] = 2
#     assert [z+398] = 15411 + shift_amount_m256
#     assert [z+399] = 4
#     assert [z+400] = 120
#     assert [z+401] = 2
#     assert [z+402] = 15360 + shift_amount_m256
#     assert [z+403] = 4
#     assert [z+404] = 0
#     assert [z+405] = 2
#     assert [z+406] = 17208 + shift_amount_m256
#     assert [z+407] = 4
#     assert [z+408] = 0
#     assert [z+409] = 2
#     assert [z+410] = 16419 + shift_amount_m256
#     assert [z+411] = 4
#     assert [z+412] = 80
#     assert [z+413] = 2
#     assert [z+414] = 16384 + shift_amount_m256
#     assert [z+415] = 4
#     assert [z+416] = 0
#     assert [z+417] = 2
#     assert [z+418] = 15408 + shift_amount_m256
#     assert [z+419] = 4
#     assert [z+420] = 80
#     assert [z+421] = 2
#     assert [z+422] = 15360 + shift_amount_m256
#     assert [z+423] = 4
#     assert [z+424] = 0
#     assert [z+425] = 2
#     assert [z+426] = 17152 + shift_amount_m256
#     assert [z+427] = 4
#     assert [z+428] = 0
#     assert [z+429] = 2
#     assert [z+430] = 17712 + shift_amount_m256
#     assert [z+431] = 4
#     assert [z+432] = 80
#     assert [z+433] = 2
#     assert [z+434] = 17664 + shift_amount_m256
#     assert [z+435] = 4
#     assert [z+436] = 0
#     assert [z+437] = 2
#     assert [z+438] = 16425 + shift_amount_m256
#     assert [z+439] = 4
#     assert [z+440] = 120
#     assert [z+441] = 2
#     assert [z+442] = 17207 + shift_amount_m256
#     assert [z+443] = 4
#     assert [z+444] = 120
#     assert [z+445] = 2
#     assert [z+446] = 17152 + shift_amount_m256
#     assert [z+447] = 4
#     assert [z+448] = 0
#     assert [z+449] = 2
#     assert [z+450] = 19517 + shift_amount_m256
#     assert [z+451] = 4
#     assert [z+452] = 0
#     assert [z+453] = 2
#     assert [z+454] = 18214 + shift_amount_m256
#     assert [z+455] = 4
#     assert [z+456] = 80
#     assert [z+457] = 2
#     assert [z+458] = 18176 + shift_amount_m256
#     assert [z+459] = 4
#     assert [z+460] = 0
#     assert [z+461] = 2
#     assert [z+462] = 17200 + shift_amount_m256
#     assert [z+463] = 4
#     assert [z+464] = 80
#     assert [z+465] = 2
#     assert [z+466] = 17152 + shift_amount_m256
#     assert [z+467] = 4
#     assert [z+468] = 0
#     assert [z+469] = 2
#     assert [z+470] = 19456 + shift_amount_m256
#     assert [z+471] = 4
#     assert [z+472] = 0
#     assert [z+473] = 2
#     assert [z+474] = 16384 + shift_amount_m256
#     assert [z+475] = 4
#     assert [z+476] = 0
#     assert [z+477] = 2
#     assert [z+478] = 15913 + shift_amount_m256
#     assert [z+479] = 4
#     assert [z+480] = 0
#     assert [z+481] = 2
#     assert [z+482] = 18992 + shift_amount_m256
#     assert [z+483] = 4
#     assert [z+484] = 80
#     assert [z+485] = 2
#     assert [z+486] = 18944 + shift_amount_m256
#     assert [z+487] = 4
#     assert [z+488] = 0
#     assert [z+489] = 2
#     assert [z+490] = 15872 + shift_amount_m256
#     assert [z+491] = 4
#     assert [z+492] = 33056
#     assert [z+493] = 4
#     assert [z+494] = 15411 + shift_amount_m256
#     assert [z+495] = 4
#     assert [z+496] = 80
#     assert [z+497] = 2
#     assert [z+498] = 15360 + shift_amount_m256
#     assert [z+499] = 4
#     assert [z+500] = 0
#     assert [z+501] = 2
#     assert [z+502] = 17208 + shift_amount_m256
#     assert [z+503] = 4
#     assert [z+504] = 0
#     assert [z+505] = 2
#     assert [z+506] = 16419 + shift_amount_m256
#     assert [z+507] = 4
#     assert [z+508] = 80
#     assert [z+509] = 2
#     assert [z+510] = 16384 + shift_amount_m256
#     assert [z+511] = 4
#     assert [z+512] = 0
#     assert [z+513] = 2
#     assert [z+514] = 15408 + shift_amount_m256
#     assert [z+515] = 4
#     assert [z+516] = 80
#     assert [z+517] = 2
#     assert [z+518] = 15360 + shift_amount_m256
#     assert [z+519] = 4
#     assert [z+520] = 0
#     assert [z+521] = 2
#     assert [z+522] = 17152 + shift_amount_m256
#     assert [z+523] = 4
#     assert [z+524] = 0
#     assert [z+525] = 2
#     assert [z+526] = 17712 + shift_amount_m256
#     assert [z+527] = 4
#     assert [z+528] = 80
#     assert [z+529] = 2
#     assert [z+530] = 17664 + shift_amount_m256
#     assert [z+531] = 4
#     assert [z+532] = 80
#     assert [z+533] = 2
#     assert [z+534] = 16425 + shift_amount_m256
#     assert [z+535] = 4
#     assert [z+536] = 80
#     assert [z+537] = 2
#     assert [z+538] = 17207 + shift_amount_m256
#     assert [z+539] = 4
#     assert [z+540] = 80
#     assert [z+541] = 2
#     assert [z+542] = 17152 + shift_amount_m256
#     assert [z+543] = 4
#     assert [z+544] = 0
#     assert [z+545] = 2
#     assert [z+546] = 19517 + shift_amount_m256
#     assert [z+547] = 4
#     assert [z+548] = 0
#     assert [z+549] = 2
#     assert [z+550] = 18214 + shift_amount_m256
#     assert [z+551] = 4
#     assert [z+552] = 80
#     assert [z+553] = 2
#     assert [z+554] = 18176 + shift_amount_m256
#     assert [z+555] = 4
#     assert [z+556] = 0
#     assert [z+557] = 2
#     assert [z+558] = 17200 + shift_amount_m256
#     assert [z+559] = 4
#     assert [z+560] = 80
#     assert [z+561] = 2
#     assert [z+562] = 17152 + shift_amount_m256
#     assert [z+563] = 4
#     assert [z+564] = 0
#     assert [z+565] = 2
#     assert [z+566] = 19456 + shift_amount_m256
#     assert [z+567] = 4
#     assert [z+568] = 0
#     assert [z+569] = 2
#     assert [z+570] = 16384 + shift_amount_m256
#     assert [z+571] = 4
#     assert [z+572] = 0
#     assert [z+573] = 2
#     assert [z+574] = 15913 + shift_amount_m256
#     assert [z+575] = 4
#     assert [z+576] = 0
#     assert [z+577] = 2
#     assert [z+578] = 18992 + shift_amount_m256
#     assert [z+579] = 4
#     assert [z+580] = 80
#     assert [z+581] = 2
#     assert [z+582] = 18944 + shift_amount_m256
#     assert [z+583] = 4
#     assert [z+584] = 0
#     assert [z+585] = 2
#     assert [z+586] = 15872 + shift_amount_m256
#     assert [z+587] = 4
#     assert [z+588] = 80
#     assert [z+589] = 2
#     assert [z+590] = 15401 + shift_amount_m256
#     assert [z+591] = 4
#     assert [z+592] = 80
#     assert [z+593] = 2
#     assert [z+594] = 16691 + shift_amount_m256
#     assert [z+595] = 4
#     assert [z+596] = 80
#     assert [z+597] = 2
#     assert [z+598] = 16640 + shift_amount_m256
#     assert [z+599] = 4
#     assert [z+600] = 0
#     assert [z+601] = 2
#     assert [z+602] = 15360 + shift_amount_m256
#     assert [z+603] = 4
#     assert [z+604] = 0
#     assert [z+605] = 2
#     assert [z+606] = 18488 + shift_amount_m256
#     assert [z+607] = 4
#     assert [z+608] = 0
#     assert [z+609] = 2
#     assert [z+610] = 17699 + shift_amount_m256
#     assert [z+611] = 4
#     assert [z+612] = 80
#     assert [z+613] = 2
#     assert [z+614] = 17664 + shift_amount_m256
#     assert [z+615] = 4
#     assert [z+616] = 0
#     assert [z+617] = 2
#     assert [z+618] = 16685 + shift_amount_m256
#     assert [z+619] = 4
#     assert [z+620] = 80
#     assert [z+621] = 2
#     assert [z+622] = 16640 + shift_amount_m256
#     assert [z+623] = 4
#     assert [z+624] = 0
#     assert [z+625] = 2
#     assert [z+626] = 16425 + shift_amount_m256
#     assert [z+627] = 4
#     assert [z+628] = 0
#     assert [z+629] = 2
#     assert [z+630] = 17193 + shift_amount_m256
#     assert [z+631] = 4
#     assert [z+632] = 80
#     assert [z+633] = 2
#     assert [z+634] = 17152 + shift_amount_m256
#     assert [z+635] = 4
#     assert [z+636] = 0
#     assert [z+637] = 2
#     assert [z+638] = 16384 + shift_amount_m256
#     assert [z+639] = 4
#     assert [z+640] = 80
#     assert [z+641] = 2
#     assert [z+642] = 15402 + shift_amount_m256
#     assert [z+643] = 4
#     assert [z+644] = 80
#     assert [z+645] = 2
#     assert [z+646] = 16696 + shift_amount_m256
#     assert [z+647] = 4
#     assert [z+648] = 80
#     assert [z+649] = 2
#     assert [z+650] = 16640 + shift_amount_m256
#     assert [z+651] = 4
#     assert [z+652] = 0
#     assert [z+653] = 2
#     assert [z+654] = 15360 + shift_amount_m256
#     assert [z+655] = 4
#     assert [z+656] = 0
#     assert [z+657] = 2
#     assert [z+658] = 18432 + shift_amount_m256
#     assert [z+659] = 4
#     assert [z+660] = 0
#     assert [z+661] = 2
#     assert [z+662] = 18496 + shift_amount_m256
#     assert [z+663] = 4
#     assert [z+664] = 0
#     assert [z+665] = 2
#     assert [z+666] = 17703 + shift_amount_m256
#     assert [z+667] = 4
#     assert [z+668] = 80
#     assert [z+669] = 2
#     assert [z+670] = 17664 + shift_amount_m256
#     assert [z+671] = 4
#     assert [z+672] = 0
#     assert [z+673] = 2
#     assert [z+674] = 16685 + shift_amount_m256
#     assert [z+675] = 4
#     assert [z+676] = 80
#     assert [z+677] = 2
#     assert [z+678] = 16640 + shift_amount_m256
#     assert [z+679] = 4
#     assert [z+680] = 0
#     assert [z+681] = 2
#     assert [z+682] = 16425 + shift_amount_m256
#     assert [z+683] = 4
#     assert [z+684] = 0
#     assert [z+685] = 2
#     assert [z+686] = 17193 + shift_amount_m256
#     assert [z+687] = 4
#     assert [z+688] = 80
#     assert [z+689] = 2
#     assert [z+690] = 17152 + shift_amount_m256
#     assert [z+691] = 4
#     assert [z+692] = 0
#     assert [z+693] = 2
#     assert [z+694] = 16384 + shift_amount_m256
#     assert [z+695] = 4
#     assert [z+696] = 80
#     assert [z+697] = 2
#     assert [z+698] = 15400 + shift_amount_m256
#     assert [z+699] = 4
#     assert [z+700] = 80
#     assert [z+701] = 2
#     assert [z+702] = 16689 + shift_amount_m256
#     assert [z+703] = 4
#     assert [z+704] = 80
#     assert [z+705] = 2
#     assert [z+706] = 16640 + shift_amount_m256
#     assert [z+707] = 4
#     assert [z+708] = 0
#     assert [z+709] = 2
#     assert [z+710] = 15360 + shift_amount_m256
#     assert [z+711] = 4
#     assert [z+712] = 0
#     assert [z+713] = 2
#     assert [z+714] = 18432 + shift_amount_m256
#     assert [z+715] = 4
#     assert [z+716] = 0
#     assert [z+717] = 2
#     assert [z+718] = 18484 + shift_amount_m256
#     assert [z+719] = 4
#     assert [z+720] = 0
#     assert [z+721] = 2
#     assert [z+722] = 17697 + shift_amount_m256
#     assert [z+723] = 4
#     assert [z+724] = 80
#     assert [z+725] = 2
#     assert [z+726] = 17664 + shift_amount_m256
#     assert [z+727] = 4
#     assert [z+728] = 0
#     assert [z+729] = 2
#     assert [z+730] = 16681 + shift_amount_m256
#     assert [z+731] = 4
#     assert [z+732] = 80
#     assert [z+733] = 2
#     assert [z+734] = 16640 + shift_amount_m256
#     assert [z+735] = 4
#     assert [z+736] = 0
#     assert [z+737] = 2
#     assert [z+738] = 16422 + shift_amount_m256
#     assert [z+739] = 4
#     assert [z+740] = 0
#     assert [z+741] = 2
#     assert [z+742] = 17190 + shift_amount_m256
#     assert [z+743] = 4
#     assert [z+744] = 80
#     assert [z+745] = 2
#     assert [z+746] = 17152 + shift_amount_m256
#     assert [z+747] = 4
#     assert [z+748] = 0
#     assert [z+749] = 2
#     assert [z+750] = 16384 + shift_amount_m256
#     assert [z+751] = 4
#     assert [z+752] = 80
#     assert [z+753] = 2
#     assert [z+754] = 15397 + shift_amount_m256
#     assert [z+755] = 4
#     assert [z+756] = 80
#     assert [z+757] = 2
#     assert [z+758] = 16684 + shift_amount_m256
#     assert [z+759] = 4
#     assert [z+760] = 80
#     assert [z+761] = 2
#     assert [z+762] = 16640 + shift_amount_m256
#     assert [z+763] = 4
#     assert [z+764] = 0
#     assert [z+765] = 2
#     assert [z+766] = 15360 + shift_amount_m256
#     assert [z+767] = 4
#     assert [z+768] = 0
#     assert [z+769] = 2
#     assert [z+770] = 18432 + shift_amount_m256
#     assert [z+771] = 4
#     assert [z+772] = 0
#     assert [z+773] = 2
#     assert [z+774] = 18478 + shift_amount_m256
#     assert [z+775] = 4
#     assert [z+776] = 0
#     assert [z+777] = 2
#     assert [z+778] = 17693 + shift_amount_m256
#     assert [z+779] = 4
#     assert [z+780] = 80
#     assert [z+781] = 2
#     assert [z+782] = 17664 + shift_amount_m256
#     assert [z+783] = 4
#     assert [z+784] = 0
#     assert [z+785] = 2
#     assert [z+786] = 16676 + shift_amount_m256
#     assert [z+787] = 4
#     assert [z+788] = 80
#     assert [z+789] = 2
#     assert [z+790] = 16640 + shift_amount_m256
#     assert [z+791] = 4
#     assert [z+792] = 0
#     assert [z+793] = 2
#     assert [z+794] = 16417 + shift_amount_m256
#     assert [z+795] = 4
#     assert [z+796] = 0
#     assert [z+797] = 2
#     assert [z+798] = 17185 + shift_amount_m256
#     assert [z+799] = 4
#     assert [z+800] = 80
#     assert [z+801] = 2
#     assert [z+802] = 17152 + shift_amount_m256
#     assert [z+803] = 4
#     assert [z+804] = 0
#     assert [z+805] = 2
#     assert [z+806] = 16384 + shift_amount_m256
#     assert [z+807] = 4
#     assert [z+808] = 0
#     assert [z+809] = 2
#     assert [z+810] = 18432 + shift_amount_m256
#     assert [z+811] = 4
#     assert [z+812] = 33552
#     assert [z+813] = 4
#     assert [z+814] = 15393 + shift_amount_m256
#     assert [z+815] = 4
#     assert [z+816] = 80
#     assert [z+817] = 2
#     assert [z+818] = 16417 + shift_amount_m256
#     assert [z+819] = 4
#     assert [z+820] = 33632
#     assert [z+821] = 4
#     assert [z+822] = 16384 + shift_amount_m256
#     assert [z+823] = 4
#     assert [z+824] = 0
#     assert [z+825] = 2
#     assert [z+826] = 15360 + shift_amount_m256
#     assert [z+827] = 4
#     assert [z+828] = 0
#     assert [z+829] = 2
#     assert [z+830] = 16723712
#     assert [z+831] = 6

# %% [markdown]
# ### music track two

# %%
len(chpn_og.track_objs[2].segs)
# Out:
# 640

# %%
generate_single_note_manipulable(chpn_og.track_objs[2].segs[0:320], '')
# Out:
#     local shift_amount_m256 = shift_amount * 256
#     assert [z+0] = 1297379947
#     assert [z+1] = 8
#     assert [z+2] = 1072
#     assert [z+3] = 8
#     assert [z+4] = 0
#     assert [z+5] = 2
#     assert [z+6] = 20204122365158313696216914159220
#     assert [z+7] = 26
#     assert [z+8] = 0
#     assert [z+9] = 2
#     assert [z+10] = 49152
#     assert [z+11] = 4
#     assert [z+12] = 0
#     assert [z+13] = 2
#     assert [z+14] = 11536228
#     assert [z+15] = 6
#     assert [z+16] = 0
#     assert [z+17] = 2
#     assert [z+18] = 2624
#     assert [z+19] = 4
#     assert [z+20] = 0
#     assert [z+21] = 2
#     assert [z+22] = 23423
#     assert [z+23] = 4
#     assert [z+24] = 0
#     assert [z+25] = 2
#     assert [z+26] = 23423
#     assert [z+27] = 4
#     assert [z+28] = 0
#     assert [z+29] = 2
#     assert [z+30] = 16511
#     assert [z+31] = 4
#     assert [z+32] = 1
#     assert [z+33] = 2
#     assert [z+34] = 9446446 + shift_amount_m256
#     assert [z+35] = 6
#     assert [z+36] = 79
#     assert [z+37] = 2
#     assert [z+38] = 9216 + shift_amount_m256
#     assert [z+39] = 4
#     assert [z+40] = 0
#     assert [z+41] = 2
#     assert [z+42] = 14116 + shift_amount_m256
#     assert [z+43] = 4
#     assert [z+44] = 0
#     assert [z+45] = 2
#     assert [z+46] = 11038 + shift_amount_m256
#     assert [z+47] = 4
#     assert [z+48] = 80
#     assert [z+49] = 2
#     assert [z+50] = 11008 + shift_amount_m256
#     assert [z+51] = 4
#     assert [z+52] = 0
#     assert [z+53] = 2
#     assert [z+54] = 13348 + shift_amount_m256
#     assert [z+55] = 4
#     assert [z+56] = 80
#     assert [z+57] = 2
#     assert [z+58] = 13312 + shift_amount_m256
#     assert [z+59] = 4
#     assert [z+60] = 33056
#     assert [z+61] = 4
#     assert [z+62] = 14080 + shift_amount_m256
#     assert [z+63] = 4
#     assert [z+64] = 0
#     assert [z+65] = 2
#     assert [z+66] = 14619 + shift_amount_m256
#     assert [z+67] = 4
#     assert [z+68] = 80
#     assert [z+69] = 2
#     assert [z+70] = 14592 + shift_amount_m256
#     assert [z+71] = 4
#     assert [z+72] = 0
#     assert [z+73] = 2
#     assert [z+74] = 9011 + shift_amount_m256
#     assert [z+75] = 4
#     assert [z+76] = 10
#     assert [z+77] = 2
#     assert [z+78] = 11550720
#     assert [z+79] = 6
#     assert [z+80] = 25
#     assert [z+81] = 2
#     assert [z+82] = 16511
#     assert [z+83] = 4
#     assert [z+84] = 45
#     assert [z+85] = 2
#     assert [z+86] = 9446144 + shift_amount_m256
#     assert [z+87] = 6
#     assert [z+88] = 0
#     assert [z+89] = 2
#     assert [z+90] = 14127 + shift_amount_m256
#     assert [z+91] = 4
#     assert [z+92] = 0
#     assert [z+93] = 2
#     assert [z+94] = 11046 + shift_amount_m256
#     assert [z+95] = 4
#     assert [z+96] = 80
#     assert [z+97] = 2
#     assert [z+98] = 11008 + shift_amount_m256
#     assert [z+99] = 4
#     assert [z+100] = 0
#     assert [z+101] = 2
#     assert [z+102] = 13604 + shift_amount_m256
#     assert [z+103] = 4
#     assert [z+104] = 80
#     assert [z+105] = 2
#     assert [z+106] = 13568 + shift_amount_m256
#     assert [z+107] = 4
#     assert [z+108] = 33056
#     assert [z+109] = 4
#     assert [z+110] = 14080 + shift_amount_m256
#     assert [z+111] = 4
#     assert [z+112] = 0
#     assert [z+113] = 2
#     assert [z+114] = 14625 + shift_amount_m256
#     assert [z+115] = 4
#     assert [z+116] = 80
#     assert [z+117] = 2
#     assert [z+118] = 14592 + shift_amount_m256
#     assert [z+119] = 4
#     assert [z+120] = 0
#     assert [z+121] = 2
#     assert [z+122] = 9269 + shift_amount_m256
#     assert [z+123] = 4
#     assert [z+124] = 11
#     assert [z+125] = 2
#     assert [z+126] = 11550720
#     assert [z+127] = 6
#     assert [z+128] = 24
#     assert [z+129] = 2
#     assert [z+130] = 16511
#     assert [z+131] = 4
#     assert [z+132] = 45
#     assert [z+133] = 2
#     assert [z+134] = 9446400 + shift_amount_m256
#     assert [z+135] = 6
#     assert [z+136] = 0
#     assert [z+137] = 2
#     assert [z+138] = 14136 + shift_amount_m256
#     assert [z+139] = 4
#     assert [z+140] = 0
#     assert [z+141] = 2
#     assert [z+142] = 11055 + shift_amount_m256
#     assert [z+143] = 4
#     assert [z+144] = 80
#     assert [z+145] = 2
#     assert [z+146] = 11008 + shift_amount_m256
#     assert [z+147] = 4
#     assert [z+148] = 0
#     assert [z+149] = 2
#     assert [z+150] = 13359 + shift_amount_m256
#     assert [z+151] = 4
#     assert [z+152] = 80
#     assert [z+153] = 2
#     assert [z+154] = 13312 + shift_amount_m256
#     assert [z+155] = 4
#     assert [z+156] = 33056
#     assert [z+157] = 4
#     assert [z+158] = 14080 + shift_amount_m256
#     assert [z+159] = 4
#     assert [z+160] = 0
#     assert [z+161] = 2
#     assert [z+162] = 14644 + shift_amount_m256
#     assert [z+163] = 4
#     assert [z+164] = 80
#     assert [z+165] = 2
#     assert [z+166] = 14592 + shift_amount_m256
#     assert [z+167] = 4
#     assert [z+168] = 0
#     assert [z+169] = 2
#     assert [z+170] = 10319 + shift_amount_m256
#     assert [z+171] = 4
#     assert [z+172] = 10
#     assert [z+173] = 2
#     assert [z+174] = 11550720
#     assert [z+175] = 6
#     assert [z+176] = 25
#     assert [z+177] = 2
#     assert [z+178] = 16511
#     assert [z+179] = 4
#     assert [z+180] = 45
#     assert [z+181] = 2
#     assert [z+182] = 9447424 + shift_amount_m256
#     assert [z+183] = 6
#     assert [z+184] = 0
#     assert [z+185] = 2
#     assert [z+186] = 15170 + shift_amount_m256
#     assert [z+187] = 4
#     assert [z+188] = 0
#     assert [z+189] = 2
#     assert [z+190] = 13367 + shift_amount_m256
#     assert [z+191] = 4
#     assert [z+192] = 80
#     assert [z+193] = 2
#     assert [z+194] = 13312 + shift_amount_m256
#     assert [z+195] = 4
#     assert [z+196] = 0
#     assert [z+197] = 2
#     assert [z+198] = 14136 + shift_amount_m256
#     assert [z+199] = 4
#     assert [z+200] = 80
#     assert [z+201] = 2
#     assert [z+202] = 14080 + shift_amount_m256
#     assert [z+203] = 4
#     assert [z+204] = 33056
#     assert [z+205] = 4
#     assert [z+206] = 15104 + shift_amount_m256
#     assert [z+207] = 4
#     assert [z+208] = 0
#     assert [z+209] = 2
#     assert [z+210] = 15422 + shift_amount_m256
#     assert [z+211] = 4
#     assert [z+212] = 80
#     assert [z+213] = 2
#     assert [z+214] = 15360 + shift_amount_m256
#     assert [z+215] = 4
#     assert [z+216] = 0
#     assert [z+217] = 2
#     assert [z+218] = 10580 + shift_amount_m256
#     assert [z+219] = 4
#     assert [z+220] = 17
#     assert [z+221] = 2
#     assert [z+222] = 11550720
#     assert [z+223] = 6
#     assert [z+224] = 18
#     assert [z+225] = 2
#     assert [z+226] = 16511
#     assert [z+227] = 4
#     assert [z+228] = 45
#     assert [z+229] = 2
#     assert [z+230] = 9447680 + shift_amount_m256
#     assert [z+231] = 6
#     assert [z+232] = 0
#     assert [z+233] = 2
#     assert [z+234] = 13380 + shift_amount_m256
#     assert [z+235] = 4
#     assert [z+236] = 80
#     assert [z+237] = 2
#     assert [z+238] = 13312 + shift_amount_m256
#     assert [z+239] = 4
#     assert [z+240] = 0
#     assert [z+241] = 2
#     assert [z+242] = 14651 + shift_amount_m256
#     assert [z+243] = 4
#     assert [z+244] = 80
#     assert [z+245] = 2
#     assert [z+246] = 14592 + shift_amount_m256
#     assert [z+247] = 4
#     assert [z+248] = 33136
#     assert [z+249] = 4
#     assert [z+250] = 10843 + shift_amount_m256
#     assert [z+251] = 4
#     assert [z+252] = 13
#     assert [z+253] = 2
#     assert [z+254] = 11550720
#     assert [z+255] = 6
#     assert [z+256] = 22
#     assert [z+257] = 2
#     assert [z+258] = 16511
#     assert [z+259] = 4
#     assert [z+260] = 45
#     assert [z+261] = 2
#     assert [z+262] = 9447936 + shift_amount_m256
#     assert [z+263] = 6
#     assert [z+264] = 0
#     assert [z+265] = 2
#     assert [z+266] = 12875 + shift_amount_m256
#     assert [z+267] = 4
#     assert [z+268] = 80
#     assert [z+269] = 2
#     assert [z+270] = 12800 + shift_amount_m256
#     assert [z+271] = 4
#     assert [z+272] = 0
#     assert [z+273] = 2
#     assert [z+274] = 15424 + shift_amount_m256
#     assert [z+275] = 4
#     assert [z+276] = 80
#     assert [z+277] = 2
#     assert [z+278] = 15360 + shift_amount_m256
#     assert [z+279] = 4
#     assert [z+280] = 33136
#     assert [z+281] = 4
#     assert [z+282] = 11105 + shift_amount_m256
#     assert [z+283] = 4
#     assert [z+284] = 5
#     assert [z+285] = 2
#     assert [z+286] = 11550720
#     assert [z+287] = 6
#     assert [z+288] = 26
#     assert [z+289] = 2
#     assert [z+290] = 16511
#     assert [z+291] = 4
#     assert [z+292] = 49
#     assert [z+293] = 2
#     assert [z+294] = 9448192 + shift_amount_m256
#     assert [z+295] = 6
#     assert [z+296] = 0
#     assert [z+297] = 2
#     assert [z+298] = 13647 + shift_amount_m256
#     assert [z+299] = 4
#     assert [z+300] = 80
#     assert [z+301] = 2
#     assert [z+302] = 13568 + shift_amount_m256
#     assert [z+303] = 4
#     assert [z+304] = 0
#     assert [z+305] = 2
#     assert [z+306] = 15171 + shift_amount_m256
#     assert [z+307] = 4
#     assert [z+308] = 80
#     assert [z+309] = 2
#     assert [z+310] = 15104 + shift_amount_m256
#     assert [z+311] = 4
#     assert [z+312] = 33136
#     assert [z+313] = 4
#     assert [z+314] = 7994 + shift_amount_m256
#     assert [z+315] = 4
#     assert [z+316] = 11
#     assert [z+317] = 2
#     assert [z+318] = 11550720
#     assert [z+319] = 6
#     assert [z+320] = 46
#     assert [z+321] = 2
#     assert [z+322] = 16511
#     assert [z+323] = 4
#     assert [z+324] = 23
#     assert [z+325] = 2
#     assert [z+326] = 9445120 + shift_amount_m256
#     assert [z+327] = 6
#     assert [z+328] = 0
#     assert [z+329] = 2
#     assert [z+330] = 15154 + shift_amount_m256
#     assert [z+331] = 4
#     assert [z+332] = 0
#     assert [z+333] = 2
#     assert [z+334] = 11050 + shift_amount_m256
#     assert [z+335] = 4
#     assert [z+336] = 80
#     assert [z+337] = 2
#     assert [z+338] = 11008 + shift_amount_m256
#     assert [z+339] = 4
#     assert [z+340] = 0
#     assert [z+341] = 2
#     assert [z+342] = 13606 + shift_amount_m256
#     assert [z+343] = 4
#     assert [z+344] = 80
#     assert [z+345] = 2
#     assert [z+346] = 13568 + shift_amount_m256
#     assert [z+347] = 4
#     assert [z+348] = 33056
#     assert [z+349] = 4
#     assert [z+350] = 15104 + shift_amount_m256
#     assert [z+351] = 4
#     assert [z+352] = 0
#     assert [z+353] = 2
#     assert [z+354] = 14631 + shift_amount_m256
#     assert [z+355] = 4
#     assert [z+356] = 8
#     assert [z+357] = 2
#     assert [z+358] = 11550720
#     assert [z+359] = 6
#     assert [z+360] = 72
#     assert [z+361] = 2
#     assert [z+362] = 9451776 + shift_amount_m256
#     assert [z+363] = 6
#     assert [z+364] = 0
#     assert [z+365] = 2
#     assert [z+366] = 9267 + shift_amount_m256
#     assert [z+367] = 4
#     assert [z+368] = 32
#     assert [z+369] = 2
#     assert [z+370] = 11550847
#     assert [z+371] = 6
#     assert [z+372] = 48
#     assert [z+373] = 2
#     assert [z+374] = 9446400 + shift_amount_m256
#     assert [z+375] = 6
#     assert [z+376] = 0
#     assert [z+377] = 2
#     assert [z+378] = 14124 + shift_amount_m256
#     assert [z+379] = 4
#     assert [z+380] = 0
#     assert [z+381] = 2
#     assert [z+382] = 11045 + shift_amount_m256
#     assert [z+383] = 4
#     assert [z+384] = 80
#     assert [z+385] = 2
#     assert [z+386] = 11008 + shift_amount_m256
#     assert [z+387] = 4
#     assert [z+388] = 0
#     assert [z+389] = 2
#     assert [z+390] = 13351 + shift_amount_m256
#     assert [z+391] = 4
#     assert [z+392] = 80
#     assert [z+393] = 2
#     assert [z+394] = 13312 + shift_amount_m256
#     assert [z+395] = 4
#     assert [z+396] = 33056
#     assert [z+397] = 4
#     assert [z+398] = 14080 + shift_amount_m256
#     assert [z+399] = 4
#     assert [z+400] = 0
#     assert [z+401] = 2
#     assert [z+402] = 14630 + shift_amount_m256
#     assert [z+403] = 4
#     assert [z+404] = 80
#     assert [z+405] = 2
#     assert [z+406] = 14592 + shift_amount_m256
#     assert [z+407] = 4
#     assert [z+408] = 0
#     assert [z+409] = 2
#     assert [z+410] = 9013 + shift_amount_m256
#     assert [z+411] = 4
#     assert [z+412] = 7
#     assert [z+413] = 2
#     assert [z+414] = 11550720
#     assert [z+415] = 6
#     assert [z+416] = 28
#     assert [z+417] = 2
#     assert [z+418] = 16511
#     assert [z+419] = 4
#     assert [z+420] = 45
#     assert [z+421] = 2
#     assert [z+422] = 9446144 + shift_amount_m256
#     assert [z+423] = 6
#     assert [z+424] = 0
#     assert [z+425] = 2
#     assert [z+426] = 14131 + shift_amount_m256
#     assert [z+427] = 4
#     assert [z+428] = 0
#     assert [z+429] = 2
#     assert [z+430] = 11050 + shift_amount_m256
#     assert [z+431] = 4
#     assert [z+432] = 80
#     assert [z+433] = 2
#     assert [z+434] = 11008 + shift_amount_m256
#     assert [z+435] = 4
#     assert [z+436] = 0
#     assert [z+437] = 2
#     assert [z+438] = 13612 + shift_amount_m256
#     assert [z+439] = 4
#     assert [z+440] = 80
#     assert [z+441] = 2
#     assert [z+442] = 13568 + shift_amount_m256
#     assert [z+443] = 4
#     assert [z+444] = 33056
#     assert [z+445] = 4
#     assert [z+446] = 14080 + shift_amount_m256
#     assert [z+447] = 4
#     assert [z+448] = 0
#     assert [z+449] = 2
#     assert [z+450] = 14636 + shift_amount_m256
#     assert [z+451] = 4
#     assert [z+452] = 80
#     assert [z+453] = 2
#     assert [z+454] = 14592 + shift_amount_m256
#     assert [z+455] = 4
#     assert [z+456] = 0
#     assert [z+457] = 2
#     assert [z+458] = 9279 + shift_amount_m256
#     assert [z+459] = 4
#     assert [z+460] = 6
#     assert [z+461] = 2
#     assert [z+462] = 11550720
#     assert [z+463] = 6
#     assert [z+464] = 29
#     assert [z+465] = 2
#     assert [z+466] = 16511
#     assert [z+467] = 4
#     assert [z+468] = 45
#     assert [z+469] = 2
#     assert [z+470] = 9446400 + shift_amount_m256
#     assert [z+471] = 6
#     assert [z+472] = 0
#     assert [z+473] = 2
#     assert [z+474] = 14140 + shift_amount_m256
#     assert [z+475] = 4
#     assert [z+476] = 0
#     assert [z+477] = 2
#     assert [z+478] = 11058 + shift_amount_m256
#     assert [z+479] = 4
#     assert [z+480] = 80
#     assert [z+481] = 2
#     assert [z+482] = 11008 + shift_amount_m256
#     assert [z+483] = 4
#     assert [z+484] = 0
#     assert [z+485] = 2
#     assert [z+486] = 13375 + shift_amount_m256
#     assert [z+487] = 4
#     assert [z+488] = 80
#     assert [z+489] = 2
#     assert [z+490] = 13312 + shift_amount_m256
#     assert [z+491] = 4
#     assert [z+492] = 33056
#     assert [z+493] = 4
#     assert [z+494] = 14080 + shift_amount_m256
#     assert [z+495] = 4
#     assert [z+496] = 0
#     assert [z+497] = 2
#     assert [z+498] = 14642 + shift_amount_m256
#     assert [z+499] = 4
#     assert [z+500] = 80
#     assert [z+501] = 2
#     assert [z+502] = 14592 + shift_amount_m256
#     assert [z+503] = 4
#     assert [z+504] = 0
#     assert [z+505] = 2
#     assert [z+506] = 10319 + shift_amount_m256
#     assert [z+507] = 4
#     assert [z+508] = 6
#     assert [z+509] = 2
#     assert [z+510] = 11550720
#     assert [z+511] = 6
#     assert [z+512] = 29
#     assert [z+513] = 2
#     assert [z+514] = 16511
#     assert [z+515] = 4
#     assert [z+516] = 45
#     assert [z+517] = 2
#     assert [z+518] = 9447424 + shift_amount_m256
#     assert [z+519] = 6
#     assert [z+520] = 0
#     assert [z+521] = 2
#     assert [z+522] = 15170 + shift_amount_m256
#     assert [z+523] = 4
#     assert [z+524] = 0
#     assert [z+525] = 2
#     assert [z+526] = 13378 + shift_amount_m256
#     assert [z+527] = 4
#     assert [z+528] = 80
#     assert [z+529] = 2
#     assert [z+530] = 13312 + shift_amount_m256
#     assert [z+531] = 4
#     assert [z+532] = 0
#     assert [z+533] = 2
#     assert [z+534] = 14136 + shift_amount_m256
#     assert [z+535] = 4
#     assert [z+536] = 80
#     assert [z+537] = 2
#     assert [z+538] = 14080 + shift_amount_m256
#     assert [z+539] = 4
#     assert [z+540] = 33056
#     assert [z+541] = 4
#     assert [z+542] = 15104 + shift_amount_m256
#     assert [z+543] = 4
#     assert [z+544] = 0
#     assert [z+545] = 2
#     assert [z+546] = 15415 + shift_amount_m256
#     assert [z+547] = 4
#     assert [z+548] = 80
#     assert [z+549] = 2
#     assert [z+550] = 15360 + shift_amount_m256
#     assert [z+551] = 4
#     assert [z+552] = 0
#     assert [z+553] = 2
#     assert [z+554] = 10580 + shift_amount_m256
#     assert [z+555] = 4
#     assert [z+556] = 14
#     assert [z+557] = 2
#     assert [z+558] = 11550720
#     assert [z+559] = 6
#     assert [z+560] = 21
#     assert [z+561] = 2
#     assert [z+562] = 16511
#     assert [z+563] = 4
#     assert [z+564] = 45
#     assert [z+565] = 2
#     assert [z+566] = 9447680 + shift_amount_m256
#     assert [z+567] = 6
#     assert [z+568] = 0
#     assert [z+569] = 2
#     assert [z+570] = 12357 + shift_amount_m256
#     assert [z+571] = 4
#     assert [z+572] = 80
#     assert [z+573] = 2
#     assert [z+574] = 12288 + shift_amount_m256
#     assert [z+575] = 4
#     assert [z+576] = 0
#     assert [z+577] = 2
#     assert [z+578] = 14652 + shift_amount_m256
#     assert [z+579] = 4
#     assert [z+580] = 80
#     assert [z+581] = 2
#     assert [z+582] = 14592 + shift_amount_m256
#     assert [z+583] = 4
#     assert [z+584] = 33136
#     assert [z+585] = 4
#     assert [z+586] = 11097 + shift_amount_m256
#     assert [z+587] = 4
#     assert [z+588] = 5
#     assert [z+589] = 2
#     assert [z+590] = 11550720
#     assert [z+591] = 6
#     assert [z+592] = 35
#     assert [z+593] = 2
#     assert [z+594] = 16511
#     assert [z+595] = 4
#     assert [z+596] = 40
#     assert [z+597] = 2
#     assert [z+598] = 9448192 + shift_amount_m256
#     assert [z+599] = 6
#     assert [z+600] = 0
#     assert [z+601] = 2
#     assert [z+602] = 12360 + shift_amount_m256
#     assert [z+603] = 4
#     assert [z+604] = 80
#     assert [z+605] = 2
#     assert [z+606] = 12288 + shift_amount_m256
#     assert [z+607] = 4
#     assert [z+608] = 0
#     assert [z+609] = 2
#     assert [z+610] = 14909 + shift_amount_m256
#     assert [z+611] = 4
#     assert [z+612] = 80
#     assert [z+613] = 2
#     assert [z+614] = 14848 + shift_amount_m256
#     assert [z+615] = 4
#     assert [z+616] = 33136
#     assert [z+617] = 4
#     assert [z+618] = 11611 + shift_amount_m256
#     assert [z+619] = 4
#     assert [z+620] = 10
#     assert [z+621] = 2
#     assert [z+622] = 11550720
#     assert [z+623] = 6
#     assert [z+624] = 25
#     assert [z+625] = 2
#     assert [z+626] = 16511
#     assert [z+627] = 4
#     assert [z+628] = 45
#     assert [z+629] = 2
#     assert [z+630] = 9448704 + shift_amount_m256
#     assert [z+631] = 6
#     assert [z+632] = 0
#     assert [z+633] = 2
#     assert [z+634] = 13643 + shift_amount_m256
#     assert [z+635] = 4
#     assert [z+636] = 80
#     assert [z+637] = 2
#     assert [z+638] = 13568 + shift_amount_m256
#     assert [z+639] = 4

# %%
generate_single_note_manipulable(chpn_og.track_objs[2].segs[320:], '')
# Out:
#     local shift_amount_m256 = shift_amount * 256
#     assert [z+0] = 0
#     assert [z+1] = 2
#     assert [z+2] = 15418 + shift_amount_m256
#     assert [z+3] = 4
#     assert [z+4] = 80
#     assert [z+5] = 2
#     assert [z+6] = 15360 + shift_amount_m256
#     assert [z+7] = 4
#     assert [z+8] = 33136
#     assert [z+9] = 4
#     assert [z+10] = 11099 + shift_amount_m256
#     assert [z+11] = 4
#     assert [z+12] = 10
#     assert [z+13] = 2
#     assert [z+14] = 11550720
#     assert [z+15] = 6
#     assert [z+16] = 36
#     assert [z+17] = 2
#     assert [z+18] = 16511
#     assert [z+19] = 4
#     assert [z+20] = 34
#     assert [z+21] = 2
#     assert [z+22] = 9448192 + shift_amount_m256
#     assert [z+23] = 6
#     assert [z+24] = 0
#     assert [z+25] = 2
#     assert [z+26] = 12366 + shift_amount_m256
#     assert [z+27] = 4
#     assert [z+28] = 80
#     assert [z+29] = 2
#     assert [z+30] = 12288 + shift_amount_m256
#     assert [z+31] = 4
#     assert [z+32] = 0
#     assert [z+33] = 2
#     assert [z+34] = 15421 + shift_amount_m256
#     assert [z+35] = 4
#     assert [z+36] = 80
#     assert [z+37] = 2
#     assert [z+38] = 15360 + shift_amount_m256
#     assert [z+39] = 4
#     assert [z+40] = 33136
#     assert [z+41] = 4
#     assert [z+42] = 11612 + shift_amount_m256
#     assert [z+43] = 4
#     assert [z+44] = 15
#     assert [z+45] = 2
#     assert [z+46] = 11550720
#     assert [z+47] = 6
#     assert [z+48] = 20
#     assert [z+49] = 2
#     assert [z+50] = 16511
#     assert [z+51] = 4
#     assert [z+52] = 45
#     assert [z+53] = 2
#     assert [z+54] = 9448704 + shift_amount_m256
#     assert [z+55] = 6
#     assert [z+56] = 0
#     assert [z+57] = 2
#     assert [z+58] = 13645 + shift_amount_m256
#     assert [z+59] = 4
#     assert [z+60] = 80
#     assert [z+61] = 2
#     assert [z+62] = 13568 + shift_amount_m256
#     assert [z+63] = 4
#     assert [z+64] = 0
#     assert [z+65] = 2
#     assert [z+66] = 15421 + shift_amount_m256
#     assert [z+67] = 4
#     assert [z+68] = 80
#     assert [z+69] = 2
#     assert [z+70] = 15360 + shift_amount_m256
#     assert [z+71] = 4
#     assert [z+72] = 33136
#     assert [z+73] = 4
#     assert [z+74] = 12099 + shift_amount_m256
#     assert [z+75] = 4
#     assert [z+76] = 11
#     assert [z+77] = 2
#     assert [z+78] = 11550720
#     assert [z+79] = 6
#     assert [z+80] = 24
#     assert [z+81] = 2
#     assert [z+82] = 16511
#     assert [z+83] = 4
#     assert [z+84] = 45
#     assert [z+85] = 2
#     assert [z+86] = 9449216 + shift_amount_m256
#     assert [z+87] = 6
#     assert [z+88] = 0
#     assert [z+89] = 2
#     assert [z+90] = 14152 + shift_amount_m256
#     assert [z+91] = 4
#     assert [z+92] = 80
#     assert [z+93] = 2
#     assert [z+94] = 14080 + shift_amount_m256
#     assert [z+95] = 4
#     assert [z+96] = 0
#     assert [z+97] = 2
#     assert [z+98] = 15946 + shift_amount_m256
#     assert [z+99] = 4
#     assert [z+100] = 80
#     assert [z+101] = 2
#     assert [z+102] = 15872 + shift_amount_m256
#     assert [z+103] = 4
#     assert [z+104] = 33136
#     assert [z+105] = 4
#     assert [z+106] = 12361 + shift_amount_m256
#     assert [z+107] = 4
#     assert [z+108] = 15
#     assert [z+109] = 2
#     assert [z+110] = 11550720
#     assert [z+111] = 6
#     assert [z+112] = 20
#     assert [z+113] = 2
#     assert [z+114] = 16511
#     assert [z+115] = 4
#     assert [z+116] = 45
#     assert [z+117] = 2
#     assert [z+118] = 9449472 + shift_amount_m256
#     assert [z+119] = 6
#     assert [z+120] = 0
#     assert [z+121] = 2
#     assert [z+122] = 14160 + shift_amount_m256
#     assert [z+123] = 4
#     assert [z+124] = 80
#     assert [z+125] = 2
#     assert [z+126] = 14080 + shift_amount_m256
#     assert [z+127] = 4
#     assert [z+128] = 0
#     assert [z+129] = 2
#     assert [z+130] = 16464 + shift_amount_m256
#     assert [z+131] = 4
#     assert [z+132] = 80
#     assert [z+133] = 2
#     assert [z+134] = 16384 + shift_amount_m256
#     assert [z+135] = 4
#     assert [z+136] = 33136
#     assert [z+137] = 4
#     assert [z+138] = 12877 + shift_amount_m256
#     assert [z+139] = 4
#     assert [z+140] = 14
#     assert [z+141] = 2
#     assert [z+142] = 11550720
#     assert [z+143] = 6
#     assert [z+144] = 21
#     assert [z+145] = 2
#     assert [z+146] = 16511
#     assert [z+147] = 4
#     assert [z+148] = 45
#     assert [z+149] = 2
#     assert [z+150] = 9449984 + shift_amount_m256
#     assert [z+151] = 6
#     assert [z+152] = 0
#     assert [z+153] = 2
#     assert [z+154] = 14164 + shift_amount_m256
#     assert [z+155] = 4
#     assert [z+156] = 80
#     assert [z+157] = 2
#     assert [z+158] = 14080 + shift_amount_m256
#     assert [z+159] = 4
#     assert [z+160] = 0
#     assert [z+161] = 2
#     assert [z+162] = 16724 + shift_amount_m256
#     assert [z+163] = 4
#     assert [z+164] = 80
#     assert [z+165] = 2
#     assert [z+166] = 16640 + shift_amount_m256
#     assert [z+167] = 4
#     assert [z+168] = 33136
#     assert [z+169] = 4
#     assert [z+170] = 13414 + shift_amount_m256
#     assert [z+171] = 4
#     assert [z+172] = 11
#     assert [z+173] = 2
#     assert [z+174] = 11550720
#     assert [z+175] = 6
#     assert [z+176] = 24
#     assert [z+177] = 2
#     assert [z+178] = 16511
#     assert [z+179] = 4
#     assert [z+180] = 45
#     assert [z+181] = 2
#     assert [z+182] = 9450496 + shift_amount_m256
#     assert [z+183] = 6
#     assert [z+184] = 0
#     assert [z+185] = 2
#     assert [z+186] = 15450 + shift_amount_m256
#     assert [z+187] = 4
#     assert [z+188] = 80
#     assert [z+189] = 2
#     assert [z+190] = 15360 + shift_amount_m256
#     assert [z+191] = 4
#     assert [z+192] = 0
#     assert [z+193] = 2
#     assert [z+194] = 17223 + shift_amount_m256
#     assert [z+195] = 4
#     assert [z+196] = 80
#     assert [z+197] = 2
#     assert [z+198] = 17152 + shift_amount_m256
#     assert [z+199] = 4
#     assert [z+200] = 33136
#     assert [z+201] = 4
#     assert [z+202] = 10826 + shift_amount_m256
#     assert [z+203] = 4
#     assert [z+204] = 15
#     assert [z+205] = 2
#     assert [z+206] = 11550720
#     assert [z+207] = 6
#     assert [z+208] = 20
#     assert [z+209] = 2
#     assert [z+210] = 16511
#     assert [z+211] = 4
#     assert [z+212] = 45
#     assert [z+213] = 2
#     assert [z+214] = 9447936 + shift_amount_m256
#     assert [z+215] = 6
#     assert [z+216] = 0
#     assert [z+217] = 2
#     assert [z+218] = 13119 + shift_amount_m256
#     assert [z+219] = 4
#     assert [z+220] = 80
#     assert [z+221] = 2
#     assert [z+222] = 13056 + shift_amount_m256
#     assert [z+223] = 4
#     assert [z+224] = 0
#     assert [z+225] = 2
#     assert [z+226] = 15410 + shift_amount_m256
#     assert [z+227] = 4
#     assert [z+228] = 80
#     assert [z+229] = 2
#     assert [z+230] = 15360 + shift_amount_m256
#     assert [z+231] = 4
#     assert [z+232] = 33136
#     assert [z+233] = 4
#     assert [z+234] = 11065 + shift_amount_m256
#     assert [z+235] = 4
#     assert [z+236] = 15
#     assert [z+237] = 2
#     assert [z+238] = 11550720
#     assert [z+239] = 6
#     assert [z+240] = 20
#     assert [z+241] = 2
#     assert [z+242] = 16511
#     assert [z+243] = 4
#     assert [z+244] = 45
#     assert [z+245] = 2
#     assert [z+246] = 9448192 + shift_amount_m256
#     assert [z+247] = 6
#     assert [z+248] = 0
#     assert [z+249] = 2
#     assert [z+250] = 13373 + shift_amount_m256
#     assert [z+251] = 4
#     assert [z+252] = 80
#     assert [z+253] = 2
#     assert [z+254] = 13312 + shift_amount_m256
#     assert [z+255] = 4
#     assert [z+256] = 0
#     assert [z+257] = 2
#     assert [z+258] = 15416 + shift_amount_m256
#     assert [z+259] = 4
#     assert [z+260] = 80
#     assert [z+261] = 2
#     assert [z+262] = 15360 + shift_amount_m256
#     assert [z+263] = 4
#     assert [z+264] = 33136
#     assert [z+265] = 4
#     assert [z+266] = 11067 + shift_amount_m256
#     assert [z+267] = 4
#     assert [z+268] = 16
#     assert [z+269] = 2
#     assert [z+270] = 11550720
#     assert [z+271] = 6
#     assert [z+272] = 19
#     assert [z+273] = 2
#     assert [z+274] = 16511
#     assert [z+275] = 4
#     assert [z+276] = 45
#     assert [z+277] = 2
#     assert [z+278] = 9448192 + shift_amount_m256
#     assert [z+279] = 6
#     assert [z+280] = 0
#     assert [z+281] = 2
#     assert [z+282] = 13621 + shift_amount_m256
#     assert [z+283] = 4
#     assert [z+284] = 80
#     assert [z+285] = 2
#     assert [z+286] = 13568 + shift_amount_m256
#     assert [z+287] = 4
#     assert [z+288] = 0
#     assert [z+289] = 2
#     assert [z+290] = 15145 + shift_amount_m256
#     assert [z+291] = 4
#     assert [z+292] = 80
#     assert [z+293] = 2
#     assert [z+294] = 15104 + shift_amount_m256
#     assert [z+295] = 4
#     assert [z+296] = 33136
#     assert [z+297] = 4
#     assert [z+298] = 14121 + shift_amount_m256
#     assert [z+299] = 4
#     assert [z+300] = 0
#     assert [z+301] = 2
#     assert [z+302] = 9264 + shift_amount_m256
#     assert [z+303] = 4
#     assert [z+304] = 15
#     assert [z+305] = 2
#     assert [z+306] = 11550720
#     assert [z+307] = 6
#     assert [z+308] = 27
#     assert [z+309] = 2
#     assert [z+310] = 16511
#     assert [z+311] = 4
#     assert [z+312] = 38
#     assert [z+313] = 2
#     assert [z+314] = 9446400 + shift_amount_m256
#     assert [z+315] = 6
#     assert [z+316] = 0
#     assert [z+317] = 2
#     assert [z+318] = 11049 + shift_amount_m256
#     assert [z+319] = 4
#     assert [z+320] = 80
#     assert [z+321] = 2
#     assert [z+322] = 11008 + shift_amount_m256
#     assert [z+323] = 4
#     assert [z+324] = 0
#     assert [z+325] = 2
#     assert [z+326] = 13348 + shift_amount_m256
#     assert [z+327] = 4
#     assert [z+328] = 80
#     assert [z+329] = 2
#     assert [z+330] = 13312 + shift_amount_m256
#     assert [z+331] = 4
#     assert [z+332] = 33056
#     assert [z+333] = 4
#     assert [z+334] = 14080 + shift_amount_m256
#     assert [z+335] = 4
#     assert [z+336] = 0
#     assert [z+337] = 2
#     assert [z+338] = 14633 + shift_amount_m256
#     assert [z+339] = 4
#     assert [z+340] = 80
#     assert [z+341] = 2
#     assert [z+342] = 14592 + shift_amount_m256
#     assert [z+343] = 4
#     assert [z+344] = 0
#     assert [z+345] = 2
#     assert [z+346] = 9264 + shift_amount_m256
#     assert [z+347] = 4
#     assert [z+348] = 18
#     assert [z+349] = 2
#     assert [z+350] = 11550720
#     assert [z+351] = 6
#     assert [z+352] = 14
#     assert [z+353] = 2
#     assert [z+354] = 16511
#     assert [z+355] = 4
#     assert [z+356] = 48
#     assert [z+357] = 2
#     assert [z+358] = 9446400 + shift_amount_m256
#     assert [z+359] = 6
#     assert [z+360] = 0
#     assert [z+361] = 2
#     assert [z+362] = 11049 + shift_amount_m256
#     assert [z+363] = 4
#     assert [z+364] = 80
#     assert [z+365] = 2
#     assert [z+366] = 11008 + shift_amount_m256
#     assert [z+367] = 4
#     assert [z+368] = 0
#     assert [z+369] = 2
#     assert [z+370] = 13614 + shift_amount_m256
#     assert [z+371] = 4
#     assert [z+372] = 80
#     assert [z+373] = 2
#     assert [z+374] = 13568 + shift_amount_m256
#     assert [z+375] = 4
#     assert [z+376] = 33136
#     assert [z+377] = 4
#     assert [z+378] = 9264 + shift_amount_m256
#     assert [z+379] = 4
#     assert [z+380] = 10
#     assert [z+381] = 2
#     assert [z+382] = 11550720
#     assert [z+383] = 6
#     assert [z+384] = 25
#     assert [z+385] = 2
#     assert [z+386] = 16511
#     assert [z+387] = 4
#     assert [z+388] = 45
#     assert [z+389] = 2
#     assert [z+390] = 9446400 + shift_amount_m256
#     assert [z+391] = 6
#     assert [z+392] = 0
#     assert [z+393] = 2
#     assert [z+394] = 14121 + shift_amount_m256
#     assert [z+395] = 4
#     assert [z+396] = 0
#     assert [z+397] = 2
#     assert [z+398] = 11049 + shift_amount_m256
#     assert [z+399] = 4
#     assert [z+400] = 80
#     assert [z+401] = 2
#     assert [z+402] = 11008 + shift_amount_m256
#     assert [z+403] = 4
#     assert [z+404] = 0
#     assert [z+405] = 2
#     assert [z+406] = 13348 + shift_amount_m256
#     assert [z+407] = 4
#     assert [z+408] = 80
#     assert [z+409] = 2
#     assert [z+410] = 13312 + shift_amount_m256
#     assert [z+411] = 4
#     assert [z+412] = 33056
#     assert [z+413] = 4
#     assert [z+414] = 14080 + shift_amount_m256
#     assert [z+415] = 4
#     assert [z+416] = 0
#     assert [z+417] = 2
#     assert [z+418] = 14633 + shift_amount_m256
#     assert [z+419] = 4
#     assert [z+420] = 80
#     assert [z+421] = 2
#     assert [z+422] = 14592 + shift_amount_m256
#     assert [z+423] = 4
#     assert [z+424] = 0
#     assert [z+425] = 2
#     assert [z+426] = 9264 + shift_amount_m256
#     assert [z+427] = 4
#     assert [z+428] = 19
#     assert [z+429] = 2
#     assert [z+430] = 11550720
#     assert [z+431] = 6
#     assert [z+432] = 13
#     assert [z+433] = 2
#     assert [z+434] = 16511
#     assert [z+435] = 4
#     assert [z+436] = 48
#     assert [z+437] = 2
#     assert [z+438] = 9446400 + shift_amount_m256
#     assert [z+439] = 6
#     assert [z+440] = 0
#     assert [z+441] = 2
#     assert [z+442] = 11049 + shift_amount_m256
#     assert [z+443] = 4
#     assert [z+444] = 80
#     assert [z+445] = 2
#     assert [z+446] = 11008 + shift_amount_m256
#     assert [z+447] = 4
#     assert [z+448] = 0
#     assert [z+449] = 2
#     assert [z+450] = 13604 + shift_amount_m256
#     assert [z+451] = 4
#     assert [z+452] = 80
#     assert [z+453] = 2
#     assert [z+454] = 13568 + shift_amount_m256
#     assert [z+455] = 4
#     assert [z+456] = 33136
#     assert [z+457] = 4
#     assert [z+458] = 9264 + shift_amount_m256
#     assert [z+459] = 4
#     assert [z+460] = 17
#     assert [z+461] = 2
#     assert [z+462] = 11550720
#     assert [z+463] = 6
#     assert [z+464] = 18
#     assert [z+465] = 2
#     assert [z+466] = 16511
#     assert [z+467] = 4
#     assert [z+468] = 45
#     assert [z+469] = 2
#     assert [z+470] = 9446400 + shift_amount_m256
#     assert [z+471] = 6
#     assert [z+472] = 0
#     assert [z+473] = 2
#     assert [z+474] = 11049 + shift_amount_m256
#     assert [z+475] = 4
#     assert [z+476] = 80
#     assert [z+477] = 2
#     assert [z+478] = 11008 + shift_amount_m256
#     assert [z+479] = 4
#     assert [z+480] = 0
#     assert [z+481] = 2
#     assert [z+482] = 14116 + shift_amount_m256
#     assert [z+483] = 4
#     assert [z+484] = 80
#     assert [z+485] = 2
#     assert [z+486] = 14080 + shift_amount_m256
#     assert [z+487] = 4
#     assert [z+488] = 33136
#     assert [z+489] = 4
#     assert [z+490] = 9264 + shift_amount_m256
#     assert [z+491] = 4
#     assert [z+492] = 17
#     assert [z+493] = 2
#     assert [z+494] = 11550720
#     assert [z+495] = 6
#     assert [z+496] = 17
#     assert [z+497] = 2
#     assert [z+498] = 16511
#     assert [z+499] = 4
#     assert [z+500] = 46
#     assert [z+501] = 2
#     assert [z+502] = 9446400 + shift_amount_m256
#     assert [z+503] = 6
#     assert [z+504] = 0
#     assert [z+505] = 2
#     assert [z+506] = 11050 + shift_amount_m256
#     assert [z+507] = 4
#     assert [z+508] = 80
#     assert [z+509] = 2
#     assert [z+510] = 11008 + shift_amount_m256
#     assert [z+511] = 4
#     assert [z+512] = 0
#     assert [z+513] = 2
#     assert [z+514] = 14119 + shift_amount_m256
#     assert [z+515] = 4
#     assert [z+516] = 80
#     assert [z+517] = 2
#     assert [z+518] = 14080 + shift_amount_m256
#     assert [z+519] = 4
#     assert [z+520] = 33136
#     assert [z+521] = 4
#     assert [z+522] = 9264 + shift_amount_m256
#     assert [z+523] = 4
#     assert [z+524] = 17
#     assert [z+525] = 2
#     assert [z+526] = 11550720
#     assert [z+527] = 6
#     assert [z+528] = 22
#     assert [z+529] = 2
#     assert [z+530] = 16511
#     assert [z+531] = 4
#     assert [z+532] = 41
#     assert [z+533] = 2
#     assert [z+534] = 9446400 + shift_amount_m256
#     assert [z+535] = 6
#     assert [z+536] = 0
#     assert [z+537] = 2
#     assert [z+538] = 11048 + shift_amount_m256
#     assert [z+539] = 4
#     assert [z+540] = 80
#     assert [z+541] = 2
#     assert [z+542] = 11008 + shift_amount_m256
#     assert [z+543] = 4
#     assert [z+544] = 0
#     assert [z+545] = 2
#     assert [z+546] = 14115 + shift_amount_m256
#     assert [z+547] = 4
#     assert [z+548] = 80
#     assert [z+549] = 2
#     assert [z+550] = 14080 + shift_amount_m256
#     assert [z+551] = 4
#     assert [z+552] = 33136
#     assert [z+553] = 4
#     assert [z+554] = 9258 + shift_amount_m256
#     assert [z+555] = 4
#     assert [z+556] = 16
#     assert [z+557] = 2
#     assert [z+558] = 11550720
#     assert [z+559] = 6
#     assert [z+560] = 19
#     assert [z+561] = 2
#     assert [z+562] = 16511
#     assert [z+563] = 4
#     assert [z+564] = 45
#     assert [z+565] = 2
#     assert [z+566] = 9446400 + shift_amount_m256
#     assert [z+567] = 6
#     assert [z+568] = 0
#     assert [z+569] = 2
#     assert [z+570] = 11045 + shift_amount_m256
#     assert [z+571] = 4
#     assert [z+572] = 80
#     assert [z+573] = 2
#     assert [z+574] = 11008 + shift_amount_m256
#     assert [z+575] = 4
#     assert [z+576] = 0
#     assert [z+577] = 2
#     assert [z+578] = 14110 + shift_amount_m256
#     assert [z+579] = 4
#     assert [z+580] = 80
#     assert [z+581] = 2
#     assert [z+582] = 14080 + shift_amount_m256
#     assert [z+583] = 4
#     assert [z+584] = 33136
#     assert [z+585] = 4
#     assert [z+586] = 9254 + shift_amount_m256
#     assert [z+587] = 4
#     assert [z+588] = 9
#     assert [z+589] = 2
#     assert [z+590] = 11550720
#     assert [z+591] = 6
#     assert [z+592] = 23
#     assert [z+593] = 2
#     assert [z+594] = 16511
#     assert [z+595] = 4
#     assert [z+596] = 48
#     assert [z+597] = 2
#     assert [z+598] = 9448225 + shift_amount_m256
#     assert [z+599] = 6
#     assert [z+600] = 80
#     assert [z+601] = 2
#     assert [z+602] = 12325 + shift_amount_m256
#     assert [z+603] = 4
#     assert [z+604] = 80
#     assert [z+605] = 2
#     assert [z+606] = 13346 + shift_amount_m256
#     assert [z+607] = 4
#     assert [z+608] = 80
#     assert [z+609] = 2
#     assert [z+610] = 14118 + shift_amount_m256
#     assert [z+611] = 4
#     assert [z+612] = 34048
#     assert [z+613] = 4
#     assert [z+614] = 14080 + shift_amount_m256
#     assert [z+615] = 4
#     assert [z+616] = 0
#     assert [z+617] = 2
#     assert [z+618] = 12288 + shift_amount_m256
#     assert [z+619] = 4
#     assert [z+620] = 0
#     assert [z+621] = 2
#     assert [z+622] = 9216 + shift_amount_m256
#     assert [z+623] = 4
#     assert [z+624] = 0
#     assert [z+625] = 2
#     assert [z+626] = 11008 + shift_amount_m256
#     assert [z+627] = 4
#     assert [z+628] = 0
#     assert [z+629] = 2
#     assert [z+630] = 13312 + shift_amount_m256
#     assert [z+631] = 4
#     assert [z+632] = 33331
#     assert [z+633] = 4
#     assert [z+634] = 11550720
#     assert [z+635] = 6
#     assert [z+636] = 0
#     assert [z+637] = 2
#     assert [z+638] = 16723712
#     assert [z+639] = 6

# %% [markdown]
# ### track three to end

# %%
hexstring = ''
#for track in chpn.track_objs[3:]:
for track in chpn.track_objs[3:]:
    for event in track.segs:
        hexstring += event_to_hexstring_no_omittance(event)

# %%
generate_single(hexstring, 'music_3to6')
# Out:
# @view
# func music_3to6 {
#         range_check_ptr
#     } () -> (
#         z_len : felt,
#         z : felt*
#     ):
#     alloc_locals
#
#     let (local z) = alloc()
#
#     assert [z+0] = 136630055383401265450026481975897785629628796645206062477878610220790214446
#     assert [z+1] = 86799204449262242841506209475406639191495463763289587680747166378917830979
#     assert [z+2] = 196896293983749844085133960720503419841174072837427151471105177045055137637
#     assert [z+3] = 201427445120937909719305475177723715238454465423221075366242329356546369889
#     assert [z+4] = 195120495690111691153414471557661700819694411966667018762683761288135930985
#     assert [z+5] = 9706972061181884266817624211700865765945088
#     assert [z+6] = 36
#     let z_len = 7
#
#     return (z_len, z)
# end
