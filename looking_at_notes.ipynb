# %%
import mido
import sys
import binascii
import pprint
from collections import OrderedDict
from mido import Message, MidiFile, MidiTrack
from enum import Enum

# %%
'''
C C# D D# E F F# G G# A A# B
'''
NOTES = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
MAP_DEC_TO_NOTE = {}
MAP_NOTE_TO_DEC = {}
octave = -1
i = 0
j = 0
while i<128:
    MAP_DEC_TO_NOTE[ i ] = NOTES[j] + '_' + str(octave)
    MAP_NOTE_TO_DEC[ NOTES[j] + '_' + str(octave) ] = i
    if j == len(NOTES)-1:
        j = 0
        octave += 1
    else:
        j += 1
    i += 1

# %% [markdown]
# ### State machine to parse raw midi track

# %%
### Need to deal with variable length -- for both "len" of meta-event, and "delta-time"
### Need to deal with running status -- http://midi.teragonaudio.com/tech/midispec/run.htm

MSB_1 = ['8', '9', 'a', 'b', 'c', 'd', 'e', 'f']

## TODO: ff00
## TODO: ff20, 21
## TODO: ff7f
## TODO: running status for all events

END_OF_TRACK = 'ff2f00'
TEXT_META_EVENTS = [f'ff0{i+1}' for i in range(9)]
TEMPO = 'ff5103'
SMPTE = 'ff5405'
TIME_SIG = 'ff5804'
KEY_SIG = 'ff5902'

class Track:
    def __init__(self, track):
        self.track = track
        self._parse()
    
    def _get_varlen_value (self, string):
        value = ''
        j = 0
        while True:
            if string[j] not in MSB_1: # reached last byte of variable-length field
                value = string[0:j+2]
                break
            else:
                j += 2
        return value
        
    def _varFieldToInt(self, hexstring):
        ret = 0
        current_byte = ''

        i=0
        while len(hexstring):
            current_byte = "0x" + hexstring[0:2]
            current_integer = int(current_byte, 16)
            ret = (ret << 7) | (current_integer & 0x7f)
            if not current_integer & 0x80:
                return ret
            hexstring = hexstring[2:]

            i += 1
            if i>1000:
                print('error')
                break
    
    def _parse(self):
        D = []
        
        assert self.track[0:8] == '4d54726b'
        self.chunklen = self.track[8:8+8]
        D.append({'type':'header', 'value':'4d54726b'})
        D.append({'type':'chunklen', 'value':self.track[8:8+8]})
        
        track = self.track[16:]
        i = 0
        state = 'delta-time' # state in ['delta-time', 'event']
        while True:
            if state == 'delta-time':
                value = self._get_varlen_value(track[i:])
                D.append( {'type':'delta time', 'value':value} )
                i += len(value)
                state = 'event'
                continue
                
            else: # state == 'event'
                running = False
                ## first decode event
                if track[i] not in MSB_1: # running status in use
                    event = last_event # for note on / note off / control change / program change - include channel n
                    running = True
                else:
                    track_first6 = track[i:i+6]
                    track_first4 = track[i:i+4]
                    track_first = track[i]
                    if track_first6 == END_OF_TRACK: # end of track; ff 2f 00
                        event = END_OF_TRACK
                    elif track_first6 == TIME_SIG: # ff 58 04 nn dd cc bb
                        event = TIME_SIG
                    elif track_first6 == KEY_SIG: # ff 59 02 sf mi
                        event = KEY_SIG
                    elif track_first6 == TEMPO: # ff 51 03 tt tt tt
                        event = TEMPO
                    elif track_first6 == SMPTE: # ff 54 05 hr mn se fr ff
                        event = SMPTE
                    elif track_first4 in TEXT_META_EVENTS:
                        event = track_first4
                    elif track_first in ['b','c','8','9']:
                        event = track[i:i+2]
                    
                ## then parse event and append to event list
                if event == END_OF_TRACK: # end of track; ff 2f 00
                    D.append( {'type':'end of track', 'type hex':END_OF_TRACK, 'value':''} )
                    break
                
                elif event == TIME_SIG: # ff 58 04 nn dd cc bb
                    D.append( {'type':'time signature', 'type hex':track_first6, 'value':track[i+6:i+6+8]} )
                    i += 14
                    
                elif event == KEY_SIG: # ff 59 02 sf mi
                    D.append( {'type':'key signature', 'type hex':track_first6, 'value':track[i+6:i+6+4]} )
                    i += 10
                
                elif event == TEMPO: # ff 51 03 tt tt tt
                    D.append( {'type':'tempo', 'type hex':track_first6, 'value':track[i+6:i+6+6]} )
                    i += 12
                
                elif event == SMPTE: # ff 54 05 hr mn se fr ff
                    D.append( {'type':'smpte', 'type hex':track_first6, 'value':track[i+6:i+6+10]} )
                    i += 16
                    
                # sequence/track name (ff 03 length text)
                # or marker (ff 06 length text)
                # or cue (ff 07 length text)
                elif event in TEXT_META_EVENTS:
                    if running:
                        name_length_varlen = self._get_varlen_value(track)
                        name_length = self._varFieldToInt(name_length_varlen)
                        name = track[i + len(name_length_varlen) : i + len(name_length_varlen) + name_length*2]
                        D.append( {'type':'text meta event', 'type hex':event, 'omitted':True,
                                   'length_varlen':name_length_varlen, 'name':name} )
                        i += len(name_length_varlen) + name_length*2 # name_length * byte, every byte == 2 hex
                    else:
                        name_length_varlen = self._get_varlen_value(track[i+4:])
                        name_length = self._varFieldToInt(name_length_varlen)
                        name = track[i + 4 + len(name_length_varlen) : i + 4 + len(name_length_varlen) + name_length*2]
                        D.append( {'type':'text meta event', 'type hex':track_first4, 'omitted':False,
                                   'length_varlen':name_length_varlen, 'name':name} )
                        i += 4 + len(name_length_varlen) + name_length*2 # name_length * byte, every byte == 2 hex
                
                # Assuming only bn/cn/8n/9n can use running-status
                elif event[0] == 'b': # control change; bn controller value
                    if running:
                        D.append( {'type':'control change', 'type hex':'b', 'omitted':True,
                                   'channel':event[1], 'controller':track[i:i+2], 'value':track[i+2:i+4]} )
                        i += 4
                    else:
                        D.append( {'type':'control change', 'type hex':'b', 'omitted':False,
                                   'channel':track[i+1], 'controller':track[i+2:i+4], 'value':track[i+4:i+6]} )
                        i += 6
                
                elif event[0] == 'c': # program change; cn program
                    if running:
                        D.append( {'type':'program change', 'type hex':'c', 'omitted':True,
                                   'channel':event[1], 'program':track[i:i+2]} )
                        i += 2
                    else:
                        D.append( {'type':'program change', 'type hex':'c', 'omitted':False,
                                   'channel':track[i+1], 'program':track[i+2:i+4]} )
                        i += 4
                
                elif event[0] == '9': # note on; 9n note velocity
                    if running:
                        D.append( {'type':'note on', 'type hex':'9', 'omitted':True,
                                   'channel':event[1], 'note':track[i:i+2], 'velocity':track[i+2:i+4]} )
                        i += 4
                    else:
                        D.append( {'type':'note on', 'type hex':'9', 'omitted':False,
                                   'channel':track[i+1], 'note':track[i+2:i+4], 'velocity':track[i+4:i+6]} )
                        i += 6
                    
                elif track_first == '8': # note off; 8n note velocity
                    if running:
                        D.append( {'type':'note off', 'type hex':'8', 'omitted':True,
                                   'channel':event[1], 'note':track[i:i+2], 'velocity':track[i+2:i+4]} )
                        i += 4
                    else:
                        D.append( {'type':'note off', 'type hex':'8', 'omitted':False,
                                   'channel':track[i+1], 'note':track[i+2:i+4], 'velocity':track[i+4:i+6]} )
                        i += 6
                
                last_event = event
                state = 'delta-time'
                
        self.segs = D    
    
    def segs_to_hexstring(self): # segs is list of events, each event is a dictionary
        hexstring = ''

        for event in self.segs:
            hexstring += Track.event_to_hexstring(event)
        return hexstring

    @staticmethod
    def event_to_hexstring(event):
        if event['type'] == 'header' or event['type'] == 'chunklen' or event['type'] == 'delta time':
            hexstring = event['value']

        elif event['type'] == 'end of track':
            hexstring = event['type hex']

        elif event['type'] == 'text meta event':
            hexstring = event['type hex']*(not event['omitted']) + event['length_varlen'] + event['name']

        elif event['type'] in ['time signature', 'key signature', 'tempo', 'smpte']:
            hexstring = event['type hex'] + event['value']

        elif event['type'] == 'control change':
            hexstring = (event['type hex']+event['channel'])*(not event['omitted']) + event['controller'] + event['value']

        elif event['type'] == 'program change':
            hexstring = (event['type hex']+event['channel'])*(not event['omitted']) + event['program']

        elif event['type'] == 'note on' or event['type'] == 'note off':
            hexstring = (event['type hex']+event['channel'])*(not event['omitted']) + event['note'] + event['velocity']

        return hexstring

# %%
class Music:
    def __init__(self, name):
        self._parse_midi(name)
        self.name = name
    
    def _parse_midi(self, name):
        midi_file = f'./{name}.mid'

        with open(midi_file, 'rb') as f:
            hexdata = binascii.hexlify(f.read())
        hexdata_str = hexdata.decode("utf-8")

        MTrk = '4d54726b'
        tracks_str = []
        for i,chunk in enumerate(hexdata_str.split(MTrk)):
            if i == 0:
                header_str = chunk
            else:
                tracks_str.append (MTrk + chunk)

        track_objs = [Track(t) for t in tracks_str]
        
        self.header_str = header_str
        self.track_objs = track_objs

    def keyshift(self, shift_amount):
        track_objs = self.track_objs.copy()
        for obj in track_objs:
            for event in obj.segs:
                if event['type'] == 'note on' or event['type'] == 'note off':
                    note_hex = '0x'+event['note']
                    note_integer = int(note_hex, 16)
                    note_integer_shifted = note_integer + shift_amount
                    note_hex_shifted = hex(note_integer_shifted)[2:]
                    note_hex_shifted = note_hex_shifted.rjust(2, '0')
                    event['note'] = note_hex_shifted
        self.track_objs = track_objs
    
    def export_midi(self, name):
        recovered_tracks = [T.segs_to_hexstring() for T in self.track_objs]
        with open(f'{name}.mid', 'wb') as fout:
            fout.write( binascii.unhexlify(self.header_str + ''.join(recovered_tracks)) )

# %%
chopin = Music('chpn_op25_e1')
chopin.keyshift(2)
chopin.export_midi('chpn_op25_up2')

# %%
for i,track in enumerate(chopin.track_objs):
    for event in track.segs:
        if event['type'] == 'tempo':
            print(i, 'tempo')
            break
        if event['type'] == 'note on':
            print(i, 'note')
            break
# Out:
# 0 tempo
# 1 note
# 2 note
# 3 note

# %%
chpn = Music('chpn-p1')
for i,track in enumerate(chpn.track_objs):
    for event in track.segs:
        if event['type'] == 'tempo':
            print(i, 'tempo')
            break
        if event['type'] == 'note on':
            print(i, 'note')
            break
len(chpn.track_objs)
# Out:
# 0 tempo
# 1 note
# 2 note
# 7

# %%
n1 = 0
n2 = 0
for i in [0,1,2]:
    for event in chpn.track_objs[i].segs:
        if event['type'] == 'note on':
            n1 += 1
        elif event['type'] == 'note off':
            n2 += 1
    print(n1, n2)
# Out:
# 0 0
# 408 0
# 654 0

# %% [markdown]
# ---

# %% [markdown]
# ### Converting to Cairo contract

# %%
class CairoMidi:
    def __init__(self, music):
        ## music is a Music object
        self.music = music
        self.name = self.music.name
        self._init_template()
    
    def generate_single(self):
        MEAT = []
        
        MEAT.append( '@view')
        MEAT.append(f'func {self.name} {{')
        MEAT.append( '        range_check_ptr')
        MEAT.append( '    } () -> (')
        MEAT.append( '        z_len : felt,')
        MEAT.append( '        z : felt*')
        MEAT.append( '    ):')
        MEAT.append( '    alloc_locals\n')
        MEAT.append( '    let (local z) = alloc()\n')
        
        hexstring = ''.join( [T.segs_to_hexstring() for T in self.music.track_objs] )
        hexstring = self.music.header_str + hexstring
        arr = self._convert_hex_to_arr(hexstring)
        for i,num in enumerate(arr):
            MEAT.append(f'    assert [z+{i}] = {num}')
        MEAT.append(f'    let z_len = {i+1}')
        
        FOOTER = []
        FOOTER.append('\n    return (z_len, z)')
        FOOTER.append('end')
        
        self.contract = self.header + MEAT + FOOTER
    
    def generate_note_manipulable(self): # tracks 1-3
        pass
    
    def generate_tempo_manipulable(self):
        ## note on / note off event -- add shift_amount
        ## tempo event -- add multiplier & divider
        
        MEAT = []
        tempo_track = self.music.track_objs[0]
        music_tracks = self.music.track_objs[1:]
        
        MEAT.append( '@view')
        MEAT.append(f'func {self.name}_tempo {{')
        MEAT.append( '        range_check_ptr')
        MEAT.append( '    } (')
        MEAT.append( '        tempo_multiplier : felt,')
        MEAT.append( '        tempo_divider : felt')
        MEAT.append( '    ) -> (')
        MEAT.append( '        z_len : felt,')
        MEAT.append( '        z : felt*')
        MEAT.append( '    ):')
        MEAT.append( '    alloc_locals\n')
        MEAT.append( '    let (local z) = alloc()\n')
        i = 0
        for event in tempo_track.segs:
            if event['type'] != 'tempo':
                event_hex = Track.event_to_hexstring(event)
                s = event_hex
                while( len(s)>62 ):
                    felt_hex = s[0:62]
                    MEAT.append( f'    assert [z+{i}] = {int(felt_hex, 16)}' )
                    MEAT.append( f'    assert [z+{i+1}] = 62' )
                    s = s[62:]
                    i += 2
                felt_hex = s
                last_length = len(felt_hex)
                MEAT.append( f'    assert [z+{i}] = {int(felt_hex, 16)}' )
                MEAT.append( f'    assert [z+{i+1}] = {last_length}' )
                i += 2
            else:
                event_integer = int(event['type hex'], 16)
                event_length  = len(event['type hex'])
                value_integer = int(event['value'], 16)
                value_length  = len(event['value'])
                assert value_length == 6
                MEAT.append( f'    assert [z+{i}] = {event_integer}\n' )
                MEAT.append( f'    assert [z+{i+1}] = {event_length}\n' )
                MEAT.append( f'    tempvar value_ = {value_integer} * tempo_multiplier\n' )
                MEAT.append( f'    let (adjusted_value, _) = unsigned_div_rem(value_, tempo_divider)\n' )
                MEAT.append( f'    assert [z+{i+2}] = adjusted_value\n' )
                MEAT.append( f'    assert [z+{i+3}] = 6' ) # the hex-length of tempo value is always 6
                i += 4
        MEAT.append(f'    let z_len = {i+1}')
        MEAT.append('\n    return (z_len, z)')
        MEAT.append('end')
        
        MEAT.append( '\n@view')
        MEAT.append(f'func {self.name}_music {{')
        MEAT.append( '        range_check_ptr')
        MEAT.append( '    } () -> (')
        MEAT.append( '        z_len : felt,')
        MEAT.append( '        z : felt*')
        MEAT.append( '    ):')
        MEAT.append( '    alloc_locals\n')
        MEAT.append( '    let (local z) = alloc()\n')
        
        hexstring = ''.join( [T.segs_to_hexstring() for T in music_tracks] )
        hexstring = self.music.header_str + hexstring
        arr = self._convert_hex_to_arr(hexstring)
        for i,num in enumerate(arr):
            MEAT.append(f'    assert [z+{i}] = {num}')
        MEAT.append(f'    let z_len = {i+1}')
        MEAT.append('\n    return (z_len, z)')
        MEAT.append('end')
                            
        self.contract = self.header + MEAT
                            
    def print_contract(self):
        for line in self.contract:
            print(line)
    
    def export_contract(self, appendix=''):
        contract_str = '\n'.join(self.contract)
        if appendix:
            apdx = f'_{appendix}'
        else:
            apdx = ''
        with open(f'{self.name+apdx}.cairo', 'w') as f:
            f.write(contract_str)
    
    def _init_template(self):
        # generate a single contract
        HEADER = []
        HEADER.append( '%lang starknet')
        HEADER.append( '%builtins pedersen range_check')
        HEADER.append( 'from starkware.cairo.common.cairo_builtins import HashBuiltin')
        HEADER.append( 'from starkware.cairo.common.alloc import alloc')
        HEADER.append( 'from starkware.cairo.common.math import (unsigned_div_rem)\n')
        self.header = HEADER
    
    def _convert_hex_to_arr(self, hexstring):
        '''
        last element of the felt array is an integer indicating the hex-length of the last felt value
        '''
        arr = []
        s = hexstring
        while( len(s)>62 ):
            felt_hex = s[0:62]
            arr.append( int(felt_hex, 16) )
            s = s[62:]
        felt_hex = s
        last_length = len(felt_hex)
        arr.append( int(felt_hex, 16) )
        arr.append(last_length)
        
        return arr

# %%
chopin = Music('chpn_op25_e1')
cm = CairoMidi(chopin)
#cm.generate_tempo_manipulable()
#cm.export_contract('tempo')
# cm.generate_single()
# cm.export_contract()

# %%
n1 = 0
n2 = 0
for i in [1,2,3]:
    for event in chopin.track_objs[i].segs:
        if event['type'] == 'note on':
            n1 += 1
        elif event['type'] == 'note off':
            n2 += 1
    print(n1, n2)
# Out:
# 360 0
# 2272 0
# 4444 0

# %%
arr = []
for event in chopin.track_objs[1].segs:
    if 'note' not in event['type']:
        event_hex = Track.event_to_hexstring(event)
        s = event_hex
        while( len(s)>62 ):
            felt_hex = s[0:62]
            arr.append( f'    assert [z+{i}] = {int(felt_hex, 16)}' )
            arr.append( f'    assert [z+{i+1}] = 62' )
            s = s[62:]
            i += 2
        felt_hex = s
        last_length = len(felt_hex)
        arr.append( f'    assert [z+{i}] = {int(felt_hex, 16)}' )
        arr.append( f'    assert [z+{i+1}] = {last_length}' )
        i += 2
    else:
        event_integer = int(event['type hex']+event['channel'], 16)
        arr.append( f'    assert [z+{i}] = {event_integer}' )
        arr.append( f'    assert [z+{i+1}] = 2' )
        
        note_integer = int(event['note'], 16)
        arr.append( f'    assert [z+{i+2}] = {note_integer} + note_shift')
        arr.append( f'    assert [z+{i+3}] = 2' )
        
        velocity_integer = int(event['velocity'], 16)
        arr.append( f'    assert [z+{i+4}] = {velocity_integer}')
        arr.append( f'    assert [z+{i+5}] = 2' )
        
        i += 6

for line in arr:
    print(line)
# Out:
#     assert [z+3] = 1297379947
#     assert [z+4] = 8
#     assert [z+5] = 1332
#     assert [z+6] = 8
#     assert [z+7] = 0
#     assert [z+8] = 2
#     assert [z+9] = 5172255634965538127576624586516596
#     assert [z+10] = 28
#     assert [z+11] = 0
#     assert [z+12] = 2
#     assert [z+13] = 49152
#     assert [z+14] = 4
#     assert [z+15] = 0
#     assert [z+16] = 2
#     assert [z+17] = 11536228
#     assert [z+18] = 6
#     assert [z+19] = 0
#     assert [z+20] = 2
#     assert [z+21] = 2624
#     assert [z+22] = 4
#     assert [z+23] = 0
#     assert [z+24] = 2
#     assert [z+25] = 450553776345030037904731835580182146853641395011731700227710265710693791032
#     assert [z+26] = 62
#     assert [z+27] = 926233139
#     assert [z+28] = 8
#     assert [z+29] = 0
#     assert [z+30] = 2
#     assert [z+31] = 11557759
#     assert [z+32] = 6
#     assert [z+33] = 35616
#     assert [z+34] = 4
#     assert [z+35] = 144
#     assert [z+36] = 2
#     assert [z+37] = 75 + note_shift
#     assert [z+38] = 2
#     assert [z+39] = 49
#     assert [z+40] = 2
#     assert [z+41] = 33632
#     assert [z+42] = 4
#     assert [z+43] = 144
#     assert [z+44] = 2
#     assert [z+45] = 75 + note_shift
#     assert [z+46] = 2
#     assert [z+47] = 0
#     assert [z+48] = 2
#     assert [z+49] = 0
#     assert [z+50] = 2
#     assert [z+51] = 144
#     assert [z+52] = 2
#     assert [z+53] = 75 + note_shift
#     assert [z+54] = 2
#     assert [z+55] = 40
#     assert [z+56] = 2
#     assert [z+57] = 33632
#     assert [z+58] = 4
#     assert [z+59] = 144
#     assert [z+60] = 2
#     assert [z+61] = 75 + note_shift
#     assert [z+62] = 2
#     assert [z+63] = 0
#     assert [z+64] = 2
#     assert [z+65] = 0
#     assert [z+66] = 2
#     assert [z+67] = 144
#     assert [z+68] = 2
#     assert [z+69] = 75 + note_shift
#     assert [z+70] = 2
#     assert [z+71] = 44
#     assert [z+72] = 2
#     assert [z+73] = 33632
#     assert [z+74] = 4
#     assert [z+75] = 144
#     assert [z+76] = 2
#     assert [z+77] = 75 + note_shift
#     assert [z+78] = 2
#     assert [z+79] = 0
#     assert [z+80] = 2
#     assert [z+81] = 0
#     assert [z+82] = 2
#     assert [z+83] = 144
#     assert [z+84] = 2
#     assert [z+85] = 75 + note_shift
#     assert [z+86] = 2
#     assert [z+87] = 49
#     assert [z+88] = 2
#     assert [z+89] = 33632
#     assert [z+90] = 4
#     assert [z+91] = 144
#     assert [z+92] = 2
#     assert [z+93] = 75 + note_shift
#     assert [z+94] = 2
#     assert [z+95] = 0
#     assert [z+96] = 2
#     assert [z+97] = 0
#     assert [z+98] = 2
#     assert [z+99] = 144
#     assert [z+100] = 2
#     assert [z+101] = 75 + note_shift
#     assert [z+102] = 2
#     assert [z+103] = 52
#     assert [z+104] = 2
#     assert [z+105] = 33632
#     assert [z+106] = 4
#     assert [z+107] = 144
#     assert [z+108] = 2
#     assert [z+109] = 75 + note_shift
#     assert [z+110] = 2
#     assert [z+111] = 0
#     assert [z+112] = 2
#     assert [z+113] = 0
#     assert [z+114] = 2
#     assert [z+115] = 144
#     assert [z+116] = 2
#     assert [z+117] = 77 + note_shift
#     assert [z+118] = 2
#     assert [z+119] = 55
#     assert [z+120] = 2
#     assert [z+121] = 33632
#     assert [z+122] = 4
#     assert [z+123] = 144
#     assert [z+124] = 2
#     assert [z+125] = 77 + note_shift
#     assert [z+126] = 2
#     assert [z+127] = 0
#     assert [z+128] = 2
#     assert [z+129] = 0
#     assert [z+130] = 2
#     assert [z+131] = 144
#     assert [z+132] = 2
#     assert [z+133] = 75 + note_shift
#     assert [z+134] = 2
#     assert [z+135] = 52
#     assert [z+136] = 2
#     assert [z+137] = 33632
#     assert [z+138] = 4
#     assert [z+139] = 144
#     assert [z+140] = 2
#     assert [z+141] = 75 + note_shift
#     assert [z+142] = 2
#     assert [z+143] = 0
#     assert [z+144] = 2
#     assert [z+145] = 0
#     assert [z+146] = 2
#     assert [z+147] = 144
#     assert [z+148] = 2
#     assert [z+149] = 75 + note_shift
#     assert [z+150] = 2
#     assert [z+151] = 50
#     assert [z+152] = 2
#     assert [z+153] = 33632
#     assert [z+154] = 4
#     assert [z+155] = 144
#     assert [z+156] = 2
#     assert [z+157] = 75 + note_shift
#     assert [z+158] = 2
#     assert [z+159] = 0
#     assert [z+160] = 2
#     assert [z+161] = 0
#     assert [z+162] = 2
#     assert [z+163] = 144
#     assert [z+164] = 2
#     assert [z+165] = 75 + note_shift
#     assert [z+166] = 2
#     assert [z+167] = 51
#     assert [z+168] = 2
#     assert [z+169] = 33632
#     assert [z+170] = 4
#     assert [z+171] = 144
#     assert [z+172] = 2
#     assert [z+173] = 75 + note_shift
#     assert [z+174] = 2
#     assert [z+175] = 0
#     assert [z+176] = 2
#     assert [z+177] = 0
#     assert [z+178] = 2
#     assert [z+179] = 144
#     assert [z+180] = 2
#     assert [z+181] = 75 + note_shift
#     assert [z+182] = 2
#     assert [z+183] = 55
#     assert [z+184] = 2
#     assert [z+185] = 33632
#     assert [z+186] = 4
#     assert [z+187] = 144
#     assert [z+188] = 2
#     assert [z+189] = 75 + note_shift
#     assert [z+190] = 2
#     assert [z+191] = 0
#     assert [z+192] = 2
#     assert [z+193] = 0
#     assert [z+194] = 2
#     assert [z+195] = 144
#     assert [z+196] = 2
#     assert [z+197] = 75 + note_shift
#     assert [z+198] = 2
#     assert [z+199] = 60
#     assert [z+200] = 2
#     assert [z+201] = 33632
#     assert [z+202] = 4
#     assert [z+203] = 144
#     assert [z+204] = 2
#     assert [z+205] = 75 + note_shift
#     assert [z+206] = 2
#     assert [z+207] = 0
#     assert [z+208] = 2
#     assert [z+209] = 0
#     assert [z+210] = 2
#     assert [z+211] = 144
#     assert [z+212] = 2
#     assert [z+213] = 77 + note_shift
#     assert [z+214] = 2
#     assert [z+215] = 62
#     assert [z+216] = 2
#     assert [z+217] = 33632
#     assert [z+218] = 4
#     assert [z+219] = 144
#     assert [z+220] = 2
#     assert [z+221] = 77 + note_shift
#     assert [z+222] = 2
#     assert [z+223] = 0
#     assert [z+224] = 2
#     assert [z+225] = 0
#     assert [z+226] = 2
#     assert [z+227] = 144
#     assert [z+228] = 2
#     assert [z+229] = 75 + note_shift
#     assert [z+230] = 2
#     assert [z+231] = 61
#     assert [z+232] = 2
#     assert [z+233] = 33632
#     assert [z+234] = 4
#     assert [z+235] = 144
#     assert [z+236] = 2
#     assert [z+237] = 75 + note_shift
#     assert [z+238] = 2
#     assert [z+239] = 0
#     assert [z+240] = 2
#     assert [z+241] = 0
#     assert [z+242] = 2
#     assert [z+243] = 144
#     assert [z+244] = 2
#     assert [z+245] = 82 + note_shift
#     assert [z+246] = 2
#     assert [z+247] = 66
#     assert [z+248] = 2
#     assert [z+249] = 33632
#     assert [z+250] = 4
#     assert [z+251] = 144
#     assert [z+252] = 2
#     assert [z+253] = 82 + note_shift
#     assert [z+254] = 2
#     assert [z+255] = 0
#     assert [z+256] = 2
#     assert [z+257] = 0
#     assert [z+258] = 2
#     assert [z+259] = 144
#     assert [z+260] = 2
#     assert [z+261] = 80 + note_shift
#     assert [z+262] = 2
#     assert [z+263] = 64
#     assert [z+264] = 2
#     assert [z+265] = 33632
#     assert [z+266] = 4
#     assert [z+267] = 144
#     assert [z+268] = 2
#     assert [z+269] = 80 + note_shift
#     assert [z+270] = 2
#     assert [z+271] = 0
#     assert [z+272] = 2
#     assert [z+273] = 0
#     assert [z+274] = 2
#     assert [z+275] = 144
#     assert [z+276] = 2
#     assert [z+277] = 80 + note_shift
#     assert [z+278] = 2
#     assert [z+279] = 70
#     assert [z+280] = 2
#     assert [z+281] = 33632
#     assert [z+282] = 4
#     assert [z+283] = 144
#     assert [z+284] = 2
#     assert [z+285] = 80 + note_shift
#     assert [z+286] = 2
#     assert [z+287] = 0
#     assert [z+288] = 2
#     assert [z+289] = 0
#     assert [z+290] = 2
#     assert [z+291] = 144
#     assert [z+292] = 2
#     assert [z+293] = 80 + note_shift
#     assert [z+294] = 2
#     assert [z+295] = 69
#     assert [z+296] = 2
#     assert [z+297] = 33632
#     assert [z+298] = 4
#     assert [z+299] = 144
#     assert [z+300] = 2
#     assert [z+301] = 80 + note_shift
#     assert [z+302] = 2
#     assert [z+303] = 0
#     assert [z+304] = 2
#     assert [z+305] = 0
#     assert [z+306] = 2
#     assert [z+307] = 144
#     assert [z+308] = 2
#     assert [z+309] = 80 + note_shift
#     assert [z+310] = 2
#     assert [z+311] = 73
#     assert [z+312] = 2
#     assert [z+313] = 33632
#     assert [z+314] = 4
#     assert [z+315] = 144
#     assert [z+316] = 2
#     assert [z+317] = 80 + note_shift
#     assert [z+318] = 2
#     assert [z+319] = 0
#     assert [z+320] = 2
#     assert [z+321] = 0
#     assert [z+322] = 2
#     assert [z+323] = 144
#     assert [z+324] = 2
#     assert [z+325] = 80 + note_shift
#     assert [z+326] = 2
#     assert [z+327] = 70
#     assert [z+328] = 2
#     assert [z+329] = 33632
#     assert [z+330] = 4
#     assert [z+331] = 144
#     assert [z+332] = 2
#     assert [z+333] = 80 + note_shift
#     assert [z+334] = 2
#     assert [z+335] = 0
#     assert [z+336] = 2
#     assert [z+337] = 0
#     assert [z+338] = 2
#     assert [z+339] = 144
#     assert [z+340] = 2
#     assert [z+341] = 80 + note_shift
#     assert [z+342] = 2
#     assert [z+343] = 77
#     assert [z+344] = 2
#     assert [z+345] = 33632
#     assert [z+346] = 4
#     assert [z+347] = 144
#     assert [z+348] = 2
#     assert [z+349] = 80 + note_shift
#     assert [z+350] = 2
#     assert [z+351] = 0
#     assert [z+352] = 2
#     assert [z+353] = 0
#     assert [z+354] = 2
#     assert [z+355] = 144
#     assert [z+356] = 2
#     assert [z+357] = 82 + note_shift
#     assert [z+358] = 2
#     assert [z+359] = 77
#     assert [z+360] = 2
#     assert [z+361] = 33632
#     assert [z+362] = 4
#     assert [z+363] = 144
#     assert [z+364] = 2
#     assert [z+365] = 82 + note_shift
#     assert [z+366] = 2
#     assert [z+367] = 0
#     assert [z+368] = 2
#     assert [z+369] = 0
#     assert [z+370] = 2
#     assert [z+371] = 144
#     assert [z+372] = 2
#     assert [z+373] = 84 + note_shift
#     assert [z+374] = 2
#     assert [z+375] = 80
#     assert [z+376] = 2
#     assert [z+377] = 33632
#     assert [z+378] = 4
#     assert [z+379] = 144
#     assert [z+380] = 2
#     assert [z+381] = 84 + note_shift
#     assert [z+382] = 2
#     assert [z+383] = 0
#     assert [z+384] = 2
#     assert [z+385] = 0
#     assert [z+386] = 2
#     assert [z+387] = 144
#     assert [z+388] = 2
#     assert [z+389] = 82 + note_shift
#     assert [z+390] = 2
#     assert [z+391] = 77
#     assert [z+392] = 2
#     assert [z+393] = 33632
#     assert [z+394] = 4
#     assert [z+395] = 144
#     assert [z+396] = 2
#     assert [z+397] = 82 + note_shift
#     assert [z+398] = 2
#     assert [z+399] = 0
#     assert [z+400] = 2
#     assert [z+401] = 0
#     assert [z+402] = 2
#     assert [z+403] = 144
#     assert [z+404] = 2
#     assert [z+405] = 80 + note_shift
#     assert [z+406] = 2
#     assert [z+407] = 77
#     assert [z+408] = 2
#     assert [z+409] = 33632
#     assert [z+410] = 4
#     assert [z+411] = 144
#     assert [z+412] = 2
#     assert [z+413] = 80 + note_shift
#     assert [z+414] = 2
#     assert [z+415] = 0
#     assert [z+416] = 2
#     assert [z+417] = 0
#     assert [z+418] = 2
#     assert [z+419] = 144
#     assert [z+420] = 2
#     assert [z+421] = 77 + note_shift
#     assert [z+422] = 2
#     assert [z+423] = 70
#     assert [z+424] = 2
#     assert [z+425] = 33632
#     assert [z+426] = 4
#     assert [z+427] = 144
#     assert [z+428] = 2
#     assert [z+429] = 77 + note_shift
#     assert [z+430] = 2
#     assert [z+431] = 0
#     assert [z+432] = 2
#     assert [z+433] = 0
#     assert [z+434] = 2
#     assert [z+435] = 144
#     assert [z+436] = 2
#     assert [z+437] = 77 + note_shift
#     assert [z+438] = 2
#     assert [z+439] = 72
#     assert [z+440] = 2
#     assert [z+441] = 33632
#     assert [z+442] = 4
#     assert [z+443] = 144
#     assert [z+444] = 2
#     assert [z+445] = 77 + note_shift
#     assert [z+446] = 2
#     assert [z+447] = 0
#     assert [z+448] = 2
#     assert [z+449] = 0
#     assert [z+450] = 2
#     assert [z+451] = 144
#     assert [z+452] = 2
#     assert [z+453] = 79 + note_shift
#     assert [z+454] = 2
#     assert [z+455] = 72
#     assert [z+456] = 2
#     assert [z+457] = 33632
#     assert [z+458] = 4
#     assert [z+459] = 144
#     assert [z+460] = 2
#     assert [z+461] = 79 + note_shift
#     assert [z+462] = 2
#     assert [z+463] = 0
#     assert [z+464] = 2
#     assert [z+465] = 0
#     assert [z+466] = 2
#     assert [z+467] = 144
#     assert [z+468] = 2
#     assert [z+469] = 80 + note_shift
#     assert [z+470] = 2
#     assert [z+471] = 75
#     assert [z+472] = 2
#     assert [z+473] = 33632
#     assert [z+474] = 4
#     assert [z+475] = 144
#     assert [z+476] = 2
#     assert [z+477] = 80 + note_shift
#     assert [z+478] = 2
#     assert [z+479] = 0
#     assert [z+480] = 2
#     assert [z+481] = 10
#     assert [z+482] = 2
#     assert [z+483] = 144
#     assert [z+484] = 2
#     assert [z+485] = 70 + note_shift
#     assert [z+486] = 2
#     assert [z+487] = 68
#     assert [z+488] = 2
#     assert [z+489] = 33622
#     assert [z+490] = 4
#     assert [z+491] = 144
#     assert [z+492] = 2
#     assert [z+493] = 70 + note_shift
#     assert [z+494] = 2
#     assert [z+495] = 0
#     assert [z+496] = 2
#     assert [z+497] = 0
#     assert [z+498] = 2
#     assert [z+499] = 144
#     assert [z+500] = 2
#     assert [z+501] = 70 + note_shift
#     assert [z+502] = 2
#     assert [z+503] = 70
#     assert [z+504] = 2
#     assert [z+505] = 33632
#     assert [z+506] = 4
#     assert [z+507] = 144
#     assert [z+508] = 2
#     assert [z+509] = 70 + note_shift
#     assert [z+510] = 2
#     assert [z+511] = 0
#     assert [z+512] = 2
#     assert [z+513] = 0
#     assert [z+514] = 2
#     assert [z+515] = 144
#     assert [z+516] = 2
#     assert [z+517] = 72 + note_shift
#     assert [z+518] = 2
#     assert [z+519] = 62
#     assert [z+520] = 2
#     assert [z+521] = 33632
#     assert [z+522] = 4
#     assert [z+523] = 144
#     assert [z+524] = 2
#     assert [z+525] = 72 + note_shift
#     assert [z+526] = 2
#     assert [z+527] = 0
#     assert [z+528] = 2
#     assert [z+529] = 0
#     assert [z+530] = 2
#     assert [z+531] = 144
#     assert [z+532] = 2
#     assert [z+533] = 73 + note_shift
#     assert [z+534] = 2
#     assert [z+535] = 63
#     assert [z+536] = 2
#     assert [z+537] = 33632
#     assert [z+538] = 4
#     assert [z+539] = 144
#     assert [z+540] = 2
#     assert [z+541] = 73 + note_shift
#     assert [z+542] = 2
#     assert [z+543] = 0
#     assert [z+544] = 2
#     assert [z+545] = 0
#     assert [z+546] = 2
#     assert [z+547] = 144
#     assert [z+548] = 2
#     assert [z+549] = 63 + note_shift
#     assert [z+550] = 2
#     assert [z+551] = 55
#     assert [z+552] = 2
#     assert [z+553] = 33632
#     assert [z+554] = 4
#     assert [z+555] = 144
#     assert [z+556] = 2
#     assert [z+557] = 63 + note_shift
#     assert [z+558] = 2
#     assert [z+559] = 0
#     assert [z+560] = 2
#     assert [z+561] = 0
#     assert [z+562] = 2
#     assert [z+563] = 144
#     assert [z+564] = 2
#     assert [z+565] = 75 + note_shift
#     assert [z+566] = 2
#     assert [z+567] = 51
#     assert [z+568] = 2
#     assert [z+569] = 33632
#     assert [z+570] = 4
#     assert [z+571] = 144
#     assert [z+572] = 2
#     assert [z+573] = 75 + note_shift
#     assert [z+574] = 2
#     assert [z+575] = 0
#     assert [z+576] = 2
#     assert [z+577] = 0
#     assert [z+578] = 2
#     assert [z+579] = 144
#     assert [z+580] = 2
#     assert [z+581] = 75 + note_shift
#     assert [z+582] = 2
#     assert [z+583] = 44
#     assert [z+584] = 2
#     assert [z+585] = 33632
#     assert [z+586] = 4
#     assert [z+587] = 144
#     assert [z+588] = 2
#     assert [z+589] = 75 + note_shift
#     assert [z+590] = 2
#     assert [z+591] = 0
#     assert [z+592] = 2
#     assert [z+593] = 0
#     assert [z+594] = 2
#     assert [z+595] = 144
#     assert [z+596] = 2
#     assert [z+597] = 75 + note_shift
#     assert [z+598] = 2
#     assert [z+599] = 49
#     assert [z+600] = 2
#     assert [z+601] = 33632
#     assert [z+602] = 4
#     assert [z+603] = 144
#     assert [z+604] = 2
#     assert [z+605] = 75 + note_shift
#     assert [z+606] = 2
#     assert [z+607] = 0
#     assert [z+608] = 2
#     assert [z+609] = 0
#     assert [z+610] = 2
#     assert [z+611] = 144
#     assert [z+612] = 2
#     assert [z+613] = 75 + note_shift
#     assert [z+614] = 2
#     assert [z+615] = 52
#     assert [z+616] = 2
#     assert [z+617] = 33632
#     assert [z+618] = 4
#     assert [z+619] = 144
#     assert [z+620] = 2
#     assert [z+621] = 75 + note_shift
#     assert [z+622] = 2
#     assert [z+623] = 0
#     assert [z+624] = 2
#     assert [z+625] = 0
#     assert [z+626] = 2
#     assert [z+627] = 144
#     assert [z+628] = 2
#     assert [z+629] = 77 + note_shift
#     assert [z+630] = 2
#     assert [z+631] = 55
#     assert [z+632] = 2
#     assert [z+633] = 33632
#     assert [z+634] = 4
#     assert [z+635] = 144
#     assert [z+636] = 2
#     assert [z+637] = 77 + note_shift
#     assert [z+638] = 2
#     assert [z+639] = 0
#     assert [z+640] = 2
#     assert [z+641] = 0
#     assert [z+642] = 2
#     assert [z+643] = 144
#     assert [z+644] = 2
#     assert [z+645] = 75 + note_shift
#     assert [z+646] = 2
#     assert [z+647] = 52
#     assert [z+648] = 2
#     assert [z+649] = 33632
#     assert [z+650] = 4
#     assert [z+651] = 144
#     assert [z+652] = 2
#     assert [z+653] = 75 + note_shift
#     assert [z+654] = 2
#     assert [z+655] = 0
#     assert [z+656] = 2
#     assert [z+657] = 0
#     assert [z+658] = 2
#     assert [z+659] = 144
#     assert [z+660] = 2
#     assert [z+661] = 75 + note_shift
#     assert [z+662] = 2
#     assert [z+663] = 50
#     assert [z+664] = 2
#     assert [z+665] = 33632
#     assert [z+666] = 4
#     assert [z+667] = 144
#     assert [z+668] = 2
#     assert [z+669] = 75 + note_shift
#     assert [z+670] = 2
#     assert [z+671] = 0
#     assert [z+672] = 2
#     assert [z+673] = 0
#     assert [z+674] = 2
#     assert [z+675] = 144
#     assert [z+676] = 2
#     assert [z+677] = 75 + note_shift
#     assert [z+678] = 2
#     assert [z+679] = 51
#     assert [z+680] = 2
#     assert [z+681] = 33632
#     assert [z+682] = 4
#     assert [z+683] = 144
#     assert [z+684] = 2
#     assert [z+685] = 75 + note_shift
#     assert [z+686] = 2
#     assert [z+687] = 0
#     assert [z+688] = 2
#     assert [z+689] = 0
#     assert [z+690] = 2
#     assert [z+691] = 144
#     assert [z+692] = 2
#     assert [z+693] = 75 + note_shift
#     assert [z+694] = 2
#     assert [z+695] = 59
#     assert [z+696] = 2
#     assert [z+697] = 33632
#     assert [z+698] = 4
#     assert [z+699] = 144
#     assert [z+700] = 2
#     assert [z+701] = 75 + note_shift
#     assert [z+702] = 2
#     assert [z+703] = 0
#     assert [z+704] = 2
#     assert [z+705] = 0
#     assert [z+706] = 2
#     assert [z+707] = 144
#     assert [z+708] = 2
#     assert [z+709] = 82 + note_shift
#     assert [z+710] = 2
#     assert [z+711] = 68
#     assert [z+712] = 2
#     assert [z+713] = 33632
#     assert [z+714] = 4
#     assert [z+715] = 144
#     assert [z+716] = 2
#     assert [z+717] = 82 + note_shift
#     assert [z+718] = 2
#     assert [z+719] = 0
#     assert [z+720] = 2
#     assert [z+721] = 0
#     assert [z+722] = 2
#     assert [z+723] = 144
#     assert [z+724] = 2
#     assert [z+725] = 84 + note_shift
#     assert [z+726] = 2
#     assert [z+727] = 71
#     assert [z+728] = 2
#     assert [z+729] = 33632
#     assert [z+730] = 4
#     assert [z+731] = 144
#     assert [z+732] = 2
#     assert [z+733] = 84 + note_shift
#     assert [z+734] = 2
#     assert [z+735] = 0
#     assert [z+736] = 2
#     assert [z+737] = 0
#     assert [z+738] = 2
#     assert [z+739] = 144
#     assert [z+740] = 2
#     assert [z+741] = 79 + note_shift
#     assert [z+742] = 2
#     assert [z+743] = 66
#     assert [z+744] = 2
#     assert [z+745] = 33632
#     assert [z+746] = 4
#     assert [z+747] = 144
#     assert [z+748] = 2
#     assert [z+749] = 79 + note_shift
#     assert [z+750] = 2
#     assert [z+751] = 0
#     assert [z+752] = 2
#     assert [z+753] = 0
#     assert [z+754] = 2
#     assert [z+755] = 144
#     assert [z+756] = 2
#     assert [z+757] = 82 + note_shift
#     assert [z+758] = 2
#     assert [z+759] = 72
#     assert [z+760] = 2
#     assert [z+761] = 33632
#     assert [z+762] = 4
#     assert [z+763] = 144
#     assert [z+764] = 2
#     assert [z+765] = 82 + note_shift
#     assert [z+766] = 2
#     assert [z+767] = 0
#     assert [z+768] = 2
#     assert [z+769] = 0
#     assert [z+770] = 2
#     assert [z+771] = 144
#     assert [z+772] = 2
#     assert [z+773] = 80 + note_shift
#     assert [z+774] = 2
#     assert [z+775] = 71
#     assert [z+776] = 2
#     assert [z+777] = 33632
#     assert [z+778] = 4
#     assert [z+779] = 144
#     assert [z+780] = 2
#     assert [z+781] = 80 + note_shift
#     assert [z+782] = 2
#     assert [z+783] = 0
#     assert [z+784] = 2
#     assert [z+785] = 0
#     assert [z+786] = 2
#     assert [z+787] = 144
#     assert [z+788] = 2
#     assert [z+789] = 80 + note_shift
#     assert [z+790] = 2
#     assert [z+791] = 80
#     assert [z+792] = 2
#     assert [z+793] = 33632
#     assert [z+794] = 4
#     assert [z+795] = 144
#     assert [z+796] = 2
#     assert [z+797] = 80 + note_shift
#     assert [z+798] = 2
#     assert [z+799] = 0
#     assert [z+800] = 2
#     assert [z+801] = 0
#     assert [z+802] = 2
#     assert [z+803] = 144
#     assert [z+804] = 2
#     assert [z+805] = 80 + note_shift
#     assert [z+806] = 2
#     assert [z+807] = 82
#     assert [z+808] = 2
#     assert [z+809] = 33632
#     assert [z+810] = 4
#     assert [z+811] = 144
#     assert [z+812] = 2
#     assert [z+813] = 80 + note_shift
#     assert [z+814] = 2
#     assert [z+815] = 0
#     assert [z+816] = 2
#     assert [z+817] = 0
#     assert [z+818] = 2
#     assert [z+819] = 144
#     assert [z+820] = 2
#     assert [z+821] = 80 + note_shift
#     assert [z+822] = 2
#     assert [z+823] = 80
#     assert [z+824] = 2
#     assert [z+825] = 33632
#     assert [z+826] = 4
#     assert [z+827] = 144
#     assert [z+828] = 2
#     assert [z+829] = 80 + note_shift
#     assert [z+830] = 2
#     assert [z+831] = 0
#     assert [z+832] = 2
#     assert [z+833] = 0
#     assert [z+834] = 2
#     assert [z+835] = 144
#     assert [z+836] = 2
#     assert [z+837] = 80 + note_shift
#     assert [z+838] = 2
#     assert [z+839] = 81
#     assert [z+840] = 2
#     assert [z+841] = 33632
#     assert [z+842] = 4
#     assert [z+843] = 144
#     assert [z+844] = 2
#     assert [z+845] = 80 + note_shift
#     assert [z+846] = 2
#     assert [z+847] = 0
#     assert [z+848] = 2
#     assert [z+849] = 0
#     assert [z+850] = 2
#     assert [z+851] = 144
#     assert [z+852] = 2
#     assert [z+853] = 80 + note_shift
#     assert [z+854] = 2
#     assert [z+855] = 84
#     assert [z+856] = 2
#     assert [z+857] = 33632
#     assert [z+858] = 4
#     assert [z+859] = 144
#     assert [z+860] = 2
#     assert [z+861] = 80 + note_shift
#     assert [z+862] = 2
#     assert [z+863] = 0
#     assert [z+864] = 2
#     assert [z+865] = 0
#     assert [z+866] = 2
#     assert [z+867] = 144
#     assert [z+868] = 2
#     assert [z+869] = 82 + note_shift
#     assert [z+870] = 2
#     assert [z+871] = 84
#     assert [z+872] = 2
#     assert [z+873] = 33632
#     assert [z+874] = 4
#     assert [z+875] = 144
#     assert [z+876] = 2
#     assert [z+877] = 82 + note_shift
#     assert [z+878] = 2
#     assert [z+879] = 0
#     assert [z+880] = 2
#     assert [z+881] = 0
#     assert [z+882] = 2
#     assert [z+883] = 144
#     assert [z+884] = 2
#     assert [z+885] = 84 + note_shift
#     assert [z+886] = 2
#     assert [z+887] = 88
#     assert [z+888] = 2
#     assert [z+889] = 33632
#     assert [z+890] = 4
#     assert [z+891] = 144
#     assert [z+892] = 2
#     assert [z+893] = 84 + note_shift
#     assert [z+894] = 2
#     assert [z+895] = 0
#     assert [z+896] = 2
#     assert [z+897] = 0
#     assert [z+898] = 2
#     assert [z+899] = 144
#     assert [z+900] = 2
#     assert [z+901] = 79 + note_shift
#     assert [z+902] = 2
#     assert [z+903] = 82
#     assert [z+904] = 2
#     assert [z+905] = 33632
#     assert [z+906] = 4
#     assert [z+907] = 144
#     assert [z+908] = 2
#     assert [z+909] = 79 + note_shift
#     assert [z+910] = 2
#     assert [z+911] = 0
#     assert [z+912] = 2
#     assert [z+913] = 0
#     assert [z+914] = 2
#     assert [z+915] = 144
#     assert [z+916] = 2
#     assert [z+917] = 79 + note_shift
#     assert [z+918] = 2
#     assert [z+919] = 80
#     assert [z+920] = 2
#     assert [z+921] = 33632
#     assert [z+922] = 4
#     assert [z+923] = 144
#     assert [z+924] = 2
#     assert [z+925] = 79 + note_shift
#     assert [z+926] = 2
#     assert [z+927] = 0
#     assert [z+928] = 2
#     assert [z+929] = 0
#     assert [z+930] = 2
#     assert [z+931] = 144
#     assert [z+932] = 2
#     assert [z+933] = 79 + note_shift
#     assert [z+934] = 2
#     assert [z+935] = 71
#     assert [z+936] = 2
#     assert [z+937] = 33632
#     assert [z+938] = 4
#     assert [z+939] = 144
#     assert [z+940] = 2
#     assert [z+941] = 79 + note_shift
#     assert [z+942] = 2
#     assert [z+943] = 0
#     assert [z+944] = 2
#     assert [z+945] = 0
#     assert [z+946] = 2
#     assert [z+947] = 144
#     assert [z+948] = 2
#     assert [z+949] = 79 + note_shift
#     assert [z+950] = 2
#     assert [z+951] = 64
#     assert [z+952] = 2
#     assert [z+953] = 33632
#     assert [z+954] = 4
#     assert [z+955] = 144
#     assert [z+956] = 2
#     assert [z+957] = 79 + note_shift
#     assert [z+958] = 2
#     assert [z+959] = 0
#     assert [z+960] = 2
#     assert [z+961] = 0
#     assert [z+962] = 2
#     assert [z+963] = 144
#     assert [z+964] = 2
#     assert [z+965] = 79 + note_shift
#     assert [z+966] = 2
#     assert [z+967] = 66
#     assert [z+968] = 2
#     assert [z+969] = 33632
#     assert [z+970] = 4
#     assert [z+971] = 144
#     assert [z+972] = 2
#     assert [z+973] = 79 + note_shift
#     assert [z+974] = 2
#     assert [z+975] = 0
#     assert [z+976] = 2
#     assert [z+977] = 0
#     assert [z+978] = 2
#     assert [z+979] = 144
#     assert [z+980] = 2
#     assert [z+981] = 79 + note_shift
#     assert [z+982] = 2
#     assert [z+983] = 68
#     assert [z+984] = 2
#     assert [z+985] = 33632
#     assert [z+986] = 4
#     assert [z+987] = 144
#     assert [z+988] = 2
#     assert [z+989] = 79 + note_shift
#     assert [z+990] = 2
#     assert [z+991] = 0
#     assert [z+992] = 2
#     assert [z+993] = 0
#     assert [z+994] = 2
#     assert [z+995] = 144
#     assert [z+996] = 2
#     assert [z+997] = 79 + note_shift
#     assert [z+998] = 2
#     assert [z+999] = 60
#     assert [z+1000] = 2
#     assert [z+1001] = 33632
#     assert [z+1002] = 4
#     assert [z+1003] = 144
#     assert [z+1004] = 2
#     assert [z+1005] = 79 + note_shift
#     assert [z+1006] = 2
#     assert [z+1007] = 0
#     assert [z+1008] = 2
#     assert [z+1009] = 0
#     assert [z+1010] = 2
#     assert [z+1011] = 144
#     assert [z+1012] = 2
#     assert [z+1013] = 74 + note_shift
#     assert [z+1014] = 2
#     assert [z+1015] = 53
#     assert [z+1016] = 2
#     assert [z+1017] = 33632
#     assert [z+1018] = 4
#     assert [z+1019] = 144
#     assert [z+1020] = 2
#     assert [z+1021] = 74 + note_shift
#     assert [z+1022] = 2
#     assert [z+1023] = 0
#     assert [z+1024] = 2
#     assert [z+1025] = 0
#     assert [z+1026] = 2
#     assert [z+1027] = 144
#     assert [z+1028] = 2
#     assert [z+1029] = 72 + note_shift
#     assert [z+1030] = 2
#     assert [z+1031] = 52
#     assert [z+1032] = 2
#     assert [z+1033] = 33632
#     assert [z+1034] = 4
#     assert [z+1035] = 144
#     assert [z+1036] = 2
#     assert [z+1037] = 72 + note_shift
#     assert [z+1038] = 2
#     assert [z+1039] = 0
#     assert [z+1040] = 2
#     assert [z+1041] = 0
#     assert [z+1042] = 2
#     assert [z+1043] = 144
#     assert [z+1044] = 2
#     assert [z+1045] = 72 + note_shift
#     assert [z+1046] = 2
#     assert [z+1047] = 53
#     assert [z+1048] = 2
#     assert [z+1049] = 33632
#     assert [z+1050] = 4
#     assert [z+1051] = 144
#     assert [z+1052] = 2
#     assert [z+1053] = 72 + note_shift
#     assert [z+1054] = 2
#     assert [z+1055] = 0
#     assert [z+1056] = 2
#     assert [z+1057] = 0
#     assert [z+1058] = 2
#     assert [z+1059] = 144
#     assert [z+1060] = 2
#     assert [z+1061] = 72 + note_shift
#     assert [z+1062] = 2
#     assert [z+1063] = 47
#     assert [z+1064] = 2
#     assert [z+1065] = 33632
#     assert [z+1066] = 4
#     assert [z+1067] = 144
#     assert [z+1068] = 2
#     assert [z+1069] = 72 + note_shift
#     assert [z+1070] = 2
#     assert [z+1071] = 0
#     assert [z+1072] = 2
#     assert [z+1073] = 0
#     assert [z+1074] = 2
#     assert [z+1075] = 144
#     assert [z+1076] = 2
#     assert [z+1077] = 72 + note_shift
#     assert [z+1078] = 2
#     assert [z+1079] = 49
#     assert [z+1080] = 2
#     assert [z+1081] = 33632
#     assert [z+1082] = 4
#     assert [z+1083] = 144
#     assert [z+1084] = 2
#     assert [z+1085] = 72 + note_shift
#     assert [z+1086] = 2
#     assert [z+1087] = 0
#     assert [z+1088] = 2
#     assert [z+1089] = 0
#     assert [z+1090] = 2
#     assert [z+1091] = 144
#     assert [z+1092] = 2
#     assert [z+1093] = 72 + note_shift
#     assert [z+1094] = 2
#     assert [z+1095] = 44
#     assert [z+1096] = 2
#     assert [z+1097] = 33632
#     assert [z+1098] = 4
#     assert [z+1099] = 144
#     assert [z+1100] = 2
#     assert [z+1101] = 72 + note_shift
#     assert [z+1102] = 2
#     assert [z+1103] = 0
#     assert [z+1104] = 2
#     assert [z+1105] = 0
#     assert [z+1106] = 2
#     assert [z+1107] = 144
#     assert [z+1108] = 2
#     assert [z+1109] = 73 + note_shift
#     assert [z+1110] = 2
#     assert [z+1111] = 51
#     assert [z+1112] = 2
#     assert [z+1113] = 33632
#     assert [z+1114] = 4
#     assert [z+1115] = 144
#     assert [z+1116] = 2
#     assert [z+1117] = 73 + note_shift
#     assert [z+1118] = 2
#     assert [z+1119] = 0
#     assert [z+1120] = 2
#     assert [z+1121] = 0
#     assert [z+1122] = 2
#     assert [z+1123] = 144
#     assert [z+1124] = 2
#     assert [z+1125] = 72 + note_shift
#     assert [z+1126] = 2
#     assert [z+1127] = 49
#     assert [z+1128] = 2
#     assert [z+1129] = 33632
#     assert [z+1130] = 4
#     assert [z+1131] = 144
#     assert [z+1132] = 2
#     assert [z+1133] = 72 + note_shift
#     assert [z+1134] = 2
#     assert [z+1135] = 0
#     assert [z+1136] = 2
#     assert [z+1137] = 0
#     assert [z+1138] = 2
#     assert [z+1139] = 144
#     assert [z+1140] = 2
#     assert [z+1141] = 72 + note_shift
#     assert [z+1142] = 2
#     assert [z+1143] = 52
#     assert [z+1144] = 2
#     assert [z+1145] = 33632
#     assert [z+1146] = 4
#     assert [z+1147] = 144
#     assert [z+1148] = 2
#     assert [z+1149] = 72 + note_shift
#     assert [z+1150] = 2
#     assert [z+1151] = 0
#     assert [z+1152] = 2
#     assert [z+1153] = 0
#     assert [z+1154] = 2
#     assert [z+1155] = 144
#     assert [z+1156] = 2
#     assert [z+1157] = 74 + note_shift
#     assert [z+1158] = 2
#     assert [z+1159] = 55
#     assert [z+1160] = 2
#     assert [z+1161] = 33632
#     assert [z+1162] = 4
#     assert [z+1163] = 144
#     assert [z+1164] = 2
#     assert [z+1165] = 74 + note_shift
#     assert [z+1166] = 2
#     assert [z+1167] = 0
#     assert [z+1168] = 2
#     assert [z+1169] = 0
#     assert [z+1170] = 2
#     assert [z+1171] = 144
#     assert [z+1172] = 2
#     assert [z+1173] = 76 + note_shift
#     assert [z+1174] = 2
#     assert [z+1175] = 58
#     assert [z+1176] = 2
#     assert [z+1177] = 33632
#     assert [z+1178] = 4
#     assert [z+1179] = 144
#     assert [z+1180] = 2
#     assert [z+1181] = 76 + note_shift
#     assert [z+1182] = 2
#     assert [z+1183] = 0
#     assert [z+1184] = 2
#     assert [z+1185] = 0
#     assert [z+1186] = 2
#     assert [z+1187] = 144
#     assert [z+1188] = 2
#     assert [z+1189] = 77 + note_shift
#     assert [z+1190] = 2
#     assert [z+1191] = 60
#     assert [z+1192] = 2
#     assert [z+1193] = 33632
#     assert [z+1194] = 4
#     assert [z+1195] = 144
#     assert [z+1196] = 2
#     assert [z+1197] = 77 + note_shift
#     assert [z+1198] = 2
#     assert [z+1199] = 0
#     assert [z+1200] = 2
#     assert [z+1201] = 0
#     assert [z+1202] = 2
#     assert [z+1203] = 144
#     assert [z+1204] = 2
#     assert [z+1205] = 75 + note_shift
#     assert [z+1206] = 2
#     assert [z+1207] = 59
#     assert [z+1208] = 2
#     assert [z+1209] = 33632
#     assert [z+1210] = 4
#     assert [z+1211] = 144
#     assert [z+1212] = 2
#     assert [z+1213] = 75 + note_shift
#     assert [z+1214] = 2
#     assert [z+1215] = 0
#     assert [z+1216] = 2
#     assert [z+1217] = 0
#     assert [z+1218] = 2
#     assert [z+1219] = 144
#     assert [z+1220] = 2
#     assert [z+1221] = 75 + note_shift
#     assert [z+1222] = 2
#     assert [z+1223] = 67
#     assert [z+1224] = 2
#     assert [z+1225] = 33632
#     assert [z+1226] = 4
#     assert [z+1227] = 144
#     assert [z+1228] = 2
#     assert [z+1229] = 75 + note_shift
#     assert [z+1230] = 2
#     assert [z+1231] = 0
#     assert [z+1232] = 2
#     assert [z+1233] = 0
#     assert [z+1234] = 2
#     assert [z+1235] = 144
#     assert [z+1236] = 2
#     assert [z+1237] = 77 + note_shift
#     assert [z+1238] = 2
#     assert [z+1239] = 70
#     assert [z+1240] = 2
#     assert [z+1241] = 33632
#     assert [z+1242] = 4
#     assert [z+1243] = 144
#     assert [z+1244] = 2
#     assert [z+1245] = 77 + note_shift
#     assert [z+1246] = 2
#     assert [z+1247] = 0
#     assert [z+1248] = 2
#     assert [z+1249] = 0
#     assert [z+1250] = 2
#     assert [z+1251] = 144
#     assert [z+1252] = 2
#     assert [z+1253] = 75 + note_shift
#     assert [z+1254] = 2
#     assert [z+1255] = 66
#     assert [z+1256] = 2
#     assert [z+1257] = 33632
#     assert [z+1258] = 4
#     assert [z+1259] = 144
#     assert [z+1260] = 2
#     assert [z+1261] = 75 + note_shift
#     assert [z+1262] = 2
#     assert [z+1263] = 0
#     assert [z+1264] = 2
#     assert [z+1265] = 0
#     assert [z+1266] = 2
#     assert [z+1267] = 144
#     assert [z+1268] = 2
#     assert [z+1269] = 75 + note_shift
#     assert [z+1270] = 2
#     assert [z+1271] = 72
#     assert [z+1272] = 2
#     assert [z+1273] = 33632
#     assert [z+1274] = 4
#     assert [z+1275] = 144
#     assert [z+1276] = 2
#     assert [z+1277] = 75 + note_shift
#     assert [z+1278] = 2
#     assert [z+1279] = 0
#     assert [z+1280] = 2
#     assert [z+1281] = 0
#     assert [z+1282] = 2
#     assert [z+1283] = 144
#     assert [z+1284] = 2
#     assert [z+1285] = 77 + note_shift
#     assert [z+1286] = 2
#     assert [z+1287] = 75
#     assert [z+1288] = 2
#     assert [z+1289] = 33632
#     assert [z+1290] = 4
#     assert [z+1291] = 144
#     assert [z+1292] = 2
#     assert [z+1293] = 77 + note_shift
#     assert [z+1294] = 2
#     assert [z+1295] = 0
#     assert [z+1296] = 2
#     assert [z+1297] = 0
#     assert [z+1298] = 2
#     assert [z+1299] = 144
#     assert [z+1300] = 2
#     assert [z+1301] = 79 + note_shift
#     assert [z+1302] = 2
#     assert [z+1303] = 80
#     assert [z+1304] = 2
#     assert [z+1305] = 33632
#     assert [z+1306] = 4
#     assert [z+1307] = 144
#     assert [z+1308] = 2
#     assert [z+1309] = 79 + note_shift
#     assert [z+1310] = 2
#     assert [z+1311] = 0
#     assert [z+1312] = 2
#     assert [z+1313] = 0
#     assert [z+1314] = 2
#     assert [z+1315] = 144
#     assert [z+1316] = 2
#     assert [z+1317] = 80 + note_shift
#     assert [z+1318] = 2
#     assert [z+1319] = 82
#     assert [z+1320] = 2
#     assert [z+1321] = 33632
#     assert [z+1322] = 4
#     assert [z+1323] = 144
#     assert [z+1324] = 2
#     assert [z+1325] = 80 + note_shift
#     assert [z+1326] = 2
#     assert [z+1327] = 0
#     assert [z+1328] = 2
#     assert [z+1329] = 0
#     assert [z+1330] = 2
#     assert [z+1331] = 144
#     assert [z+1332] = 2
#     assert [z+1333] = 79 + note_shift
#     assert [z+1334] = 2
#     assert [z+1335] = 80
#     assert [z+1336] = 2
#     assert [z+1337] = 33632
#     assert [z+1338] = 4
#     assert [z+1339] = 144
#     assert [z+1340] = 2
#     assert [z+1341] = 79 + note_shift
#     assert [z+1342] = 2
#     assert [z+1343] = 0
#     assert [z+1344] = 2
#     assert [z+1345] = 0
#     assert [z+1346] = 2
#     assert [z+1347] = 144
#     assert [z+1348] = 2
#     assert [z+1349] = 79 + note_shift
#     assert [z+1350] = 2
#     assert [z+1351] = 81
#     assert [z+1352] = 2
#     assert [z+1353] = 33632
#     assert [z+1354] = 4
#     assert [z+1355] = 144
#     assert [z+1356] = 2
#     assert [z+1357] = 79 + note_shift
#     assert [z+1358] = 2
#     assert [z+1359] = 0
#     assert [z+1360] = 2
#     assert [z+1361] = 0
#     assert [z+1362] = 2
#     assert [z+1363] = 144
#     assert [z+1364] = 2
#     assert [z+1365] = 80 + note_shift
#     assert [z+1366] = 2
#     assert [z+1367] = 84
#     assert [z+1368] = 2
#     assert [z+1369] = 33632
#     assert [z+1370] = 4
#     assert [z+1371] = 144
#     assert [z+1372] = 2
#     assert [z+1373] = 80 + note_shift
#     assert [z+1374] = 2
#     assert [z+1375] = 0
#     assert [z+1376] = 2
#     assert [z+1377] = 0
#     assert [z+1378] = 2
#     assert [z+1379] = 144
#     assert [z+1380] = 2
#     assert [z+1381] = 77 + note_shift
#     assert [z+1382] = 2
#     assert [z+1383] = 75
#     assert [z+1384] = 2
#     assert [z+1385] = 33632
#     assert [z+1386] = 4
#     assert [z+1387] = 144
#     assert [z+1388] = 2
#     assert [z+1389] = 77 + note_shift
#     assert [z+1390] = 2
#     assert [z+1391] = 0
#     assert [z+1392] = 2
#     assert [z+1393] = 0
#     assert [z+1394] = 2
#     assert [z+1395] = 144
#     assert [z+1396] = 2
#     assert [z+1397] = 76 + note_shift
#     assert [z+1398] = 2
#     assert [z+1399] = 64
#     assert [z+1400] = 2
#     assert [z+1401] = 33632
#     assert [z+1402] = 4
#     assert [z+1403] = 144
#     assert [z+1404] = 2
#     assert [z+1405] = 76 + note_shift
#     assert [z+1406] = 2
#     assert [z+1407] = 0
#     assert [z+1408] = 2
#     assert [z+1409] = 0
#     assert [z+1410] = 2
#     assert [z+1411] = 144
#     assert [z+1412] = 2
#     assert [z+1413] = 74 + note_shift
#     assert [z+1414] = 2
#     assert [z+1415] = 58
#     assert [z+1416] = 2
#     assert [z+1417] = 33632
#     assert [z+1418] = 4
#     assert [z+1419] = 144
#     assert [z+1420] = 2
#     assert [z+1421] = 74 + note_shift
#     assert [z+1422] = 2
#     assert [z+1423] = 0
#     assert [z+1424] = 2
#     assert [z+1425] = 0
#     assert [z+1426] = 2
#     assert [z+1427] = 144
#     assert [z+1428] = 2
#     assert [z+1429] = 77 + note_shift
#     assert [z+1430] = 2
#     assert [z+1431] = 61
#     assert [z+1432] = 2
#     assert [z+1433] = 33632
#     assert [z+1434] = 4
#     assert [z+1435] = 144
#     assert [z+1436] = 2
#     assert [z+1437] = 77 + note_shift
#     assert [z+1438] = 2
#     assert [z+1439] = 0
#     assert [z+1440] = 2
#     assert [z+1441] = 0
#     assert [z+1442] = 2
#     assert [z+1443] = 144
#     assert [z+1444] = 2
#     assert [z+1445] = 76 + note_shift
#     assert [z+1446] = 2
#     assert [z+1447] = 57
#     assert [z+1448] = 2
#     assert [z+1449] = 33632
#     assert [z+1450] = 4
#     assert [z+1451] = 144
#     assert [z+1452] = 2
#     assert [z+1453] = 76 + note_shift
#     assert [z+1454] = 2
#     assert [z+1455] = 0
#     assert [z+1456] = 2
#     assert [z+1457] = 0
#     assert [z+1458] = 2
#     assert [z+1459] = 144
#     assert [z+1460] = 2
#     assert [z+1461] = 76 + note_shift
#     assert [z+1462] = 2
#     assert [z+1463] = 64
#     assert [z+1464] = 2
#     assert [z+1465] = 33632
#     assert [z+1466] = 4
#     assert [z+1467] = 144
#     assert [z+1468] = 2
#     assert [z+1469] = 76 + note_shift
#     assert [z+1470] = 2
#     assert [z+1471] = 0
#     assert [z+1472] = 2
#     assert [z+1473] = 0
#     assert [z+1474] = 2
#     assert [z+1475] = 144
#     assert [z+1476] = 2
#     assert [z+1477] = 74 + note_shift
#     assert [z+1478] = 2
#     assert [z+1479] = 58
#     assert [z+1480] = 2
#     assert [z+1481] = 33632
#     assert [z+1482] = 4
#     assert [z+1483] = 144
#     assert [z+1484] = 2
#     assert [z+1485] = 74 + note_shift
#     assert [z+1486] = 2
#     assert [z+1487] = 0
#     assert [z+1488] = 2
#     assert [z+1489] = 0
#     assert [z+1490] = 2
#     assert [z+1491] = 144
#     assert [z+1492] = 2
#     assert [z+1493] = 77 + note_shift
#     assert [z+1494] = 2
#     assert [z+1495] = 61
#     assert [z+1496] = 2
#     assert [z+1497] = 33632
#     assert [z+1498] = 4
#     assert [z+1499] = 144
#     assert [z+1500] = 2
#     assert [z+1501] = 77 + note_shift
#     assert [z+1502] = 2
#     assert [z+1503] = 0
#     assert [z+1504] = 2
#     assert [z+1505] = 0
#     assert [z+1506] = 2
#     assert [z+1507] = 144
#     assert [z+1508] = 2
#     assert [z+1509] = 76 + note_shift
#     assert [z+1510] = 2
#     assert [z+1511] = 57
#     assert [z+1512] = 2
#     assert [z+1513] = 33632
#     assert [z+1514] = 4
#     assert [z+1515] = 144
#     assert [z+1516] = 2
#     assert [z+1517] = 76 + note_shift
#     assert [z+1518] = 2
#     assert [z+1519] = 0
#     assert [z+1520] = 2
#     assert [z+1521] = 0
#     assert [z+1522] = 2
#     assert [z+1523] = 144
#     assert [z+1524] = 2
#     assert [z+1525] = 76 + note_shift
#     assert [z+1526] = 2
#     assert [z+1527] = 67
#     assert [z+1528] = 2
#     assert [z+1529] = 33632
#     assert [z+1530] = 4
#     assert [z+1531] = 144
#     assert [z+1532] = 2
#     assert [z+1533] = 76 + note_shift
#     assert [z+1534] = 2
#     assert [z+1535] = 0
#     assert [z+1536] = 2
#     assert [z+1537] = 0
#     assert [z+1538] = 2
#     assert [z+1539] = 144
#     assert [z+1540] = 2
#     assert [z+1541] = 74 + note_shift
#     assert [z+1542] = 2
#     assert [z+1543] = 62
#     assert [z+1544] = 2
#     assert [z+1545] = 33632
#     assert [z+1546] = 4
#     assert [z+1547] = 144
#     assert [z+1548] = 2
#     assert [z+1549] = 74 + note_shift
#     assert [z+1550] = 2
#     assert [z+1551] = 0
#     assert [z+1552] = 2
#     assert [z+1553] = 0
#     assert [z+1554] = 2
#     assert [z+1555] = 144
#     assert [z+1556] = 2
#     assert [z+1557] = 78 + note_shift
#     assert [z+1558] = 2
#     assert [z+1559] = 69
#     assert [z+1560] = 2
#     assert [z+1561] = 33632
#     assert [z+1562] = 4
#     assert [z+1563] = 144
#     assert [z+1564] = 2
#     assert [z+1565] = 78 + note_shift
#     assert [z+1566] = 2
#     assert [z+1567] = 0
#     assert [z+1568] = 2
#     assert [z+1569] = 0
#     assert [z+1570] = 2
#     assert [z+1571] = 144
#     assert [z+1572] = 2
#     assert [z+1573] = 76 + note_shift
#     assert [z+1574] = 2
#     assert [z+1575] = 67
#     assert [z+1576] = 2
#     assert [z+1577] = 33632
#     assert [z+1578] = 4
#     assert [z+1579] = 144
#     assert [z+1580] = 2
#     assert [z+1581] = 76 + note_shift
#     assert [z+1582] = 2
#     assert [z+1583] = 0
#     assert [z+1584] = 2
#     assert [z+1585] = 0
#     assert [z+1586] = 2
#     assert [z+1587] = 144
#     assert [z+1588] = 2
#     assert [z+1589] = 76 + note_shift
#     assert [z+1590] = 2
#     assert [z+1591] = 72
#     assert [z+1592] = 2
#     assert [z+1593] = 33632
#     assert [z+1594] = 4
#     assert [z+1595] = 144
#     assert [z+1596] = 2
#     assert [z+1597] = 76 + note_shift
#     assert [z+1598] = 2
#     assert [z+1599] = 0
#     assert [z+1600] = 2
#     assert [z+1601] = 0
#     assert [z+1602] = 2
#     assert [z+1603] = 144
#     assert [z+1604] = 2
#     assert [z+1605] = 81 + note_shift
#     assert [z+1606] = 2
#     assert [z+1607] = 74
#     assert [z+1608] = 2
#     assert [z+1609] = 33632
#     assert [z+1610] = 4
#     assert [z+1611] = 144
#     assert [z+1612] = 2
#     assert [z+1613] = 81 + note_shift
#     assert [z+1614] = 2
#     assert [z+1615] = 0
#     assert [z+1616] = 2
#     assert [z+1617] = 0
#     assert [z+1618] = 2
#     assert [z+1619] = 144
#     assert [z+1620] = 2
#     assert [z+1621] = 83 + note_shift
#     assert [z+1622] = 2
#     assert [z+1623] = 82
#     assert [z+1624] = 2
#     assert [z+1625] = 33632
#     assert [z+1626] = 4
#     assert [z+1627] = 144
#     assert [z+1628] = 2
#     assert [z+1629] = 83 + note_shift
#     assert [z+1630] = 2
#     assert [z+1631] = 0
#     assert [z+1632] = 2
#     assert [z+1633] = 0
#     assert [z+1634] = 2
#     assert [z+1635] = 144
#     assert [z+1636] = 2
#     assert [z+1637] = 84 + note_shift
#     assert [z+1638] = 2
#     assert [z+1639] = 79
#     assert [z+1640] = 2
#     assert [z+1641] = 33632
#     assert [z+1642] = 4
#     assert [z+1643] = 144
#     assert [z+1644] = 2
#     assert [z+1645] = 84 + note_shift
#     assert [z+1646] = 2
#     assert [z+1647] = 0
#     assert [z+1648] = 2
#     assert [z+1649] = 0
#     assert [z+1650] = 2
#     assert [z+1651] = 144
#     assert [z+1652] = 2
#     assert [z+1653] = 84 + note_shift
#     assert [z+1654] = 2
#     assert [z+1655] = 84
#     assert [z+1656] = 2
#     assert [z+1657] = 33632
#     assert [z+1658] = 4
#     assert [z+1659] = 144
#     assert [z+1660] = 2
#     assert [z+1661] = 84 + note_shift
#     assert [z+1662] = 2
#     assert [z+1663] = 0
#     assert [z+1664] = 2
#     assert [z+1665] = 0
#     assert [z+1666] = 2
#     assert [z+1667] = 144
#     assert [z+1668] = 2
#     assert [z+1669] = 82 + note_shift
#     assert [z+1670] = 2
#     assert [z+1671] = 82
#     assert [z+1672] = 2
#     assert [z+1673] = 33632
#     assert [z+1674] = 4
#     assert [z+1675] = 144
#     assert [z+1676] = 2
#     assert [z+1677] = 82 + note_shift
#     assert [z+1678] = 2
#     assert [z+1679] = 0
#     assert [z+1680] = 2
#     assert [z+1681] = 0
#     assert [z+1682] = 2
#     assert [z+1683] = 144
#     assert [z+1684] = 2
#     assert [z+1685] = 85 + note_shift
#     assert [z+1686] = 2
#     assert [z+1687] = 86
#     assert [z+1688] = 2
#     assert [z+1689] = 33632
#     assert [z+1690] = 4
#     assert [z+1691] = 144
#     assert [z+1692] = 2
#     assert [z+1693] = 85 + note_shift
#     assert [z+1694] = 2
#     assert [z+1695] = 0
#     assert [z+1696] = 2
#     assert [z+1697] = 0
#     assert [z+1698] = 2
#     assert [z+1699] = 144
#     assert [z+1700] = 2
#     assert [z+1701] = 77 + note_shift
#     assert [z+1702] = 2
#     assert [z+1703] = 79
#     assert [z+1704] = 2
#     assert [z+1705] = 33632
#     assert [z+1706] = 4
#     assert [z+1707] = 144
#     assert [z+1708] = 2
#     assert [z+1709] = 77 + note_shift
#     assert [z+1710] = 2
#     assert [z+1711] = 0
#     assert [z+1712] = 2
#     assert [z+1713] = 0
#     assert [z+1714] = 2
#     assert [z+1715] = 144
#     assert [z+1716] = 2
#     assert [z+1717] = 82 + note_shift
#     assert [z+1718] = 2
#     assert [z+1719] = 84
#     assert [z+1720] = 2
#     assert [z+1721] = 33632
#     assert [z+1722] = 4
#     assert [z+1723] = 144
#     assert [z+1724] = 2
#     assert [z+1725] = 82 + note_shift
#     assert [z+1726] = 2
#     assert [z+1727] = 0
#     assert [z+1728] = 2
#     assert [z+1729] = 0
#     assert [z+1730] = 2
#     assert [z+1731] = 144
#     assert [z+1732] = 2
#     assert [z+1733] = 80 + note_shift
#     assert [z+1734] = 2
#     assert [z+1735] = 81
#     assert [z+1736] = 2
#     assert [z+1737] = 33632
#     assert [z+1738] = 4
#     assert [z+1739] = 144
#     assert [z+1740] = 2
#     assert [z+1741] = 80 + note_shift
#     assert [z+1742] = 2
#     assert [z+1743] = 0
#     assert [z+1744] = 2
#     assert [z+1745] = 0
#     assert [z+1746] = 2
#     assert [z+1747] = 144
#     assert [z+1748] = 2
#     assert [z+1749] = 84 + note_shift
#     assert [z+1750] = 2
#     assert [z+1751] = 82
#     assert [z+1752] = 2
#     assert [z+1753] = 33632
#     assert [z+1754] = 4
#     assert [z+1755] = 144
#     assert [z+1756] = 2
#     assert [z+1757] = 84 + note_shift
#     assert [z+1758] = 2
#     assert [z+1759] = 0
#     assert [z+1760] = 2
#     assert [z+1761] = 0
#     assert [z+1762] = 2
#     assert [z+1763] = 144
#     assert [z+1764] = 2
#     assert [z+1765] = 75 + note_shift
#     assert [z+1766] = 2
#     assert [z+1767] = 79
#     assert [z+1768] = 2
#     assert [z+1769] = 33632
#     assert [z+1770] = 4
#     assert [z+1771] = 144
#     assert [z+1772] = 2
#     assert [z+1773] = 75 + note_shift
#     assert [z+1774] = 2
#     assert [z+1775] = 0
#     assert [z+1776] = 2
#     assert [z+1777] = 0
#     assert [z+1778] = 2
#     assert [z+1779] = 144
#     assert [z+1780] = 2
#     assert [z+1781] = 75 + note_shift
#     assert [z+1782] = 2
#     assert [z+1783] = 84
#     assert [z+1784] = 2
#     assert [z+1785] = 33632
#     assert [z+1786] = 4
#     assert [z+1787] = 144
#     assert [z+1788] = 2
#     assert [z+1789] = 75 + note_shift
#     assert [z+1790] = 2
#     assert [z+1791] = 0
#     assert [z+1792] = 2
#     assert [z+1793] = 0
#     assert [z+1794] = 2
#     assert [z+1795] = 144
#     assert [z+1796] = 2
#     assert [z+1797] = 76 + note_shift
#     assert [z+1798] = 2
#     assert [z+1799] = 81
#     assert [z+1800] = 2
#     assert [z+1801] = 33632
#     assert [z+1802] = 4
#     assert [z+1803] = 144
#     assert [z+1804] = 2
#     assert [z+1805] = 76 + note_shift
#     assert [z+1806] = 2
#     assert [z+1807] = 0
#     assert [z+1808] = 2
#     assert [z+1809] = 0
#     assert [z+1810] = 2
#     assert [z+1811] = 144
#     assert [z+1812] = 2
#     assert [z+1813] = 77 + note_shift
#     assert [z+1814] = 2
#     assert [z+1815] = 82
#     assert [z+1816] = 2
#     assert [z+1817] = 33632
#     assert [z+1818] = 4
#     assert [z+1819] = 144
#     assert [z+1820] = 2
#     assert [z+1821] = 77 + note_shift
#     assert [z+1822] = 2
#     assert [z+1823] = 0
#     assert [z+1824] = 2
#     assert [z+1825] = 0
#     assert [z+1826] = 2
#     assert [z+1827] = 144
#     assert [z+1828] = 2
#     assert [z+1829] = 75 + note_shift
#     assert [z+1830] = 2
#     assert [z+1831] = 79
#     assert [z+1832] = 2
#     assert [z+1833] = 33632
#     assert [z+1834] = 4
#     assert [z+1835] = 144
#     assert [z+1836] = 2
#     assert [z+1837] = 75 + note_shift
#     assert [z+1838] = 2
#     assert [z+1839] = 0
#     assert [z+1840] = 2
#     assert [z+1841] = 0
#     assert [z+1842] = 2
#     assert [z+1843] = 144
#     assert [z+1844] = 2
#     assert [z+1845] = 73 + note_shift
#     assert [z+1846] = 2
#     assert [z+1847] = 84
#     assert [z+1848] = 2
#     assert [z+1849] = 33632
#     assert [z+1850] = 4
#     assert [z+1851] = 144
#     assert [z+1852] = 2
#     assert [z+1853] = 73 + note_shift
#     assert [z+1854] = 2
#     assert [z+1855] = 0
#     assert [z+1856] = 2
#     assert [z+1857] = 0
#     assert [z+1858] = 2
#     assert [z+1859] = 144
#     assert [z+1860] = 2
#     assert [z+1861] = 72 + note_shift
#     assert [z+1862] = 2
#     assert [z+1863] = 77
#     assert [z+1864] = 2
# ...
#     assert [z+2310] = 2
#     assert [z+2311] = 61
#     assert [z+2312] = 2
#     assert [z+2313] = 33632
#     assert [z+2314] = 4
#     assert [z+2315] = 144
#     assert [z+2316] = 2
#     assert [z+2317] = 75 + note_shift
#     assert [z+2318] = 2
#     assert [z+2319] = 0
#     assert [z+2320] = 2
#     assert [z+2321] = 0
#     assert [z+2322] = 2
#     assert [z+2323] = 144
#     assert [z+2324] = 2
#     assert [z+2325] = 75 + note_shift
#     assert [z+2326] = 2
#     assert [z+2327] = 64
#     assert [z+2328] = 2
#     assert [z+2329] = 33632
#     assert [z+2330] = 4
#     assert [z+2331] = 144
#     assert [z+2332] = 2
#     assert [z+2333] = 75 + note_shift
#     assert [z+2334] = 2
#     assert [z+2335] = 0
#     assert [z+2336] = 2
#     assert [z+2337] = 0
#     assert [z+2338] = 2
#     assert [z+2339] = 144
#     assert [z+2340] = 2
#     assert [z+2341] = 75 + note_shift
#     assert [z+2342] = 2
#     assert [z+2343] = 69
#     assert [z+2344] = 2
#     assert [z+2345] = 33632
#     assert [z+2346] = 4
#     assert [z+2347] = 144
#     assert [z+2348] = 2
#     assert [z+2349] = 75 + note_shift
#     assert [z+2350] = 2
#     assert [z+2351] = 0
#     assert [z+2352] = 2
#     assert [z+2353] = 0
#     assert [z+2354] = 2
#     assert [z+2355] = 144
#     assert [z+2356] = 2
#     assert [z+2357] = 77 + note_shift
#     assert [z+2358] = 2
#     assert [z+2359] = 77
#     assert [z+2360] = 2
#     assert [z+2361] = 33632
#     assert [z+2362] = 4
#     assert [z+2363] = 144
#     assert [z+2364] = 2
#     assert [z+2365] = 77 + note_shift
#     assert [z+2366] = 2
#     assert [z+2367] = 0
#     assert [z+2368] = 2
#     assert [z+2369] = 0
#     assert [z+2370] = 2
#     assert [z+2371] = 144
#     assert [z+2372] = 2
#     assert [z+2373] = 75 + note_shift
#     assert [z+2374] = 2
#     assert [z+2375] = 68
#     assert [z+2376] = 2
#     assert [z+2377] = 33632
#     assert [z+2378] = 4
#     assert [z+2379] = 144
#     assert [z+2380] = 2
#     assert [z+2381] = 75 + note_shift
#     assert [z+2382] = 2
#     assert [z+2383] = 0
#     assert [z+2384] = 2
#     assert [z+2385] = 0
#     assert [z+2386] = 2
#     assert [z+2387] = 144
#     assert [z+2388] = 2
#     assert [z+2389] = 84 + note_shift
#     assert [z+2390] = 2
#     assert [z+2391] = 73
#     assert [z+2392] = 2
#     assert [z+2393] = 33632
#     assert [z+2394] = 4
#     assert [z+2395] = 144
#     assert [z+2396] = 2
#     assert [z+2397] = 84 + note_shift
#     assert [z+2398] = 2
#     assert [z+2399] = 0
#     assert [z+2400] = 2
#     assert [z+2401] = 0
#     assert [z+2402] = 2
#     assert [z+2403] = 144
#     assert [z+2404] = 2
#     assert [z+2405] = 79 + note_shift
#     assert [z+2406] = 2
#     assert [z+2407] = 69
#     assert [z+2408] = 2
#     assert [z+2409] = 33632
#     assert [z+2410] = 4
#     assert [z+2411] = 144
#     assert [z+2412] = 2
#     assert [z+2413] = 79 + note_shift
#     assert [z+2414] = 2
#     assert [z+2415] = 0
#     assert [z+2416] = 2
#     assert [z+2417] = 0
#     assert [z+2418] = 2
#     assert [z+2419] = 144
#     assert [z+2420] = 2
#     assert [z+2421] = 80 + note_shift
#     assert [z+2422] = 2
#     assert [z+2423] = 72
#     assert [z+2424] = 2
#     assert [z+2425] = 33632
#     assert [z+2426] = 4
#     assert [z+2427] = 144
#     assert [z+2428] = 2
#     assert [z+2429] = 80 + note_shift
#     assert [z+2430] = 2
#     assert [z+2431] = 0
#     assert [z+2432] = 2
#     assert [z+2433] = 0
#     assert [z+2434] = 2
#     assert [z+2435] = 144
#     assert [z+2436] = 2
#     assert [z+2437] = 75 + note_shift
#     assert [z+2438] = 2
#     assert [z+2439] = 61
#     assert [z+2440] = 2
#     assert [z+2441] = 33632
#     assert [z+2442] = 4
#     assert [z+2443] = 144
#     assert [z+2444] = 2
#     assert [z+2445] = 75 + note_shift
#     assert [z+2446] = 2
#     assert [z+2447] = 0
#     assert [z+2448] = 2
#     assert [z+2449] = 0
#     assert [z+2450] = 2
#     assert [z+2451] = 144
#     assert [z+2452] = 2
#     assert [z+2453] = 75 + note_shift
#     assert [z+2454] = 2
#     assert [z+2455] = 64
#     assert [z+2456] = 2
#     assert [z+2457] = 33632
#     assert [z+2458] = 4
#     assert [z+2459] = 144
#     assert [z+2460] = 2
#     assert [z+2461] = 75 + note_shift
#     assert [z+2462] = 2
#     assert [z+2463] = 0
#     assert [z+2464] = 2
#     assert [z+2465] = 0
#     assert [z+2466] = 2
#     assert [z+2467] = 144
#     assert [z+2468] = 2
#     assert [z+2469] = 75 + note_shift
#     assert [z+2470] = 2
#     assert [z+2471] = 69
#     assert [z+2472] = 2
#     assert [z+2473] = 33632
#     assert [z+2474] = 4
#     assert [z+2475] = 144
#     assert [z+2476] = 2
#     assert [z+2477] = 75 + note_shift
#     assert [z+2478] = 2
#     assert [z+2479] = 0
#     assert [z+2480] = 2
#     assert [z+2481] = 0
#     assert [z+2482] = 2
#     assert [z+2483] = 144
#     assert [z+2484] = 2
#     assert [z+2485] = 77 + note_shift
#     assert [z+2486] = 2
#     assert [z+2487] = 75
#     assert [z+2488] = 2
#     assert [z+2489] = 33632
#     assert [z+2490] = 4
#     assert [z+2491] = 144
#     assert [z+2492] = 2
#     assert [z+2493] = 77 + note_shift
#     assert [z+2494] = 2
#     assert [z+2495] = 0
#     assert [z+2496] = 2
#     assert [z+2497] = 0
#     assert [z+2498] = 2
#     assert [z+2499] = 144
#     assert [z+2500] = 2
#     assert [z+2501] = 75 + note_shift
#     assert [z+2502] = 2
#     assert [z+2503] = 61
#     assert [z+2504] = 2
#     assert [z+2505] = 33632
#     assert [z+2506] = 4
#     assert [z+2507] = 144
#     assert [z+2508] = 2
#     assert [z+2509] = 75 + note_shift
#     assert [z+2510] = 2
#     assert [z+2511] = 0
#     assert [z+2512] = 2
#     assert [z+2513] = 0
#     assert [z+2514] = 2
#     assert [z+2515] = 144
#     assert [z+2516] = 2
#     assert [z+2517] = 89 + note_shift
#     assert [z+2518] = 2
#     assert [z+2519] = 66
#     assert [z+2520] = 2
#     assert [z+2521] = 33632
#     assert [z+2522] = 4
#     assert [z+2523] = 144
#     assert [z+2524] = 2
#     assert [z+2525] = 89 + note_shift
#     assert [z+2526] = 2
#     assert [z+2527] = 0
#     assert [z+2528] = 2
#     assert [z+2529] = 0
#     assert [z+2530] = 2
#     assert [z+2531] = 144
#     assert [z+2532] = 2
#     assert [z+2533] = 79 + note_shift
#     assert [z+2534] = 2
#     assert [z+2535] = 61
#     assert [z+2536] = 2
#     assert [z+2537] = 33632
#     assert [z+2538] = 4
#     assert [z+2539] = 144
#     assert [z+2540] = 2
#     assert [z+2541] = 79 + note_shift
#     assert [z+2542] = 2
#     assert [z+2543] = 0
#     assert [z+2544] = 2
#     assert [z+2545] = 0
#     assert [z+2546] = 2
#     assert [z+2547] = 144
#     assert [z+2548] = 2
#     assert [z+2549] = 80 + note_shift
#     assert [z+2550] = 2
#     assert [z+2551] = 64
#     assert [z+2552] = 2
#     assert [z+2553] = 33632
#     assert [z+2554] = 4
#     assert [z+2555] = 144
#     assert [z+2556] = 2
#     assert [z+2557] = 80 + note_shift
#     assert [z+2558] = 2
#     assert [z+2559] = 0
#     assert [z+2560] = 2
#     assert [z+2561] = 0
#     assert [z+2562] = 2
#     assert [z+2563] = 144
#     assert [z+2564] = 2
#     assert [z+2565] = 75 + note_shift
#     assert [z+2566] = 2
#     assert [z+2567] = 55
#     assert [z+2568] = 2
#     assert [z+2569] = 33632
#     assert [z+2570] = 4
#     assert [z+2571] = 144
#     assert [z+2572] = 2
#     assert [z+2573] = 75 + note_shift
#     assert [z+2574] = 2
#     assert [z+2575] = 0
#     assert [z+2576] = 2
#     assert [z+2577] = 0
#     assert [z+2578] = 2
#     assert [z+2579] = 144
#     assert [z+2580] = 2
#     assert [z+2581] = 77 + note_shift
#     assert [z+2582] = 2
#     assert [z+2583] = 55
#     assert [z+2584] = 2
#     assert [z+2585] = 33632
#     assert [z+2586] = 4
#     assert [z+2587] = 144
#     assert [z+2588] = 2
#     assert [z+2589] = 77 + note_shift
#     assert [z+2590] = 2
#     assert [z+2591] = 0
#     assert [z+2592] = 2
#     assert [z+2593] = 0
#     assert [z+2594] = 2
#     assert [z+2595] = 144
#     assert [z+2596] = 2
#     assert [z+2597] = 75 + note_shift
#     assert [z+2598] = 2
#     assert [z+2599] = 56
#     assert [z+2600] = 2
#     assert [z+2601] = 33632
#     assert [z+2602] = 4
#     assert [z+2603] = 144
#     assert [z+2604] = 2
#     assert [z+2605] = 75 + note_shift
#     assert [z+2606] = 2
#     assert [z+2607] = 0
#     assert [z+2608] = 2
#     assert [z+2609] = 0
#     assert [z+2610] = 2
#     assert [z+2611] = 144
#     assert [z+2612] = 2
#     assert [z+2613] = 73 + note_shift
#     assert [z+2614] = 2
#     assert [z+2615] = 60
#     assert [z+2616] = 2
#     assert [z+2617] = 33632
#     assert [z+2618] = 4
#     assert [z+2619] = 144
#     assert [z+2620] = 2
#     assert [z+2621] = 73 + note_shift
#     assert [z+2622] = 2
#     assert [z+2623] = 0
#     assert [z+2624] = 2
#     assert [z+2625] = 0
#     assert [z+2626] = 2
#     assert [z+2627] = 144
#     assert [z+2628] = 2
#     assert [z+2629] = 72 + note_shift
#     assert [z+2630] = 2
#     assert [z+2631] = 51
#     assert [z+2632] = 2
#     assert [z+2633] = 33632
#     assert [z+2634] = 4
#     assert [z+2635] = 144
#     assert [z+2636] = 2
#     assert [z+2637] = 72 + note_shift
#     assert [z+2638] = 2
#     assert [z+2639] = 0
#     assert [z+2640] = 2
#     assert [z+2641] = 0
#     assert [z+2642] = 2
#     assert [z+2643] = 144
#     assert [z+2644] = 2
#     assert [z+2645] = 73 + note_shift
#     assert [z+2646] = 2
#     assert [z+2647] = 57
#     assert [z+2648] = 2
#     assert [z+2649] = 33632
#     assert [z+2650] = 4
#     assert [z+2651] = 144
#     assert [z+2652] = 2
#     assert [z+2653] = 73 + note_shift
#     assert [z+2654] = 2
#     assert [z+2655] = 0
#     assert [z+2656] = 2
#     assert [z+2657] = 0
#     assert [z+2658] = 2
#     assert [z+2659] = 144
#     assert [z+2660] = 2
#     assert [z+2661] = 72 + note_shift
#     assert [z+2662] = 2
#     assert [z+2663] = 51
#     assert [z+2664] = 2
#     assert [z+2665] = 33632
#     assert [z+2666] = 4
#     assert [z+2667] = 144
#     assert [z+2668] = 2
#     assert [z+2669] = 72 + note_shift
#     assert [z+2670] = 2
#     assert [z+2671] = 0
#     assert [z+2672] = 2
#     assert [z+2673] = 0
#     assert [z+2674] = 2
#     assert [z+2675] = 144
#     assert [z+2676] = 2
#     assert [z+2677] = 70 + note_shift
#     assert [z+2678] = 2
#     assert [z+2679] = 61
#     assert [z+2680] = 2
#     assert [z+2681] = 33632
#     assert [z+2682] = 4
#     assert [z+2683] = 144
#     assert [z+2684] = 2
#     assert [z+2685] = 70 + note_shift
#     assert [z+2686] = 2
#     assert [z+2687] = 0
#     assert [z+2688] = 2
#     assert [z+2689] = 0
#     assert [z+2690] = 2
#     assert [z+2691] = 144
#     assert [z+2692] = 2
#     assert [z+2693] = 68 + note_shift
#     assert [z+2694] = 2
#     assert [z+2695] = 49
#     assert [z+2696] = 2
#     assert [z+2697] = 33632
#     assert [z+2698] = 4
#     assert [z+2699] = 144
#     assert [z+2700] = 2
#     assert [z+2701] = 68 + note_shift
#     assert [z+2702] = 2
#     assert [z+2703] = 0
#     assert [z+2704] = 2
#     assert [z+2705] = 0
#     assert [z+2706] = 2
#     assert [z+2707] = 144
#     assert [z+2708] = 2
#     assert [z+2709] = 70 + note_shift
#     assert [z+2710] = 2
#     assert [z+2711] = 52
#     assert [z+2712] = 2
#     assert [z+2713] = 33632
#     assert [z+2714] = 4
#     assert [z+2715] = 144
#     assert [z+2716] = 2
#     assert [z+2717] = 70 + note_shift
#     assert [z+2718] = 2
#     assert [z+2719] = 0
#     assert [z+2720] = 2
#     assert [z+2721] = 0
#     assert [z+2722] = 2
#     assert [z+2723] = 144
#     assert [z+2724] = 2
#     assert [z+2725] = 68 + note_shift
#     assert [z+2726] = 2
#     assert [z+2727] = 49
#     assert [z+2728] = 2
#     assert [z+2729] = 33632
#     assert [z+2730] = 4
#     assert [z+2731] = 144
#     assert [z+2732] = 2
#     assert [z+2733] = 68 + note_shift
#     assert [z+2734] = 2
#     assert [z+2735] = 0
#     assert [z+2736] = 2
#     assert [z+2737] = 0
#     assert [z+2738] = 2
#     assert [z+2739] = 144
#     assert [z+2740] = 2
#     assert [z+2741] = 70 + note_shift
#     assert [z+2742] = 2
#     assert [z+2743] = 55
#     assert [z+2744] = 2
#     assert [z+2745] = 33632
#     assert [z+2746] = 4
#     assert [z+2747] = 144
#     assert [z+2748] = 2
#     assert [z+2749] = 70 + note_shift
#     assert [z+2750] = 2
#     assert [z+2751] = 0
#     assert [z+2752] = 2
#     assert [z+2753] = 0
#     assert [z+2754] = 2
#     assert [z+2755] = 144
#     assert [z+2756] = 2
#     assert [z+2757] = 68 + note_shift
#     assert [z+2758] = 2
#     assert [z+2759] = 40
#     assert [z+2760] = 2
#     assert [z+2761] = 33632
#     assert [z+2762] = 4
#     assert [z+2763] = 144
#     assert [z+2764] = 2
#     assert [z+2765] = 68 + note_shift
#     assert [z+2766] = 2
#     assert [z+2767] = 0
#     assert [z+2768] = 2
#     assert [z+2769] = 0
#     assert [z+2770] = 2
#     assert [z+2771] = 144
#     assert [z+2772] = 2
#     assert [z+2773] = 70 + note_shift
#     assert [z+2774] = 2
#     assert [z+2775] = 50
#     assert [z+2776] = 2
#     assert [z+2777] = 33632
#     assert [z+2778] = 4
#     assert [z+2779] = 144
#     assert [z+2780] = 2
#     assert [z+2781] = 70 + note_shift
#     assert [z+2782] = 2
#     assert [z+2783] = 0
#     assert [z+2784] = 2
#     assert [z+2785] = 0
#     assert [z+2786] = 2
#     assert [z+2787] = 144
#     assert [z+2788] = 2
#     assert [z+2789] = 68 + note_shift
#     assert [z+2790] = 2
#     assert [z+2791] = 42
#     assert [z+2792] = 2
#     assert [z+2793] = 33632
#     assert [z+2794] = 4
#     assert [z+2795] = 144
#     assert [z+2796] = 2
#     assert [z+2797] = 68 + note_shift
#     assert [z+2798] = 2
#     assert [z+2799] = 0
#     assert [z+2800] = 2
#     assert [z+2801] = 48128
#     assert [z+2802] = 4
#     assert [z+2803] = 144
#     assert [z+2804] = 2
#     assert [z+2805] = 68 + note_shift
#     assert [z+2806] = 2
#     assert [z+2807] = 39
#     assert [z+2808] = 2
#     assert [z+2809] = 33136
#     assert [z+2810] = 4
#     assert [z+2811] = 144
#     assert [z+2812] = 2
#     assert [z+2813] = 68 + note_shift
#     assert [z+2814] = 2
#     assert [z+2815] = 0
#     assert [z+2816] = 2
#     assert [z+2817] = 33136
#     assert [z+2818] = 4
#     assert [z+2819] = 144
#     assert [z+2820] = 2
#     assert [z+2821] = 92 + note_shift
#     assert [z+2822] = 2
#     assert [z+2823] = 41
#     assert [z+2824] = 2
#     assert [z+2825] = 0
#     assert [z+2826] = 2
#     assert [z+2827] = 144
#     assert [z+2828] = 2
#     assert [z+2829] = 80 + note_shift
#     assert [z+2830] = 2
#     assert [z+2831] = 41
#     assert [z+2832] = 2
#     assert [z+2833] = 33136
#     assert [z+2834] = 4
#     assert [z+2835] = 144
#     assert [z+2836] = 2
#     assert [z+2837] = 80 + note_shift
#     assert [z+2838] = 2
#     assert [z+2839] = 0
#     assert [z+2840] = 2
#     assert [z+2841] = 0
#     assert [z+2842] = 2
#     assert [z+2843] = 144
#     assert [z+2844] = 2
#     assert [z+2845] = 92 + note_shift
#     assert [z+2846] = 2
#     assert [z+2847] = 0
#     assert [z+2848] = 2
#     assert [z+2849] = 34128
#     assert [z+2850] = 4
#     assert [z+2851] = 144
#     assert [z+2852] = 2
#     assert [z+2853] = 72 + note_shift
#     assert [z+2854] = 2
#     assert [z+2855] = 26
#     assert [z+2856] = 2
#     assert [z+2857] = 0
#     assert [z+2858] = 2
#     assert [z+2859] = 144
#     assert [z+2860] = 2
#     assert [z+2861] = 63 + note_shift
#     assert [z+2862] = 2
#     assert [z+2863] = 26
#     assert [z+2864] = 2
#     assert [z+2865] = 33632
#     assert [z+2866] = 4
#     assert [z+2867] = 144
#     assert [z+2868] = 2
#     assert [z+2869] = 63 + note_shift
#     assert [z+2870] = 2
#     assert [z+2871] = 0
#     assert [z+2872] = 2
#     assert [z+2873] = 0
#     assert [z+2874] = 2
#     assert [z+2875] = 144
#     assert [z+2876] = 2
#     assert [z+2877] = 72 + note_shift
#     assert [z+2878] = 2
#     assert [z+2879] = 0
#     assert [z+2880] = 2
#     assert [z+2881] = 33384
#     assert [z+2882] = 4
#     assert [z+2883] = 144
#     assert [z+2884] = 2
#     assert [z+2885] = 60 + note_shift
#     assert [z+2886] = 2
#     assert [z+2887] = 33
#     assert [z+2888] = 2
#     assert [z+2889] = 120
#     assert [z+2890] = 2
#     assert [z+2891] = 144
#     assert [z+2892] = 2
#     assert [z+2893] = 68 + note_shift
#     assert [z+2894] = 2
#     assert [z+2895] = 37
#     assert [z+2896] = 2
#     assert [z+2897] = 35616
#     assert [z+2898] = 4
#     assert [z+2899] = 144
#     assert [z+2900] = 2
#     assert [z+2901] = 68 + note_shift
#     assert [z+2902] = 2
#     assert [z+2903] = 0
#     assert [z+2904] = 2
#     assert [z+2905] = 0
#     assert [z+2906] = 2
#     assert [z+2907] = 144
#     assert [z+2908] = 2
#     assert [z+2909] = 60 + note_shift
#     assert [z+2910] = 2
#     assert [z+2911] = 0
#     assert [z+2912] = 2
#     assert [z+2913] = 0
#     assert [z+2914] = 2
#     assert [z+2915] = 16723712
#     assert [z+2916] = 6

# %% [markdown]
# ### For demo purposes, manually generate all contracts

# %%
### tempo contract track_objs[0] non-manipulable

# %%
### track_objs[1]

chopin.track_objs[1]
#for event in chopin.track_objs[1].segs:
# Out:
# 736

# %% [markdown]
# #### Investigating midi file reconstructed from testnet

# %%
midi_testnet = Music('test/chpn_from_testnet')

# %%
midi_testnet.header_str
# Out:
# ''

# %% [markdown]
# ---

# %% [markdown]
# Reference for converting variable-length bytes to integer
# ```
# uint32_t varfieldGet()
# {
#     uint32_t ret = 0;
#     uint8_t byte_in;
#
#     for (;;)
#     {
#         if (m_source.eof())
#             // return error
#         byte_in = m_source.byteGet();
#         ret = (ret << 7) | (byte_in & 0x7f);
#         if (!(byte_in & 0x80))
#             return ret;
#     }
# }
# ```

# %%
def varFieldToInt(hexstring):
    
    ret = 0
    current_byte = ''
    
    i=0
    while len(hexstring):
        current_byte = "0x" + hexstring[0:2]
        current_integer = int(current_byte, 16)
        ret = (ret << 7) | (current_integer & 0x7f)
        if not current_integer & 0x80:
            return ret
        hexstring = hexstring[2:]
        
        i += 1
        if i>1000:
            print('error')
            break

assert varFieldToInt('00') == 0
assert varFieldToInt('7f') == 127
assert varFieldToInt('8100') == 128
assert varFieldToInt('ff7f') == 16383
assert varFieldToInt('818000') == 16384
